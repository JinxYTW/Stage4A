# %% [markdown]
# # Installation

# %%
# !pip install ultralytics --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 32.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 87.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 78.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 17.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 73.7 MB/s eta 0:00:00

# %% [markdown]
# # Vérification avant de commencer

# %%
import ultralytics
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
ultralytics.checks()
# Out:
# Ultralytics 8.3.119 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.2/112.6 GB disk)

# %% [markdown]
# Visualisation des ressources et utilisation GPU

# %%
# !nvidia-smi
# Out:
# Mon Apr 28 12:52:05 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   33C    P8              9W /   70W |       2MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# Vérification disponibilité GPU

# %%
import torch
print("GPU disponible :", torch.cuda.is_available())
# Out:
# GPU disponible : True

# %% [markdown]
# # Préparation du dataset

# %%
# !unzip -q /content/data.zip -d /content/custom_data_raw

# %% [markdown]
# ## Organisation à avoir

# %% [markdown]
# ```
# custom_data/
# ├── images/
# │   ├── train/
# │   └── val/
# ├── labels/
# │   ├── train/
# │   └── val/

# %% [markdown]
# ## Réorganisation du dataset

# %%
import os
import shutil
from sklearn.model_selection import train_test_split

# Répertoire d'origine pour les images et annotations
raw_data_path_images = "/content/custom_data_raw/images"  # Images sont dans ce dossier
raw_data_path_labels = "/content/custom_data_raw/obj_train_data"  # Annotations dans ce dossier

# Obtenir toutes les images (jpg/png) présentes dans le dossier "images"
images = [f for f in os.listdir(raw_data_path_images) if f.endswith(('.jpg', '.png'))]

# Split train/val (80% train, 20% val)
train_imgs, val_imgs = train_test_split(images, test_size=0.2, random_state=42)

# Création des dossiers cible pour images et labels
base_path = "/content/custom_data"


os.makedirs(base_path + "/images/train", exist_ok=True)
os.makedirs(base_path + "/images/val", exist_ok=True)
os.makedirs(base_path + "/labels/train", exist_ok=True)
os.makedirs(base_path + "/labels/val", exist_ok=True)

def move_data(image_list, split):
    for img_name in image_list:
        # Déplacer l'image vers le bon dossier
        src_img = os.path.join(raw_data_path_images, img_name)
        dst_img = os.path.join(base_path, f"images/{split}", img_name)
        shutil.copy(src_img, dst_img)

        # Vérifier et déplacer l'annotation .txt correspondante
        txt_name = img_name.rsplit('.', 1)[0] + '.txt'
        txt_src = os.path.join(raw_data_path_labels, txt_name)
        txt_dst = os.path.join(base_path, f"labels/{split}", txt_name)

        if os.path.exists(txt_src):
            shutil.copy(txt_src, txt_dst)
        else:
            print(f"Pas d'annotation pour {img_name}")

# Appliquer le déplacement aux deux splits : train et val
move_data(train_imgs, "train")
move_data(val_imgs, "val")

# %% [markdown]
# # Augmentation

# %%
import albumentations as A
from albumentations.pytorch import ToTensorV2
from tqdm import tqdm
import cv2
import os

# === PARAMÈTRES ===
augmentations = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.2),
    A.RandomBrightnessContrast(p=0.3),
    A.Rotate(limit=20, p=0.3),
    A.RandomGamma(p=0.3),
    A.HueSaturationValue(hue_shift_limit=10, sat_shift_limit=20, val_shift_limit=10, p=0.4)
])

# Tu appliques l'augmentation uniquement sur le dossier d'entraînement
augmented_path = "/content/custom_data_augmented/images/train"
augmented_label_path = "/content/custom_data_augmented/labels/train"
os.makedirs(augmented_path, exist_ok=True)
os.makedirs(augmented_label_path, exist_ok=True)

original_train_images_path = "/content/custom_data/images/train"
original_train_labels_path = "/content/custom_data/labels/train"

# Copie les fichiers originaux
for img_file in tqdm(os.listdir(original_train_images_path), desc="Copie des images originales"):
    if not img_file.endswith(('.jpg', '.png')):
        continue
    img_path = os.path.join(original_train_images_path, img_file)
    label_path = os.path.join(original_train_labels_path, img_file.replace('.jpg', '.txt').replace('.png', '.txt'))

    img = cv2.imread(img_path)
    h, w = img.shape[:2]

    # Sauvegarde originale
    cv2.imwrite(os.path.join(augmented_path, img_file), img)
    shutil.copy(label_path, os.path.join(augmented_label_path, os.path.basename(label_path)))

    # Augmente 2 fois chaque image
    for i in range(2):
        augmented = augmentations(image=img)["image"]
        aug_img_name = img_file.replace('.', f'_aug{i}.')
        aug_lbl_name = img_file.replace('.jpg', f'_aug{i}.txt').replace('.png', f'_aug{i}.txt')

        cv2.imwrite(os.path.join(augmented_path, aug_img_name), augmented)
        shutil.copy(label_path, os.path.join(augmented_label_path, aug_lbl_name))

print("✅ Dataset augmenté.")
# Out:
# Copie des images originales: 100%|██████████| 28/28 [00:16<00:00,  1.75it/s]
# ✅ Dataset augmenté.

# %%
# Copie val original sans modification
original_val_images_path = "/content/custom_data/images/val"
original_val_labels_path = "/content/custom_data/labels/val"

val_img_out_dir = "/content/custom_data_augmented/images/val"
val_lbl_out_dir = "/content/custom_data_augmented/labels/val"

os.makedirs(val_img_out_dir, exist_ok=True)
os.makedirs(val_lbl_out_dir, exist_ok=True)

for img_file in os.listdir(original_val_images_path):
    if not img_file.endswith(('.jpg', '.png')):
        continue

    img_src = os.path.join(original_val_images_path, img_file)
    lbl_src = os.path.join(original_val_labels_path, img_file.replace('.jpg', '.txt').replace('.png', '.txt'))

    img_dst = os.path.join(val_img_out_dir, img_file)
    lbl_dst = os.path.join(val_lbl_out_dir, os.path.basename(lbl_src))

    shutil.copy(img_src, img_dst)
    shutil.copy(lbl_src, lbl_dst)

print("✅ Validation copiée sans modification.")
# Out:
# ✅ Validation copiée sans modification.

# %% [markdown]
# # Split des images du dataset

# %%
import os
import cv2
import shutil

# === PARAMÈTRES ===
# input_root = "/content/custom_data"
input_root = "/content/custom_data_augmented"

output_root = "/content/split_custom_data"

base_split_path = "/content/split_custom_data"

tile_size = 320
overlap = 0

splits = ["train", "val"]

def yolo_to_bbox(x_center, y_center, w, h, img_w, img_h):
    x1 = int((x_center - w / 2) * img_w)
    y1 = int((y_center - h / 2) * img_h)
    x2 = int((x_center + w / 2) * img_w)
    y2 = int((y_center + h / 2) * img_h)
    return x1, y1, x2, y2

def bbox_to_yolo(x1, y1, x2, y2, tile_w, tile_h):
    x_center = (x1 + x2) / 2 / tile_w
    y_center = (y1 + y2) / 2 / tile_h
    w = (x2 - x1) / tile_w
    h = (y2 - y1) / tile_h
    return x_center, y_center, w, h

# Boucle sur train et val
for split in splits:
    input_img_dir = os.path.join(input_root, f"images/{split}")
    input_lbl_dir = os.path.join(input_root, f"labels/{split}")
    output_img_dir = os.path.join(output_root, f"images/{split}")
    output_lbl_dir = os.path.join(output_root, f"labels/{split}")

    os.makedirs(output_img_dir, exist_ok=True)
    os.makedirs(output_lbl_dir, exist_ok=True)

    for filename in os.listdir(input_img_dir):
        if not filename.lower().endswith(('.jpg', '.png')):
            continue

        basename = os.path.splitext(filename)[0]
        img_path = os.path.join(input_img_dir, filename)
        label_path = os.path.join(input_lbl_dir, f"{basename}.txt")

        img = cv2.imread(img_path)
        img_h, img_w = img.shape[:2]

        annotations = []
        if os.path.exists(label_path):
            with open(label_path, "r") as f:
                for line in f.readlines():
                    parts = line.strip().split()
                    if len(parts) == 5:
                        cls, xc, yc, w, h = map(float, parts)
                        annotations.append((cls, *yolo_to_bbox(xc, yc, w, h, img_w, img_h)))

        step = tile_size - overlap
        tile_id = 0

        for y in range(0, img_h, step):
            for x in range(0, img_w, step):
                tile = img[y:y + tile_size, x:x + tile_size]
                tile_h, tile_w = tile.shape[:2]

                if tile_h < tile_size or tile_w < tile_size:
                    continue

                tile_filename = f"{basename}_{tile_id}.jpg"
                label_filename = f"{basename}_{tile_id}.txt"
                tile_id += 1

                cv2.imwrite(os.path.join(output_img_dir, tile_filename), tile)

                new_annots = []
                for cls, x1, y1, x2, y2 in annotations:
                    if x1 >= x + tile_size or x2 <= x or y1 >= y + tile_size or y2 <= y:
                        continue

                    bx1 = max(0, x1 - x)
                    by1 = max(0, y1 - y)
                    bx2 = min(tile_size, x2 - x)
                    by2 = min(tile_size, y2 - y)

                    if bx2 - bx1 < 5 or by2 - by1 < 5:
                        continue

                    x_c, y_c, w, h = bbox_to_yolo(bx1, by1, bx2, by2, tile_size, tile_size)
                    new_annots.append(f"{int(cls)} {x_c:.6f} {y_c:.6f} {w:.6f} {h:.6f}")

                with open(os.path.join(output_lbl_dir, label_filename), "w") as f:
                    f.write("\n".join(new_annots))

    print(f"✅ Split terminé pour '{split}' — {len(os.listdir(output_img_dir))} tuiles générées")
# Out:
# ✅ Split terminé pour 'train' — 6420 tuiles générées
# ✅ Split terminé pour 'val' — 572 tuiles générées

# %% [markdown]
# # Génération des YAML

# %% [markdown]
# Dynamique :

# %%
# Chemin vers le fichier obj.names exporté par CVAT (modifie si besoin)
obj_names_path = "/content/custom_data_raw/obj.names"

# Lire les noms de classes depuis obj.names
with open(obj_names_path, 'r') as f:
    class_names = [line.strip() for line in f if line.strip()]

# Générer le contenu du fichier YAML avec les augmentations de couleur
yaml_content = f"""
path: {base_split_path}
train: images/train
val: images/val
nc: {len(class_names)}
names: {class_names}
augment: True  # Activer l'augmentation des données
auto_augment: albumentations



# weights: [0.9, 0.1]  # Exemple de pondération si olive est trop présente
"""


# Écriture du fichier data.yaml
with open(f"{base_path}/data.yaml", "w") as f:
    f.write(yaml_content.strip())

with open(f"{base_split_path}/data.yaml", "w") as f:
    f.write(yaml_content.strip())

print(" Fichier data.yaml généré automatiquement :")
print(yaml_content)
# Out:
#  Fichier data.yaml généré automatiquement :
#
# path: /content/split_custom_data
# train: images/train
# val: images/val
# nc: 2
# names: ['olive', 'potential_olive']
# augment: True  # Activer l'augmentation des données
# auto_augment: albumentations
#
#
#
# # weights: [0.9, 0.1]  # Exemple de pondération si olive est trop présente

# %%
custom_train_cfg = """
# train_custom.yaml — Configuration d'entraînement pour YOLOv8

# Chemins
data: /content/split_custom_data/data.yaml
model: yolov8m.pt
# model: yolo11x.pt

# Entraînement
epochs: 50
batch: 16
imgsz: 320
# device: 0

# Hyperparamètres généraux
optimizer: SGD
lr0: 0.01
lrf: 0.01




# Augmentations géométriques
degrees: 00.0
translate: 0.0
scale: 0.5
shear: 0.0
perspective: 0.0
flipud: 0.0
fliplr: 0.5

# Augmentations de couleur (adapté olives/feuillage)
hsv_h: 0.02
hsv_s: 0.6
hsv_v: 0.5

# Avancées
mosaic: 0.3
mixup: 0.1
copy_paste: 0.6

# auto_augment: randaugment
auto_augment: albumentations

"""

# Écriture du fichier YAML
with open("/content/custom_data/train_custom.yaml", "w") as f:
    f.write(custom_train_cfg.strip())

print("✅ Fichier train_custom.yaml généré.")

with open(f"/content/split_custom_data/train_custom.yaml", "w") as f:
    f.write(custom_train_cfg.strip())

print("✅ Fichier train_custom.yaml généré.")
# Out:
# ✅ Fichier train_custom.yaml généré.
# ✅ Fichier train_custom.yaml généré.

# %% [markdown]
# ## Vérification des labels et autres

# %%
import os
from collections import Counter

# Dictionnaire des classes : adapte-le si jamais tu changes l'ordre ou les noms
class_names = {
    '0': 'olive',
    '1': 'potential_olive'
}

def analyze_labels(labels_dir):
    label_counts = Counter()

    for split in ['train', 'val']:
        dir_path = os.path.join(labels_dir, split)
        for file in os.listdir(dir_path):
            if file.endswith('.txt'):
                with open(os.path.join(dir_path, file), 'r') as f:
                    for line in f:
                        if line.strip():
                            class_id = line.strip().split()[0]
                            label_counts[class_id] += 1

    print(" Résumé des classes dans les annotations :\n")
    for class_id, count in label_counts.items():
        class_name = class_names.get(class_id, " Inconnu")
        print(f"Classe {class_id} ({class_name}) → {count} objets")

    # Alerte pour les classes non attendues
    for cid in label_counts:
        if cid not in class_names:
            print(f"\n ID inattendu détecté : {cid}")

# Appel de la fonction
analyze_labels(f"{base_split_path}/labels")
# Out:
#  Résumé des classes dans les annotations :
#
# Classe 0 (olive) → 9761 objets
# Classe 1 (potential_olive) → 355 objets

# %% [markdown]
# # Train

# %% [markdown]
# - Changer le nombre d'epochs : Avec seulement 6 images et un grand déséquilibre, 10 epochs peuvent ne pas être suffisants. Essaie d'augmenter le nombre d'epochs (par exemple, à 50 ou 100) pour donner au modèle plus de temps pour apprendre.
#
# - Réduire le imgsz : La taille des images peut avoir un impact sur l'entraînement. Si les images sont petites (moins de détails), une taille de 320x320 ou 416x416 pourrait mieux fonctionner qu'une taille de 640x640, qui peut être plus difficile à traiter.

# %%
# !yolo task=detect mode=train cfg={base_split_path}/train_custom.yaml
# Out:
# Overriding /usr/local/lib/python3.11/dist-packages/ultralytics/cfg/default.yaml with /content/split_custom_data/train_custom.yaml
# WARNING ⚠️ 'mode' argument is missing. Valid modes are frozenset({'val', 'predict', 'train', 'export', 'track', 'benchmark'}). Using default 'mode=train'.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8m.pt to 'yolov8m.pt'...
# 100% 49.7M/49.7M [00:00<00:00, 374MB/s]
# Ultralytics 8.3.119 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: task=detect, mode=train, model=yolov8m.pt, data=/content/split_custom_data/data.yaml, epochs=50, time=None, patience=100, batch=16, imgsz=320, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.02, hsv_s=0.6, hsv_v=0.5, degrees=0.0, translate=0.0, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic
0.223
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      5.63G      1.856      2.165      1.285          1        320: 100% 402/402 [01:08<00:00,  5.84it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 18/18 [00:03<00:00,  5.00it/s]
#                    all        572       1320       0.88       0.32       0.36      0.218
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      5.68G      1.869       2.19      1.287          6        320: 100% 402/402 [01:09<00:00,  5.79it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 18/18 [00:03<00:00,  5.57it/s]
#                    all        572       1320      0.879      0.315      0.357      0.221
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      5.94G      1.824      2.076      1.265          8        320: 100% 402/402 [01:09<00:00,  5.80it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 18/18 [00:03<00:00,  4.76it/s]
#                    all        572       1320      0.892      0.318      0.365      0.228
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50         6G      1.807      2.098      1.264         11        320: 100% 402/402 [01:09<00:00,  5.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 18/18 [00:03<00:00,  5.48it/s]
#                    all        572       1320      0.881      0.316      0.356      0.219
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      6.03G      1.719       2.07      1.234          3        320: 100% 402/402 [01:09<00:00,  5.78it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 18/18 [00:03<00:00,  4.53it/s]
#                    all        572       1320      0.893      0.313      0.366      0.224
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      6.09G      1.693      2.041      1.228          8        320: 100% 402/402 [01:08<00:00,  5.84it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 18/18 [00:03<00:00,  5.61it/s]
#                    all        572       1320      0.892      0.317      0.363      0.222
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      6.26G      1.682      2.096       1.23         10        320: 100% 402/402 [01:08<00:00,  5.89it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 18/18 [00:03<00:00,  4.83it/s]
#                    all        572       1320      0.884      0.327      0.369      0.225
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      6.31G      1.677      2.043      1.233         13        320: 100% 402/402 [01:08<00:00,  5.89it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 18/18 [00:03<00:00,  5.57it/s]
#                    all        572       1320      0.902      0.318      0.369      0.222
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      6.57G      1.678      2.074      1.223         11        320: 100% 402/402 [01:09<00:00,  5.81it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 18/18 [00:03<00:00,  5.56it/s]
#                    all        572       1320      0.891      0.322      0.375      0.227
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      6.62G      1.645      1.976      1.215          3        320: 100% 402/402 [01:08<00:00,  5.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 18/18 [00:03<00:00,  4.65it/s]
#                    all        572       1320      0.889      0.317      0.373      0.228
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      6.66G      1.641      1.962      1.204          3        320: 100% 402/402 [01:07<00:00,  5.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 18/18 [00:03<00:00,  4.51it/s]
#                    all        572       1320      0.898      0.322      0.371      0.228
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      6.71G      1.669      2.023      1.233          2        320: 100% 402/402 [01:08<00:00,  5.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 18/18 [00:03<00:00,  5.61it/s]
#                    all        572       1320      0.894      0.322      0.368      0.225
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      6.88G      1.647      2.085      1.215          2        320: 100% 402/402 [01:09<00:00,  5.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 18/18 [00:03<00:00,  5.45it/s]
#                    all        572       1320      0.896      0.318      0.368      0.226
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      6.94G      1.579       1.99      1.194          3        320: 100% 402/402 [01:10<00:00,  5.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 18/18 [00:04<00:00,  4.19it/s]
#                    all        572       1320      0.903      0.315      0.367      0.225
#
# 50 epochs completed in 1.062 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 52.0MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 52.0MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics 8.3.119 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 92 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 18/18 [00:04<00:00,  4.00it/s]
#                    all        572       1320      0.889      0.317      0.373      0.229
#                  olive        300       1292      0.777      0.635      0.719      0.445
#        potential_olive         23         28          1          0     0.0272     0.0118
# Speed: 0.1ms preprocess, 2.6ms inference, 0.0ms loss, 1.8ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
#yolo task=detect mode=train model=yolo11n.pt data={base_path}/data.yaml hyp={base_path}/hyp.yaml epochs=100 imgsz=640 device=0

# %%
import glob
from IPython.display import Image, display

# %%
Image(filename='runs/detect/train/confusion_matrix.png', width=600)

# %%
Image(filename='runs/detect/train/results.png', width=600)

# %% [markdown]
# # Validation

# %%
from ultralytics import YOLO

# Charger le modèle entraîné
model = YOLO("runs/detect/train/weights/best.pt")

# Évaluer sur le dataset de validation
metrics = model.val(data="/content/split_custom_data/data.yaml", split="val", verbose=False)

# Accès aux métriques par classe
names = model.names  # dict {class_id: name}
precision_per_class = metrics.box.p  # Précision par classe
recall_per_class = metrics.box.r  # Rappel par classe
map50_per_class = metrics.box.ap50  # mAP à IoU de 0.5 par classe
map_per_class = metrics.box.ap  # mAP à IoU de 0.5-0.95 par classe

# Exemple : récupérer les métriques de la classe "olive"
class_name = "olive"
class_id = list(names.values()).index(class_name)

print(f"Métriques pour la classe '{class_name}':")
print(f" - Précision : {precision_per_class[class_id]:.3f}")
print(f" - Rappel    : {recall_per_class[class_id]:.3f}")
print(f" - mAP@50    : {map50_per_class[class_id]:.3f}")
print(f" - mAP@50-95 : {map_per_class[class_id]:.3f}")
# Out:
# Ultralytics 8.3.119 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 92 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 959.6±367.9 MB/s, size: 46.9 KB)
# val: Scanning /content/split_custom_data/labels/val.cache... 572 images, 269 backgrounds, 0 corrupt: 100%|██████████| 572/572 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 36/36 [00:08<00:00,  4.49it/s]
#                    all        572       1320      0.889      0.318      0.374      0.228
# Speed: 1.0ms preprocess, 5.5ms inference, 0.0ms loss, 2.3ms postprocess per image
# Results saved to runs/detect/val
# Métriques pour la classe 'olive':
#  - Précision : 0.777
#  - Rappel    : 0.635
#  - mAP@50    : 0.722
#  - mAP@50-95 : 0.445

# %% [markdown]
# En modifiant conf

# %%
from ultralytics import YOLO
from pathlib import Path
import cv2
import os
from ultralytics.utils.metrics import bbox_iou

# 🔧 Paramètres
model_path = "runs/detect/train/weights/best.pt"
data_path = "/content/split_custom_data/data.yaml"
val_images_dir = "/content/split_custom_data/images/val"
conf_threshold = 0.08  # 🔁 MODIFIE ici le seuil de confiance
target_class = "olive"
iou_threshold = 0.5  # pour comptage TP/FN

# 📦 Charger modèle + noms des classes
model = YOLO(model_path)
names = model.names
target_id = list(names.values()).index(target_class)

# 📂 Liste des fichiers image de validation
image_paths = list(Path(val_images_dir).rglob("*.jpg")) + list(Path(val_images_dir).rglob("*.png"))

# 🔢 Compteurs
TP, FP, FN = 0, 0, 0

# 🔍 Parcourir les images
import torch

# 🔍 Parcourir les images
for img_path in image_paths:
    results = model.predict(source=str(img_path), conf=conf_threshold, iou=iou_threshold, verbose=False)[0]

    # Prédictions pour la classe cible
    preds = [b for b in results.boxes.data.cpu().numpy() if int(b[5]) == target_id]
    pred_boxes = [b[:4] for b in preds]  # x1, y1, x2, y2

    # Ground truth : via les annotations val
    label_path = str(img_path).replace("/images/", "/labels/").rsplit(".", 1)[0] + ".txt"
    gt_boxes = []
    if os.path.exists(label_path):
        with open(label_path, "r") as f:
            for line in f:
                cls, x, y, w, h = map(float, line.strip().split())
                if int(cls) == target_id:
                    # YOLO format -> (x1, y1, x2, y2)
                    img = cv2.imread(str(img_path))
                    H, W = img.shape[:2]
                    cx, cy, bw, bh = x * W, y * H, w * W, h * H
                    x1 = cx - bw / 2
                    y1 = cy - bh / 2
                    x2 = cx + bw / 2
                    y2 = cy + bh / 2
                    gt_boxes.append([x1, y1, x2, y2])

    # 🧠 Matching GT ↔ prédictions
    matched_gt = set()
    for pred_box in pred_boxes:
        matched = False
        for i, gt_box in enumerate(gt_boxes):
            # Convertir en tensor avant de calculer l'IoU
            pred_box_tensor = torch.tensor(pred_box).unsqueeze(0)  # Convertir en tensor
            gt_box_tensor = torch.tensor(gt_box).unsqueeze(0)  # Convertir en tensor
            iou = bbox_iou(pred_box_tensor, gt_box_tensor)[0]  # Calcul de l'IoU
            if iou > iou_threshold and i not in matched_gt:
                TP += 1
                matched_gt.add(i)
                matched = True
                break
        if not matched:
            FP += 1
    FN += len(gt_boxes) - len(matched_gt)

# 📊 Calcul des métriques
precision = TP / (TP + FP) if (TP + FP) > 0 else 0
recall = TP / (TP + FN) if (TP + FN) > 0 else 0

print(f"\n🔎 Résultats pour la classe '{target_class}' (seuil conf = {conf_threshold}):")
print(f" - Vrais positifs (TP) : {TP}")
print(f" - Faux positifs (FP)  : {FP}")
print(f" - Faux négatifs (FN)  : {FN}")
print(f" - Précision           : {precision:.3f}")
print(f" - Rappel              : {recall:.3f}")
# Out:
# 🔎 Résultats pour la classe 'olive' (seuil conf = 0.08):
#  - Vrais positifs (TP) : 978
#  - Faux positifs (FP)  : 360
#  - Faux négatifs (FN)  : 314
#  - Précision           : 0.731
#  - Rappel              : 0.757

# %% [markdown]
# # Predict

# %% [markdown]
# - Vérifie les prédictions avec conf=0.5 ou plus bas : Parfois, si le modèle est trop conservateur, il ne détecte rien parce qu'il exige une très forte confiance. Essaie de réduire le seuil de confiance lors de la prédiction.

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt source={base_split_path}/images/val conf=0.5 save=True device=0
# Out:
# Ultralytics 8.3.119 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 92 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/572 /content/split_custom_data/images/val/20221108_112521_0.jpg: 320x320 (no detections), 15.8ms
# image 2/572 /content/split_custom_data/images/val/20221108_112521_1.jpg: 320x320 (no detections), 15.8ms
# image 3/572 /content/split_custom_data/images/val/20221108_112521_10.jpg: 320x320 (no detections), 15.8ms
# image 4/572 /content/split_custom_data/images/val/20221108_112521_11.jpg: 320x320 (no detections), 15.7ms
# image 5/572 /content/split_custom_data/images/val/20221108_112521_12.jpg: 320x320 (no detections), 15.7ms
# image 6/572 /content/split_custom_data/images/val/20221108_112521_13.jpg: 320x320 (no detections), 15.6ms
# image 7/572 /content/split_custom_data/images/val/20221108_112521_14.jpg: 320x320 (no detections), 12.3ms
# image 8/572 /content/split_custom_data/images/val/20221108_112521_15.jpg: 320x320 (no detections), 12.3ms
# image 9/572 /content/split_custom_data/images/val/20221108_112521_16.jpg: 320x320 (no detections), 12.3ms
# image 10/572 /content/split_custom_data/images/val/20221108_112521_17.jpg: 320x320 1 olive, 12.3ms
# image 11/572 /content/split_custom_data/images/val/20221108_112521_18.jpg: 320x320 (no detections), 12.4ms
# image 12/572 /content/split_custom_data/images/val/20221108_112521_19.jpg: 320x320 (no detections), 12.3ms
# image 13/572 /content/split_custom_data/images/val/20221108_112521_2.jpg: 320x320 (no detections), 12.3ms
# image 14/572 /content/split_custom_data/images/val/20221108_112521_20.jpg: 320x320 (no detections), 12.3ms
# image 15/572 /content/split_custom_data/images/val/20221108_112521_21.jpg: 320x320 (no detections), 12.3ms
# image 354/572 /content/split_custom_data/images/val/B2.13_24.jpg: 320x320 (no detections), 7.3ms
# image 355/572 /content/split_custom_data/images/val/B2.13_25.jpg: 320x320 (no detections), 7.4ms
# image 356/572 /content/split_custom_data/images/val/B2.13_26.jpg: 320x320 (no detections), 7.4ms
# image 357/572 /content/split_custom_data/images/val/B2.13_27.jpg: 320x320 (no detections), 7.5ms
# image 358/572 /content/split_custom_data/images/val/B2.13_28.jpg: 320x320 2 olives, 7.2ms
# image 359/572 /content/split_custom_data/images/val/B2.13_29.jpg: 320x320 (no detections), 7.3ms
# image 360/572 /content/split_custom_data/images/val/B2.13_3.jpg: 320x320 (no detections), 7.3ms
# image 361/572 /content/split_custom_data/images/val/B2.13_30.jpg: 320x320 (no detections), 7.2ms
# image 362/572 /content/split_custom_data/images/val/B2.13_31.jpg: 320x320 (no detections), 7.1ms
# image 363/572 /content/split_custom_data/images/val/B2.13_32.jpg: 320x320 (no detections), 7.4ms
# image 364/572 /content/split_custom_data/images/val/B2.13_33.jpg: 320x320 (no detections), 8.3ms
# image 365/572 /content/split_custom_data/images/val/B2.13_34.jpg: 320x320 (no detections), 7.1ms
# image 366/572 /content/split_custom_data/images/val/B2.13_35.jpg: 320x320 (no detections), 7.4ms
# image 367/572 /content/split_custom_data/images/val/B2.13_36.jpg: 320x320 (no detections), 8.0ms
# image 368/572 /content/split_custom_data/images/val/B2.13_37.jpg: 320x320 (no detections), 7.2ms
# image 369/572 /content/split_custom_data/images/val/B2.13_38.jpg: 320x320 (no detections), 7.2ms
# image 370/572 /content/split_custom_data/images/val/B2.13_39.jpg: 320x320 (no detections), 7.2ms
# image 371/572 /content/split_custom_data/images/val/B2.13_4.jpg: 320x320 (no detections), 7.0ms
# image 372/572 /content/split_custom_data/images/val/B2.13_40.jpg: 320x320 (no detections), 7.3ms
# image 373/572 /content/split_custom_data/images/val/B2.13_41.jpg: 320x320 (no detections), 7.2ms
# image 374/572 /content/split_custom_data/images/val/B2.13_42.jpg: 320x320 (no detections), 7.4ms
# image 375/572 /content/split_custom_data/images/val/B2.13_43.jpg: 320x320 (no detections), 7.4ms
# image 376/572 /content/split_custom_data/images/val/B2.13_44.jpg: 320x320 (no detections), 8.4ms
# image 377/572 /content/split_custom_data/images/val/B2.13_45.jpg: 320x320 (no detections), 8.2ms
# image 378/572 /content/split_custom_data/images/val/B2.13_46.jpg: 320x320 (no detections), 8.1ms
# image 379/572 /content/split_custom_data/images/val/B2.13_47.jpg: 320x320 (no detections), 7.9ms
# image 380/572 /content/split_custom_data/images/val/B2.13_48.jpg: 320x320 (no detections), 7.2ms
# image 381/572 /content/split_custom_data/images/val/B2.13_49.jpg: 320x320 (no detections), 7.1ms
# image 382/572 /content/split_custom_data/images/val/B2.13_5.jpg: 320x320 (no detections), 7.0ms
# image 383/572 /content/split_custom_data/images/val/B2.13_50.jpg: 320x320 (no detections), 7.3ms
# image 384/572 /content/split_custom_data/images/val/B2.13_51.jpg: 320x320 (no detections), 7.7ms
# image 385/572 /content/split_custom_data/images/val/B2.13_52.jpg: 320x320 (no detections), 7.4ms
# image 386/572 /content/split_custom_data/images/val/B2.13_53.jpg: 320x320 (no detections), 10.0ms
# image 387/572 /content/split_custom_data/images/val/B2.13_54.jpg: 320x320 (no detections), 7.3ms
# image 388/572 /content/split_custom_data/images/val/B2.13_55.jpg: 320x320 (no detections), 8.8ms
# image 389/572 /content/split_custom_data/images/val/B2.13_56.jpg: 320x320 (no detections), 7.7ms
# image 390/572 /content/split_custom_data/images/val/B2.13_57.jpg: 320x320 (no detections), 7.6ms
# image 391/572 /content/split_custom_data/images/val/B2.13_58.jpg: 320x320 (no detections), 7.3ms
# image 392/572 /content/split_custom_data/images/val/B2.13_59.jpg: 320x320 (no detections), 9.9ms
# image 393/572 /content/split_custom_data/images/val/B2.13_6.jpg: 320x320 (no detections), 9.0ms
# image 394/572 /content/split_custom_data/images/val/B2.13_7.jpg: 320x320 (no detections), 7.8ms
# image 395/572 /content/split_custom_data/images/val/B2.13_8.jpg: 320x320 (no detections), 7.7ms
# image 396/572 /content/split_custom_data/images/val/B2.13_9.jpg: 320x320 (no detections), 7.8ms
# image 397/572 /content/split_custom_data/images/val/IMG_20221123_154043_0.jpg: 320x320 (no detections), 7.8ms
# image 398/572 /content/split_custom_data/images/val/IMG_20221123_154043_1.jpg: 320x320 (no detections), 7.1ms
# image 399/572 /content/split_custom_data/images/val/IMG_20221123_154043_10.jpg: 320x320 (no detections), 7.3ms
# image 400/572 /content/split_custom_data/images/val/IMG_20221123_154043_11.jpg: 320x320 (no detections), 7.1ms
# image 401/572 /content/split_custom_data/images/val/IMG_20221123_154043_12.jpg: 320x320 (no detections), 7.4ms
# image 402/572 /content/split_custom_data/images/val/IMG_20221123_154043_13.jpg: 320x320 (no detections), 7.2ms
# image 403/572 /content/split_custom_data/images/val/IMG_20221123_154043_14.jpg: 320x320 (no detections), 7.3ms
# image 404/572 /content/split_custom_data/images/val/IMG_20221123_154043_15.jpg: 320x320 (no detections), 9.6ms
# image 405/572 /content/split_custom_data/images/val/IMG_20221123_154043_16.jpg: 320x320 (no detections), 8.6ms
# image 406/572 /content/split_custom_data/images/val/IMG_20221123_154043_17.jpg: 320x320 (no detections), 7.2ms
# image 407/572 /content/split_custom_data/images/val/IMG_20221123_154043_18.jpg: 320x320 (no detections), 7.1ms
# image 408/572 /content/split_custom_data/images/val/IMG_20221123_154043_19.jpg: 320x320 (no detections), 7.6ms
# image 409/572 /content/split_custom_data/images/val/IMG_20221123_154043_2.jpg: 320x320 (no detections), 7.2ms
# image 410/572 /content/split_custom_data/images/val/IMG_20221123_154043_20.jpg: 320x320 (no detections), 7.5ms
# image 411/572 /content/split_custom_data/images/val/IMG_20221123_154043_21.jpg: 320x320 (no detections), 7.1ms
# image 412/572 /content/split_custom_data/images/val/IMG_20221123_154043_22.jpg: 320x320 (no detections), 7.1ms
# image 413/572 /content/split_custom_data/images/val/IMG_20221123_154043_23.jpg: 320x320 (no detections), 7.1ms
# image 414/572 /content/split_custom_data/images/val/IMG_20221123_154043_24.jpg: 320x320 (no detections), 7.0ms
# image 415/572 /content/split_custom_data/images/val/IMG_20221123_154043_25.jpg: 320x320 (no detections), 8.2ms
# image 416/572 /content/split_custom_data/images/val/IMG_20221123_154043_26.jpg: 320x320 (no detections), 7.5ms
# image 417/572 /content/split_custom_data/images/val/IMG_20221123_154043_27.jpg: 320x320 (no detections), 7.5ms
# image 418/572 /content/split_custom_data/images/val/IMG_20221123_154043_28.jpg: 320x320 (no detections), 7.4ms
# image 419/572 /content/split_custom_data/images/val/IMG_20221123_154043_29.jpg: 320x320 (no detections), 7.3ms
# image 420/572 /content/split_custom_data/images/val/IMG_20221123_154043_3.jpg: 320x320 (no detections), 7.4ms
# image 421/572 /content/split_custom_data/images/val/IMG_20221123_154043_30.jpg: 320x320 (no detections), 7.2ms
# image 422/572 /content/split_custom_data/images/val/IMG_20221123_154043_31.jpg: 320x320 (no detections), 7.3ms
# image 423/572 /content/split_custom_data/images/val/IMG_20221123_154043_32.jpg: 320x320 (no detections), 9.3ms
# image 424/572 /content/split_custom_data/images/val/IMG_20221123_154043_33.jpg: 320x320 (no detections), 12.8ms
# image 425/572 /content/split_custom_data/images/val/IMG_20221123_154043_34.jpg: 320x320 (no detections), 14.2ms
# image 426/572 /content/split_custom_data/images/val/IMG_20221123_154043_35.jpg: 320x320 (no detections), 7.6ms
# image 427/572 /content/split_custom_data/images/val/IMG_20221123_154043_36.jpg: 320x320 (no detections), 7.5ms
# image 428/572 /content/split_custom_data/images/val/IMG_20221123_154043_37.jpg: 320x320 (no detections), 7.6ms
# image 429/572 /content/split_custom_data/images/val/IMG_20221123_154043_38.jpg: 320x320 (no detections), 8.1ms
# image 430/572 /content/split_custom_data/images/val/IMG_20221123_154043_39.jpg: 320x320 (no detections), 8.2ms
# image 431/572 /content/split_custom_data/images/val/IMG_20221123_154043_4.jpg: 320x320 (no detections), 8.1ms
# image 432/572 /content/split_custom_data/images/val/IMG_20221123_154043_40.jpg: 320x320 (no detections), 7.5ms
# image 433/572 /content/split_custom_data/images/val/IMG_20221123_154043_41.jpg: 320x320 (no detections), 7.5ms
# image 434/572 /content/split_custom_data/images/val/IMG_20221123_154043_42.jpg: 320x320 (no detections), 7.4ms
# image 435/572 /content/split_custom_data/images/val/IMG_20221123_154043_43.jpg: 320x320 (no detections), 8.6ms
# image 436/572 /content/split_custom_data/images/val/IMG_20221123_154043_44.jpg: 320x320 (no detections), 9.3ms
# image 437/572 /content/split_custom_data/images/val/IMG_20221123_154043_45.jpg: 320x320 (no detections), 7.3ms
# image 438/572 /content/split_custom_data/images/val/IMG_20221123_154043_46.jpg: 320x320 (no detections), 7.5ms
# image 439/572 /content/split_custom_data/images/val/IMG_20221123_154043_47.jpg: 320x320 (no detections), 7.1ms
# image 440/572 /content/split_custom_data/images/val/IMG_20221123_154043_48.jpg: 320x320 (no detections), 8.5ms
# image 441/572 /content/split_custom_data/images/val/IMG_20221123_154043_49.jpg: 320x320 (no detections), 7.6ms
# image 442/572 /content/split_custom_data/images/val/IMG_20221123_154043_5.jpg: 320x320 (no detections), 7.5ms
# image 471/572 /content/split_custom_data/images/val/IMG_20221123_154043_76.jpg: 320x320 (no detections), 7.1ms
# image 472/572 /content/split_custom_data/images/val/IMG_20221123_154043_77.jpg: 320x320 (no detections), 7.4ms
# image 473/572 /content/split_custom_data/images/val/IMG_20221123_154043_78.jpg: 320x320 (no detections), 7.1ms
# image 474/572 /content/split_custom_data/images/val/IMG_20221123_154043_79.jpg: 320x320 (no detections), 7.6ms
# image 475/572 /content/split_custom_data/images/val/IMG_20221123_154043_8.jpg: 320x320 (no detections), 7.1ms
# image 476/572 /content/split_custom_data/images/val/IMG_20221123_154043_80.jpg: 320x320 (no detections), 7.5ms
# image 477/572 /content/split_custom_data/images/val/IMG_20221123_154043_81.jpg: 320x320 (no detections), 7.4ms
# image 478/572 /content/split_custom_data/images/val/IMG_20221123_154043_82.jpg: 320x320 (no detections), 7.8ms
# image 479/572 /content/split_custom_data/images/val/IMG_20221123_154043_83.jpg: 320x320 (no detections), 7.2ms
# image 480/572 /content/split_custom_data/images/val/IMG_20221123_154043_84.jpg: 320x320 (no detections), 7.6ms
# image 481/572 /content/split_custom_data/images/val/IMG_20221123_154043_85.jpg: 320x320 (no detections), 7.2ms
# image 482/572 /content/split_custom_data/images/val/IMG_20221123_154043_86.jpg: 320x320 (no detections), 7.9ms
# image 483/572 /content/split_custom_data/images/val/IMG_20221123_154043_87.jpg: 320x320 (no detections), 9.7ms
# image 484/572 /content/split_custom_data/images/val/IMG_20221123_154043_9.jpg: 320x320 (no detections), 10.9ms
# image 485/572 /content/split_custom_data/images/val/Probne 2_1_0.jpg: 320x320 (no detections), 10.2ms
# image 486/572 /content/split_custom_data/images/val/Probne 2_1_1.jpg: 320x320 (no detections), 10.3ms
# image 487/572 /content/split_custom_data/images/val/Probne 2_1_10.jpg: 320x320 (no detections), 7.8ms
# image 488/572 /content/split_custom_data/images/val/Probne 2_1_11.jpg: 320x320 (no detections), 10.4ms
# image 489/572 /content/split_custom_data/images/val/Probne 2_1_12.jpg: 320x320 (no detections), 7.7ms
# image 490/572 /content/split_custom_data/images/val/Probne 2_1_13.jpg: 320x320 (no detections), 7.8ms
# image 491/572 /content/split_custom_data/images/val/Probne 2_1_14.jpg: 320x320 (no detections), 7.8ms
# image 492/572 /content/split_custom_data/images/val/Probne 2_1_15.jpg: 320x320 1 olive, 7.6ms
# image 493/572 /content/split_custom_data/images/val/Probne 2_1_16.jpg: 320x320 (no detections), 8.2ms
# image 494/572 /content/split_custom_data/images/val/Probne 2_1_17.jpg: 320x320 (no detections), 7.6ms
# image 495/572 /content/split_custom_data/images/val/Probne 2_1_18.jpg: 320x320 1 olive, 7.9ms
# image 496/572 /content/split_custom_data/images/val/Probne 2_1_19.jpg: 320x320 (no detections), 8.0ms
# image 497/572 /content/split_custom_data/images/val/Probne 2_1_2.jpg: 320x320 (no detections), 7.7ms
# image 498/572 /content/split_custom_data/images/val/Probne 2_1_20.jpg: 320x320 (no detections), 7.3ms
# image 499/572 /content/split_custom_data/images/val/Probne 2_1_21.jpg: 320x320 1 olive, 7.0ms
# image 500/572 /content/split_custom_data/images/val/Probne 2_1_22.jpg: 320x320 1 olive, 7.3ms
# image 501/572 /content/split_custom_data/images/val/Probne 2_1_23.jpg: 320x320 (no detections), 7.2ms
# image 502/572 /content/split_custom_data/images/val/Probne 2_1_24.jpg: 320x320 (no detections), 7.5ms
# image 503/572 /content/split_custom_data/images/val/Probne 2_1_25.jpg: 320x320 3 olives, 7.3ms
# image 504/572 /content/split_custom_data/images/val/Probne 2_1_26.jpg: 320x320 3 olives, 7.5ms
# image 505/572 /content/split_custom_data/images/val/Probne 2_1_27.jpg: 320x320 (no detections), 7.6ms
# image 506/572 /content/split_custom_data/images/val/Probne 2_1_28.jpg: 320x320 (no detections), 7.2ms
# image 507/572 /content/split_custom_data/images/val/Probne 2_1_29.jpg: 320x320 1 olive, 7.5ms
# image 508/572 /content/split_custom_data/images/val/Probne 2_1_3.jpg: 320x320 (no detections), 7.3ms
# image 509/572 /content/split_custom_data/images/val/Probne 2_1_30.jpg: 320x320 3 olives, 7.5ms
# image 510/572 /content/split_custom_data/images/val/Probne 2_1_31.jpg: 320x320 2 olives, 7.9ms
# image 511/572 /content/split_custom_data/images/val/Probne 2_1_32.jpg: 320x320 (no detections), 7.6ms
# image 512/572 /content/split_custom_data/images/val/Probne 2_1_33.jpg: 320x320 2 olives, 11.0ms
# image 513/572 /content/split_custom_data/images/val/Probne 2_1_34.jpg: 320x320 1 olive, 7.5ms
# image 514/572 /content/split_custom_data/images/val/Probne 2_1_35.jpg: 320x320 1 olive, 7.8ms
# image 515/572 /content/split_custom_data/images/val/Probne 2_1_36.jpg: 320x320 1 olive, 12.0ms
# image 516/572 /content/split_custom_data/images/val/Probne 2_1_37.jpg: 320x320 1 olive, 15.7ms
# image 517/572 /content/split_custom_data/images/val/Probne 2_1_38.jpg: 320x320 2 olives, 7.6ms
# image 518/572 /content/split_custom_data/images/val/Probne 2_1_39.jpg: 320x320 (no detections), 7.3ms
# image 519/572 /content/split_custom_data/images/val/Probne 2_1_4.jpg: 320x320 (no detections), 7.5ms
# image 520/572 /content/split_custom_data/images/val/Probne 2_1_40.jpg: 320x320 (no detections), 7.3ms
# image 521/572 /content/split_custom_data/images/val/Probne 2_1_41.jpg: 320x320 (no detections), 7.2ms
# image 522/572 /content/split_custom_data/images/val/Probne 2_1_42.jpg: 320x320 (no detections), 7.3ms
# image 523/572 /content/split_custom_data/images/val/Probne 2_1_43.jpg: 320x320 3 olives, 7.4ms
# image 524/572 /content/split_custom_data/images/val/Probne 2_1_44.jpg: 320x320 1 olive, 7.3ms
# image 525/572 /content/split_custom_data/images/val/Probne 2_1_45.jpg: 320x320 3 olives, 7.6ms
# image 526/572 /content/split_custom_data/images/val/Probne 2_1_46.jpg: 320x320 (no detections), 7.6ms
# image 527/572 /content/split_custom_data/images/val/Probne 2_1_47.jpg: 320x320 (no detections), 7.2ms
# image 528/572 /content/split_custom_data/images/val/Probne 2_1_48.jpg: 320x320 (no detections), 7.3ms
# image 529/572 /content/split_custom_data/images/val/Probne 2_1_49.jpg: 320x320 1 olive, 7.3ms
# image 530/572 /content/split_custom_data/images/val/Probne 2_1_5.jpg: 320x320 (no detections), 7.2ms
# image 531/572 /content/split_custom_data/images/val/Probne 2_1_50.jpg: 320x320 1 olive, 7.4ms
# image 532/572 /content/split_custom_data/images/val/Probne 2_1_51.jpg: 320x320 (no detections), 8.4ms
# image 533/572 /content/split_custom_data/images/val/Probne 2_1_52.jpg: 320x320 1 olive, 8.2ms
# image 534/572 /content/split_custom_data/images/val/Probne 2_1_53.jpg: 320x320 1 olive, 8.4ms
# image 535/572 /content/split_custom_data/images/val/Probne 2_1_54.jpg: 320x320 1 olive, 7.8ms
# image 536/572 /content/split_custom_data/images/val/Probne 2_1_55.jpg: 320x320 (no detections), 8.3ms
# image 537/572 /content/split_custom_data/images/val/Probne 2_1_56.jpg: 320x320 (no detections), 8.9ms
# image 538/572 /content/split_custom_data/images/val/Probne 2_1_57.jpg: 320x320 (no detections), 7.3ms
# image 539/572 /content/split_custom_data/images/val/Probne 2_1_58.jpg: 320x320 (no detections), 7.5ms
# image 540/572 /content/split_custom_data/images/val/Probne 2_1_59.jpg: 320x320 (no detections), 7.5ms
# image 541/572 /content/split_custom_data/images/val/Probne 2_1_6.jpg: 320x320 (no detections), 8.6ms
# image 542/572 /content/split_custom_data/images/val/Probne 2_1_60.jpg: 320x320 2 olives, 7.9ms
# image 543/572 /content/split_custom_data/images/val/Probne 2_1_61.jpg: 320x320 1 olive, 7.6ms
# image 544/572 /content/split_custom_data/images/val/Probne 2_1_62.jpg: 320x320 (no detections), 7.2ms
# image 545/572 /content/split_custom_data/images/val/Probne 2_1_63.jpg: 320x320 1 olive, 7.6ms
# image 546/572 /content/split_custom_data/images/val/Probne 2_1_64.jpg: 320x320 (no detections), 7.6ms
# image 547/572 /content/split_custom_data/images/val/Probne 2_1_65.jpg: 320x320 (no detections), 7.6ms
# image 548/572 /content/split_custom_data/images/val/Probne 2_1_66.jpg: 320x320 1 olive, 7.3ms
# image 549/572 /content/split_custom_data/images/val/Probne 2_1_67.jpg: 320x320 3 olives, 7.6ms
# image 550/572 /content/split_custom_data/images/val/Probne 2_1_68.jpg: 320x320 1 olive, 7.3ms
# image 551/572 /content/split_custom_data/images/val/Probne 2_1_69.jpg: 320x320 (no detections), 7.3ms
# image 552/572 /content/split_custom_data/images/val/Probne 2_1_7.jpg: 320x320 (no detections), 7.2ms
# image 553/572 /content/split_custom_data/images/val/Probne 2_1_70.jpg: 320x320 (no detections), 7.6ms
# image 554/572 /content/split_custom_data/images/val/Probne 2_1_71.jpg: 320x320 (no detections), 7.8ms
# image 555/572 /content/split_custom_data/images/val/Probne 2_1_72.jpg: 320x320 (no detections), 7.4ms
# image 556/572 /content/split_custom_data/images/val/Probne 2_1_73.jpg: 320x320 (no detections), 7.4ms
# image 557/572 /content/split_custom_data/images/val/Probne 2_1_74.jpg: 320x320 1 olive, 7.6ms
# image 558/572 /content/split_custom_data/images/val/Probne 2_1_75.jpg: 320x320 (no detections), 7.6ms
# image 559/572 /content/split_custom_data/images/val/Probne 2_1_76.jpg: 320x320 (no detections), 7.6ms
# image 560/572 /content/split_custom_data/images/val/Probne 2_1_77.jpg: 320x320 (no detections), 7.4ms
# image 561/572 /content/split_custom_data/images/val/Probne 2_1_78.jpg: 320x320 1 olive, 7.3ms
# image 562/572 /content/split_custom_data/images/val/Probne 2_1_79.jpg: 320x320 (no detections), 7.3ms
# image 563/572 /content/split_custom_data/images/val/Probne 2_1_8.jpg: 320x320 (no detections), 11.1ms
# image 564/572 /content/split_custom_data/images/val/Probne 2_1_80.jpg: 320x320 (no detections), 9.5ms
# image 565/572 /content/split_custom_data/images/val/Probne 2_1_81.jpg: 320x320 (no detections), 7.3ms
# image 566/572 /content/split_custom_data/images/val/Probne 2_1_82.jpg: 320x320 2 olives, 7.4ms
# image 567/572 /content/split_custom_data/images/val/Probne 2_1_83.jpg: 320x320 1 olive, 7.0ms
# image 568/572 /content/split_custom_data/images/val/Probne 2_1_84.jpg: 320x320 (no detections), 7.3ms
# image 569/572 /content/split_custom_data/images/val/Probne 2_1_85.jpg: 320x320 1 olive, 7.5ms
# image 570/572 /content/split_custom_data/images/val/Probne 2_1_86.jpg: 320x320 (no detections), 7.5ms
# image 571/572 /content/split_custom_data/images/val/Probne 2_1_87.jpg: 320x320 (no detections), 7.3ms
# image 572/572 /content/split_custom_data/images/val/Probne 2_1_9.jpg: 320x320 (no detections), 7.5ms
# Speed: 0.6ms preprocess, 8.8ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 320)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # VIsualisation

# %%
from IPython.display import Image, display
import glob

predictions = glob.glob('/content/runs/detect/predict/*.jpg')
for image_path in predictions[:10]:
    display(Image(filename=image_path, width=600))

# %% [markdown]
# # Télécharger le modèle

# %%
# Create "my_model" folder to store model weights and train results
# !mkdir /content/my_model
# !cp /content/runs/detect/train/weights/best.pt /content/my_model/my_model.pt
# !cp -r /content/runs/detect/train /content/my_model

# Zip into "my_model.zip"
# %cd my_model
# !zip /content/my_model.zip my_model.pt
# !zip -r /content/my_model.zip train
# %cd /content
# Out:
# /content/my_model
#   adding: my_model.pt (deflated 8%)
#   adding: train/ (stored 0%)
#   adding: train/confusion_matrix_normalized.png (deflated 33%)
#   adding: train/results.csv (deflated 59%)
#   adding: train/F1_curve.png (deflated 14%)
#   adding: train/args.yaml (deflated 52%)
#   adding: train/weights/ (stored 0%)
#   adding: train/weights/best.pt (deflated 8%)
#   adding: train/weights/last.pt (deflated 8%)
#   adding: train/results.png (deflated 7%)
#   adding: train/train_batch0.jpg (deflated 3%)
#   adding: train/train_batch1.jpg (deflated 3%)
#   adding: train/val_batch1_labels.jpg (deflated 9%)
#   adding: train/val_batch2_pred.jpg (deflated 9%)
#   adding: train/labels.jpg (deflated 23%)
#   adding: train/val_batch1_pred.jpg (deflated 9%)
#   adding: train/PR_curve.png (deflated 14%)
#   adding: train/R_curve.png (deflated 14%)
#   adding: train/train_batch2.jpg (deflated 4%)
#   adding: train/confusion_matrix.png (deflated 34%)
#   adding: train/val_batch2_labels.jpg (deflated 9%)
#   adding: train/labels_correlogram.jpg (deflated 36%)
#   adding: train/train_batch16081.jpg (deflated 4%)
#   adding: train/train_batch16080.jpg (deflated 5%)
#   adding: train/P_curve.png (deflated 15%)
#   adding: train/train_batch16082.jpg (deflated 3%)
#   adding: train/val_batch0_labels.jpg (deflated 8%)
#   adding: train/val_batch0_pred.jpg (deflated 8%)
# /content
