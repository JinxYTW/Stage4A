# %% [markdown]
# # Installation

# %%
# !pip install ultralytics --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.8/974.8 kB 24.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 110.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 85.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 53.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 91.7 MB/s eta 0:00:00

# %% [markdown]
# # Vérification avant de commencer

# %%
import ultralytics
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
ultralytics.checks()
# Out:
# Ultralytics 8.3.108 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.2/112.6 GB disk)

# %% [markdown]
# Visualisation des ressources et utilisation GPU

# %%
# !nvidia-smi
# Out:
# Tue Apr 15 13:34:45 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   49C    P8             12W /   70W |       2MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# Vérification disponibilité GPU

# %%
import torch
print("GPU disponible :", torch.cuda.is_available())
# Out:
# GPU disponible : True

# %% [markdown]
# # Préparation du dataset

# %%
# !unzip -q /content/data.zip -d /content/custom_data_raw

# %% [markdown]
# ## Organisation à avoir

# %% [markdown]
# ```
# custom_data/
# ├── images/
# │   ├── train/
# │   └── val/
# ├── labels/
# │   ├── train/
# │   └── val/

# %% [markdown]
# ## Réorganisation du dataset

# %%
import os
import shutil
from sklearn.model_selection import train_test_split

# Répertoire d'origine pour les images et annotations
raw_data_path_images = "/content/custom_data_raw/images"  # Images sont dans ce dossier
raw_data_path_labels = "/content/custom_data_raw/obj_train_data"  # Annotations dans ce dossier

# Obtenir toutes les images (jpg/png) présentes dans le dossier "images"
images = [f for f in os.listdir(raw_data_path_images) if f.endswith(('.jpg', '.png'))]

# Split train/val (80% train, 20% val)
train_imgs, val_imgs = train_test_split(images, test_size=0.2, random_state=42)

# Création des dossiers cible pour images et labels
base_path = "/content/custom_data"


os.makedirs(base_path + "/images/train", exist_ok=True)
os.makedirs(base_path + "/images/val", exist_ok=True)
os.makedirs(base_path + "/labels/train", exist_ok=True)
os.makedirs(base_path + "/labels/val", exist_ok=True)

def move_data(image_list, split):
    for img_name in image_list:
        # Déplacer l'image vers le bon dossier
        src_img = os.path.join(raw_data_path_images, img_name)
        dst_img = os.path.join(base_path, f"images/{split}", img_name)
        shutil.copy(src_img, dst_img)

        # Vérifier et déplacer l'annotation .txt correspondante
        txt_name = img_name.rsplit('.', 1)[0] + '.txt'
        txt_src = os.path.join(raw_data_path_labels, txt_name)
        txt_dst = os.path.join(base_path, f"labels/{split}", txt_name)

        if os.path.exists(txt_src):
            shutil.copy(txt_src, txt_dst)
        else:
            print(f"Pas d'annotation pour {img_name}")

# Appliquer le déplacement aux deux splits : train et val
move_data(train_imgs, "train")
move_data(val_imgs, "val")

# %% [markdown]
# # Split des images du dataset

# %%
import os
import cv2
import shutil

# === PARAMÈTRES ===
input_root = "/content/custom_data"
output_root = "/content/split_custom_data"

base_split_path = "/content/split_custom_data"

tile_size = 320
overlap = 0

splits = ["train", "val"]

def yolo_to_bbox(x_center, y_center, w, h, img_w, img_h):
    x1 = int((x_center - w / 2) * img_w)
    y1 = int((y_center - h / 2) * img_h)
    x2 = int((x_center + w / 2) * img_w)
    y2 = int((y_center + h / 2) * img_h)
    return x1, y1, x2, y2

def bbox_to_yolo(x1, y1, x2, y2, tile_w, tile_h):
    x_center = (x1 + x2) / 2 / tile_w
    y_center = (y1 + y2) / 2 / tile_h
    w = (x2 - x1) / tile_w
    h = (y2 - y1) / tile_h
    return x_center, y_center, w, h

# Boucle sur train et val
for split in splits:
    input_img_dir = os.path.join(input_root, f"images/{split}")
    input_lbl_dir = os.path.join(input_root, f"labels/{split}")
    output_img_dir = os.path.join(output_root, f"images/{split}")
    output_lbl_dir = os.path.join(output_root, f"labels/{split}")

    os.makedirs(output_img_dir, exist_ok=True)
    os.makedirs(output_lbl_dir, exist_ok=True)

    for filename in os.listdir(input_img_dir):
        if not filename.lower().endswith(('.jpg', '.png')):
            continue

        basename = os.path.splitext(filename)[0]
        img_path = os.path.join(input_img_dir, filename)
        label_path = os.path.join(input_lbl_dir, f"{basename}.txt")

        img = cv2.imread(img_path)
        img_h, img_w = img.shape[:2]

        annotations = []
        if os.path.exists(label_path):
            with open(label_path, "r") as f:
                for line in f.readlines():
                    parts = line.strip().split()
                    if len(parts) == 5:
                        cls, xc, yc, w, h = map(float, parts)
                        annotations.append((cls, *yolo_to_bbox(xc, yc, w, h, img_w, img_h)))

        step = tile_size - overlap
        tile_id = 0

        for y in range(0, img_h, step):
            for x in range(0, img_w, step):
                tile = img[y:y + tile_size, x:x + tile_size]
                tile_h, tile_w = tile.shape[:2]

                if tile_h < tile_size or tile_w < tile_size:
                    continue

                tile_filename = f"{basename}_{tile_id}.jpg"
                label_filename = f"{basename}_{tile_id}.txt"
                tile_id += 1

                cv2.imwrite(os.path.join(output_img_dir, tile_filename), tile)

                new_annots = []
                for cls, x1, y1, x2, y2 in annotations:
                    if x1 >= x + tile_size or x2 <= x or y1 >= y + tile_size or y2 <= y:
                        continue

                    bx1 = max(0, x1 - x)
                    by1 = max(0, y1 - y)
                    bx2 = min(tile_size, x2 - x)
                    by2 = min(tile_size, y2 - y)

                    if bx2 - bx1 < 5 or by2 - by1 < 5:
                        continue

                    x_c, y_c, w, h = bbox_to_yolo(bx1, by1, bx2, by2, tile_size, tile_size)
                    new_annots.append(f"{int(cls)} {x_c:.6f} {y_c:.6f} {w:.6f} {h:.6f}")

                with open(os.path.join(output_lbl_dir, label_filename), "w") as f:
                    f.write("\n".join(new_annots))

    print(f"✅ Split terminé pour '{split}' — {len(os.listdir(output_img_dir))} tuiles générées")
# Out:
# ✅ Split terminé pour 'train' — 2160 tuiles générées
# ✅ Split terminé pour 'val' — 552 tuiles générées

# %% [markdown]
# # Génération des YAML

# %% [markdown]
# Dynamique :

# %%
# Chemin vers le fichier obj.names exporté par CVAT (modifie si besoin)
obj_names_path = "/content/custom_data_raw/obj.names"

# Lire les noms de classes depuis obj.names
with open(obj_names_path, 'r') as f:
    class_names = [line.strip() for line in f if line.strip()]

# Générer le contenu du fichier YAML avec les augmentations de couleur
yaml_content = f"""
path: {base_split_path}
train: images/train
val: images/val
nc: {len(class_names)}
names: {class_names}
augment: True  # Activer l'augmentation des données
auto_augment: albumentations



# weights: [0.9, 0.1]  # Exemple de pondération si olive est trop présente
"""


# Écriture du fichier data.yaml
with open(f"{base_path}/data.yaml", "w") as f:
    f.write(yaml_content.strip())

with open(f"{base_split_path}/data.yaml", "w") as f:
    f.write(yaml_content.strip())

print(" Fichier data.yaml généré automatiquement :")
print(yaml_content)
# Out:
#  Fichier data.yaml généré automatiquement :
#
# path: /content/split_custom_data
# train: images/train
# val: images/val
# nc: 2
# names: ['olive', 'potential_olive']
# augment: True  # Activer l'augmentation des données
# auto_augment: albumentations
#
#
#
# # weights: [0.9, 0.1]  # Exemple de pondération si olive est trop présente

# %%
custom_train_cfg = """
# train_custom.yaml — Configuration d'entraînement pour YOLOv8

# Chemins
data: /content/split_custom_data/data.yaml
model: yolov8l.pt


# Entraînement
epochs: 50
batch: 8
imgsz: 320
device: 0

# Hyperparamètres généraux
optimizer: Adam
lr0: 0.001
lrf: 0.01




# Augmentations géométriques
degrees: 00.0
translate: 0.0
scale: 0.3
shear: 0.0
perspective: 0.0
flipud: 0.0
fliplr: 0.0

# Augmentations de couleur (adapté olives/feuillage)
hsv_h: 0.04
hsv_s: 0.6
hsv_v: 0.5

# Avancées
mosaic: 0.5
mixup: 0.1
copy_paste: 0.5

# auto_augment: randaugment
auto_augment: albumentations

"""

# Écriture du fichier YAML
with open("/content/custom_data/train_custom.yaml", "w") as f:
    f.write(custom_train_cfg.strip())

print("✅ Fichier train_custom.yaml généré.")

with open(f"/content/split_custom_data/train_custom.yaml", "w") as f:
    f.write(custom_train_cfg.strip())

print("✅ Fichier train_custom.yaml généré.")
# Out:
# ✅ Fichier train_custom.yaml généré.
# ✅ Fichier train_custom.yaml généré.

# %% [markdown]
# ## Vérification des labels et autres

# %%
import os
from collections import Counter

# Dictionnaire des classes : adapte-le si jamais tu changes l'ordre ou les noms
class_names = {
    '0': 'olive',
    '1': 'potential_olive'
}

def analyze_labels(labels_dir):
    label_counts = Counter()

    for split in ['train', 'val']:
        dir_path = os.path.join(labels_dir, split)
        for file in os.listdir(dir_path):
            if file.endswith('.txt'):
                with open(os.path.join(dir_path, file), 'r') as f:
                    for line in f:
                        if line.strip():
                            class_id = line.strip().split()[0]
                            label_counts[class_id] += 1

    print(" Résumé des classes dans les annotations :\n")
    for class_id, count in label_counts.items():
        class_name = class_names.get(class_id, " Inconnu")
        print(f"Classe {class_id} ({class_name}) → {count} objets")

    # Alerte pour les classes non attendues
    for cid in label_counts:
        if cid not in class_names:
            print(f"\n ID inattendu détecté : {cid}")

# Appel de la fonction
analyze_labels(f"{base_split_path}/labels")
# Out:
#  Résumé des classes dans les annotations :
#
# Classe 0 (olive) → 4729 objets
# Classe 1 (potential_olive) → 151 objets

# %% [markdown]
# # Train

# %% [markdown]
# - Changer le nombre d'epochs : Avec seulement 6 images et un grand déséquilibre, 10 epochs peuvent ne pas être suffisants. Essaie d'augmenter le nombre d'epochs (par exemple, à 50 ou 100) pour donner au modèle plus de temps pour apprendre.
#
# - Réduire le imgsz : La taille des images peut avoir un impact sur l'entraînement. Si les images sont petites (moins de détails), une taille de 320x320 ou 416x416 pourrait mieux fonctionner qu'une taille de 640x640, qui peut être plus difficile à traiter.

# %%
# !yolo task=detect mode=train cfg={base_split_path}/train_custom.yaml
# Out:
# Overriding /usr/local/lib/python3.11/dist-packages/ultralytics/cfg/default.yaml with /content/split_custom_data/train_custom.yaml
# WARNING ⚠️ 'mode' argument is missing. Valid modes are frozenset({'predict', 'export', 'track', 'train', 'val', 'benchmark'}). Using default 'mode=train'.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8l.pt to 'yolov8l.pt'...
# 100% 83.7M/83.7M [00:00<00:00, 289MB/s]
# Ultralytics 8.3.108 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: task=detect, mode=train, model=yolov8l.pt, data=/content/split_custom_data/data.yaml, epochs=50, time=None, patience=100, batch=8, imgsz=320, save=True, save_period=-1, cache=False, device=0, workers=8, project=None, name=train2, exist_ok=False, pretrained=True, optimizer=Adam, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.001, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.04, hsv_s=0.6, hsv_v=0.5, degrees=0.0, translate=0.0, scale=0.3, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.0, bgr=0.0, mosaic=0.5, mixup=0.1, copy_paste=0.5, copy_paste_mode=flip, auto_augment=albumentations, erasing=0.4, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train2
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744724564.809225    5091 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744724564.814519    5091 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  3    279808  ultralytics.nn.modules.block.C2f             [128, 128, 3, True]
#   3                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   4                  -1  6   2101248  ultralytics.nn.modules.block.C2f             [256, 256, 6, True]
#   5                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   6                  -1  6   8396800  ultralytics.nn.modules.block.C2f             [512, 512, 6, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  3   4461568  ultralytics.nn.modules.block.C2f             [512, 512, 3, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  3   4723712  ultralytics.nn.modules.block.C2f             [1024, 512, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  3   1247744  ultralytics.nn.modules.block.C2f             [768, 256, 3]
#  16                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  3   4592640  ultralytics.nn.modules.block.C2f             [768, 512, 3]
#  19                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  3   4723712  ultralytics.nn.modules.block.C2f             [1024, 512, 3]
#  22        [15, 18, 21]  1   5584342  ultralytics.nn.modules.head.Detect           [2, [256, 512, 512]]
# Model summary: 209 layers, 43,631,382 parameters, 43,631,366 gradients, 165.4 GFLOPs
#
# Transferred 589/595 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train2', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Scanning /content/split_custom_data/labels/train.cache... 2160 images, 1208 backgrounds, 0 corrupt: 100% 2160/2160 [00:00<?, ?it/s]
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/split_custom_data/labels/val.cache... 552 images, 256 backgrounds, 0 corrupt: 100% 552/552 [00:00<?, ?it/s]
# Plotting labels to runs/detect/train2/labels.jpg...
# optimizer: Adam(lr=0.001, momentum=0.937) with parameter groups 97 weight(decay=0.0), 104 weight(decay=0.0005), 103 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 320 train, 320 val
# Using 2 dataloader workers
# Logging results to runs/detect/train2
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      2.33G      1.767      2.156      1.305          9        320: 100% 270/270 [00:44<00:00,  6.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 35/35 [00:04<00:00,  7.73it/s]
#                    all        552       1163      0.781      0.214      0.235      0.131
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      2.59G      1.881      1.958      1.347          7        320: 100% 270/270 [00:41<00:00,  6.56it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 35/35 [00:04<00:00,  7.48it/s]
#                    all        552       1163      0.753      0.167      0.169     0.0915
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      2.86G      1.909      1.992      1.376         20        320: 100% 270/270 [00:40<00:00,  6.63it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 35/35 [00:04<00:00,  8.21it/s]
#                    all        552       1163      0.795       0.23       0.25      0.133
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      2.86G       1.83      1.937      1.326         24        320: 100% 270/270 [00:39<00:00,  6.77it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 35/35 [00:04<00:00,  8.58it/s]
#                    all        552       1163      0.744      0.224      0.219       0.13
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      2.86G      1.832      1.861       1.32         31        320: 100% 270/270 [00:40<00:00,  6.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 35/35 [00:04<00:00,  8.52it/s]
#                    all        552       1163      0.825      0.241      0.273      0.158
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      2.86G      1.766      1.902      1.292          9        320: 100% 270/270 [00:40<00:00,  6.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 35/35 [00:04<00:00,  7.81it/s]
#                    all        552       1163      0.822      0.245      0.279      0.165
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      2.86G      1.693      1.664      1.263         25        320: 100% 270/270 [00:40<00:00,  6.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 35/35 [00:04<00:00,  8.57it/s]
#                    all        552       1163       0.83      0.255      0.303      0.189
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      2.86G       1.64      1.619      1.232         14        320: 100% 270/270 [00:40<00:00,  6.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 35/35 [00:04<00:00,  8.37it/s]
#                    all        552       1163      0.846      0.248      0.295       0.18
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      2.86G      1.564      1.593      1.218          4        320: 100% 270/270 [00:39<00:00,  6.81it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 35/35 [00:04<00:00,  7.61it/s]
#                    all        552       1163      0.864       0.25        0.3      0.187
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      2.86G      1.578      1.607      1.202         14        320: 100% 270/270 [00:39<00:00,  6.78it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 35/35 [00:04<00:00,  7.73it/s]
#                    all        552       1163      0.882      0.255      0.315      0.195
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50         3G       1.57      1.595      1.196         13        320: 100% 270/270 [00:40<00:00,  6.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 35/35 [00:04<00:00,  8.61it/s]
#                    all        552       1163      0.852      0.269      0.313      0.191
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50         3G      1.542      1.525      1.202         24        320: 100% 270/270 [00:39<00:00,  6.78it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 35/35 [00:04<00:00,  8.59it/s]
#                    all        552       1163      0.854      0.285      0.321      0.199
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50         3G       1.55      1.492      1.194          8        320: 100% 270/270 [00:39<00:00,  6.82it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 35/35 [00:04<00:00,  8.61it/s]
#                    all        552       1163      0.867      0.259      0.316      0.201
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50         3G      1.513      1.464      1.183         14        320: 100% 270/270 [00:39<00:00,  6.77it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 35/35 [00:04<00:00,  8.56it/s]
#                    all        552       1163      0.872      0.269      0.319        0.2
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50
ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to runs/detect/train2
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
#yolo task=detect mode=train model=yolo11n.pt data={base_path}/data.yaml hyp={base_path}/hyp.yaml epochs=100 imgsz=640 device=0

# %%
import glob
from IPython.display import Image, display

# %%
Image(filename='runs/detect/train2/confusion_matrix.png', width=600)

# %%
Image(filename='runs/detect/train2/results.png', width=600)

# %% [markdown]
# # Validation

# %%
from ultralytics import YOLO

# Charger le modèle entraîné
model = YOLO("runs/detect/train2/weights/best.pt")

# Évaluer sur le dataset de validation
metrics = model.val(data="/content/split_custom_data/data.yaml", split="val", verbose=False)

# Accès aux métriques par classe
names = model.names  # dict {class_id: name}
precision_per_class = metrics.box.p  # Précision par classe
recall_per_class = metrics.box.r  # Rappel par classe
map50_per_class = metrics.box.ap50  # mAP à IoU de 0.5 par classe
map_per_class = metrics.box.ap  # mAP à IoU de 0.5-0.95 par classe

# Exemple : récupérer les métriques de la classe "olive"
class_name = "olive"
class_id = list(names.values()).index(class_name)

print(f"Métriques pour la classe '{class_name}':")
print(f" - Précision : {precision_per_class[class_id]:.3f}")
print(f" - Rappel    : {recall_per_class[class_id]:.3f}")
print(f" - mAP@50    : {map50_per_class[class_id]:.3f}")
print(f" - mAP@50-95 : {map_per_class[class_id]:.3f}")
# Out:
# Ultralytics 8.3.108 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 112 layers, 43,608,150 parameters, 0 gradients, 164.8 GFLOPs
# val: Scanning /content/split_custom_data/labels/val.cache... 552 images, 256 backgrounds, 0 corrupt: 100%|██████████| 552/552 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 35/35 [00:08<00:00,  4.35it/s]
#                    all        552       1163      0.364      0.358      0.365      0.242
# Speed: 0.4ms preprocess, 10.9ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to runs/detect/val4
# Métriques pour la classe 'olive':
#  - Précision : 0.702
#  - Rappel    : 0.675
#  - mAP@50    : 0.722
#  - mAP@50-95 : 0.479

# %% [markdown]
# En modifiant conf

# %%
from ultralytics import YOLO
from pathlib import Path
import cv2
import os
from ultralytics.utils.metrics import bbox_iou

# 🔧 Paramètres
model_path = "runs/detect/train2/weights/best.pt"
data_path = "/content/split_custom_data/data.yaml"
val_images_dir = "/content/split_custom_data/images/val"
conf_threshold = 0.05  # 🔁 MODIFIE ici le seuil de confiance
target_class = "olive"
iou_threshold = 0.5  # pour comptage TP/FN

# 📦 Charger modèle + noms des classes
model = YOLO(model_path)
names = model.names
target_id = list(names.values()).index(target_class)

# 📂 Liste des fichiers image de validation
image_paths = list(Path(val_images_dir).rglob("*.jpg")) + list(Path(val_images_dir).rglob("*.png"))

# 🔢 Compteurs
TP, FP, FN = 0, 0, 0

# 🔍 Parcourir les images
import torch

# 🔍 Parcourir les images
for img_path in image_paths:
    results = model.predict(source=str(img_path), conf=conf_threshold, iou=iou_threshold, verbose=False)[0]

    # Prédictions pour la classe cible
    preds = [b for b in results.boxes.data.cpu().numpy() if int(b[5]) == target_id]
    pred_boxes = [b[:4] for b in preds]  # x1, y1, x2, y2

    # Ground truth : via les annotations val
    label_path = str(img_path).replace("/images/", "/labels/").rsplit(".", 1)[0] + ".txt"
    gt_boxes = []
    if os.path.exists(label_path):
        with open(label_path, "r") as f:
            for line in f:
                cls, x, y, w, h = map(float, line.strip().split())
                if int(cls) == target_id:
                    # YOLO format -> (x1, y1, x2, y2)
                    img = cv2.imread(str(img_path))
                    H, W = img.shape[:2]
                    cx, cy, bw, bh = x * W, y * H, w * W, h * H
                    x1 = cx - bw / 2
                    y1 = cy - bh / 2
                    x2 = cx + bw / 2
                    y2 = cy + bh / 2
                    gt_boxes.append([x1, y1, x2, y2])

    # 🧠 Matching GT ↔ prédictions
    matched_gt = set()
    for pred_box in pred_boxes:
        matched = False
        for i, gt_box in enumerate(gt_boxes):
            # Convertir en tensor avant de calculer l'IoU
            pred_box_tensor = torch.tensor(pred_box).unsqueeze(0)  # Convertir en tensor
            gt_box_tensor = torch.tensor(gt_box).unsqueeze(0)  # Convertir en tensor
            iou = bbox_iou(pred_box_tensor, gt_box_tensor)[0]  # Calcul de l'IoU
            if iou > iou_threshold and i not in matched_gt:
                TP += 1
                matched_gt.add(i)
                matched = True
                break
        if not matched:
            FP += 1
    FN += len(gt_boxes) - len(matched_gt)

# 📊 Calcul des métriques
precision = TP / (TP + FP) if (TP + FP) > 0 else 0
recall = TP / (TP + FN) if (TP + FN) > 0 else 0

print(f"\n🔎 Résultats pour la classe '{target_class}' (seuil conf = {conf_threshold}):")
print(f" - Vrais positifs (TP) : {TP}")
print(f" - Faux positifs (FP)  : {FP}")
print(f" - Faux négatifs (FN)  : {FN}")
print(f" - Précision           : {precision:.3f}")
print(f" - Rappel              : {recall:.3f}")
# Out:
# 🔎 Résultats pour la classe 'olive' (seuil conf = 0.05):
#  - Vrais positifs (TP) : 878
#  - Faux positifs (FP)  : 544
#  - Faux négatifs (FN)  : 261
#  - Précision           : 0.617
#  - Rappel              : 0.771

# %% [markdown]
# # Predict

# %% [markdown]
# - Vérifie les prédictions avec conf=0.5 ou plus bas : Parfois, si le modèle est trop conservateur, il ne détecte rien parce qu'il exige une très forte confiance. Essaie de réduire le seuil de confiance lors de la prédiction.

# %%
# !yolo task=detect mode=predict model=runs/detect/train2/weights/best.pt source={base_split_path}/images/val conf=0.05 save=True device=0
# Out:
# Ultralytics 8.3.108 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 112 layers, 43,608,150 parameters, 0 gradients, 164.8 GFLOPs
#
# image 1/552 /content/split_custom_data/images/val/20221108_112521_0.jpg: 320x320 (no detections), 28.5ms
# image 2/552 /content/split_custom_data/images/val/20221108_112521_1.jpg: 320x320 (no detections), 28.6ms
# image 3/552 /content/split_custom_data/images/val/20221108_112521_10.jpg: 320x320 (no detections), 28.6ms
# image 4/552 /content/split_custom_data/images/val/20221108_112521_11.jpg: 320x320 (no detections), 23.5ms
# image 5/552 /content/split_custom_data/images/val/20221108_112521_12.jpg: 320x320 (no detections), 20.2ms
# image 6/552 /content/split_custom_data/images/val/20221108_112521_13.jpg: 320x320 (no detections), 20.2ms
# image 7/552 /content/split_custom_data/images/val/20221108_112521_14.jpg: 320x320 (no detections), 20.2ms
# image 8/552 /content/split_custom_data/images/val/20221108_112521_15.jpg: 320x320 1 olive, 20.2ms
# image 9/552 /content/split_custom_data/images/val/20221108_112521_16.jpg: 320x320 1 olive, 16.6ms
# image 10/552 /content/split_custom_data/images/val/20221108_112521_17.jpg: 320x320 3 olives, 16.5ms
# image 11/552 /content/split_custom_data/images/val/20221108_112521_18.jpg: 320x320 (no detections), 16.5ms
# image 321/552 /content/split_custom_data/images/val/B2.3_12.jpg: 320x320 1 olive, 15.4ms
# image 322/552 /content/split_custom_data/images/val/B2.3_13.jpg: 320x320 (no detections), 15.2ms
# image 323/552 /content/split_custom_data/images/val/B2.3_14.jpg: 320x320 (no detections), 15.2ms
# image 324/552 /content/split_custom_data/images/val/B2.3_15.jpg: 320x320 (no detections), 15.6ms
# image 325/552 /content/split_custom_data/images/val/B2.3_16.jpg: 320x320 (no detections), 15.4ms
# image 326/552 /content/split_custom_data/images/val/B2.3_17.jpg: 320x320 1 olive, 16.2ms
# image 327/552 /content/split_custom_data/images/val/B2.3_18.jpg: 320x320 (no detections), 16.5ms
# image 328/552 /content/split_custom_data/images/val/B2.3_19.jpg: 320x320 7 olives, 1 potential_olive, 15.1ms
# image 329/552 /content/split_custom_data/images/val/B2.3_2.jpg: 320x320 (no detections), 14.3ms
# image 330/552 /content/split_custom_data/images/val/B2.3_20.jpg: 320x320 (no detections), 15.4ms
# image 331/552 /content/split_custom_data/images/val/B2.3_21.jpg: 320x320 1 olive, 16.0ms
# image 332/552 /content/split_custom_data/images/val/B2.3_22.jpg: 320x320 1 olive, 15.7ms
# image 333/552 /content/split_custom_data/images/val/B2.3_23.jpg: 320x320 6 olives, 15.2ms
# image 334/552 /content/split_custom_data/images/val/B2.3_24.jpg: 320x320 2 olives, 15.6ms
# image 335/552 /content/split_custom_data/images/val/B2.3_25.jpg: 320x320 2 olives, 14.8ms
# image 336/552 /content/split_custom_data/images/val/B2.3_26.jpg: 320x320 1 olive, 14.4ms
# image 337/552 /content/split_custom_data/images/val/B2.3_27.jpg: 320x320 (no detections), 16.3ms
# image 338/552 /content/split_custom_data/images/val/B2.3_28.jpg: 320x320 (no detections), 15.0ms
# image 339/552 /content/split_custom_data/images/val/B2.3_29.jpg: 320x320 (no detections), 14.3ms
# image 340/552 /content/split_custom_data/images/val/B2.3_3.jpg: 320x320 (no detections), 16.9ms
# image 341/552 /content/split_custom_data/images/val/B2.3_30.jpg: 320x320 (no detections), 15.4ms
# image 342/552 /content/split_custom_data/images/val/B2.3_31.jpg: 320x320 (no detections), 15.2ms
# image 343/552 /content/split_custom_data/images/val/B2.3_32.jpg: 320x320 1 olive, 15.4ms
# image 344/552 /content/split_custom_data/images/val/B2.3_33.jpg: 320x320 (no detections), 15.4ms
# image 345/552 /content/split_custom_data/images/val/B2.3_34.jpg: 320x320 (no detections), 15.2ms
# image 346/552 /content/split_custom_data/images/val/B2.3_35.jpg: 320x320 (no detections), 18.3ms
# image 347/552 /content/split_custom_data/images/val/B2.3_36.jpg: 320x320 (no detections), 14.9ms
# image 348/552 /content/split_custom_data/images/val/B2.3_37.jpg: 320x320 (no detections), 14.9ms
# image 349/552 /content/split_custom_data/images/val/B2.3_38.jpg: 320x320 (no detections), 14.8ms
# image 350/552 /content/split_custom_data/images/val/B2.3_39.jpg: 320x320 (no detections), 15.1ms
# image 351/552 /content/split_custom_data/images/val/B2.3_4.jpg: 320x320 (no detections), 15.4ms
# image 352/552 /content/split_custom_data/images/val/B2.3_40.jpg: 320x320 1 olive, 15.6ms
# image 353/552 /content/split_custom_data/images/val/B2.3_41.jpg: 320x320 (no detections), 15.6ms
# image 354/552 /content/split_custom_data/images/val/B2.3_42.jpg: 320x320 (no detections), 15.4ms
# image 355/552 /content/split_custom_data/images/val/B2.3_43.jpg: 320x320 1 olive, 15.4ms
# image 356/552 /content/split_custom_data/images/val/B2.3_44.jpg: 320x320 1 olive, 16.0ms
# image 357/552 /content/split_custom_data/images/val/B2.3_45.jpg: 320x320 (no detections), 15.7ms
# image 358/552 /content/split_custom_data/images/val/B2.3_46.jpg: 320x320 (no detections), 15.4ms
# image 359/552 /content/split_custom_data/images/val/B2.3_47.jpg: 320x320 (no detections), 15.2ms
# image 360/552 /content/split_custom_data/images/val/B2.3_48.jpg: 320x320 (no detections), 15.1ms
# image 361/552 /content/split_custom_data/images/val/B2.3_49.jpg: 320x320 1 olive, 15.6ms
# image 362/552 /content/split_custom_data/images/val/B2.3_5.jpg: 320x320 (no detections), 16.0ms
# image 363/552 /content/split_custom_data/images/val/B2.3_50.jpg: 320x320 (no detections), 16.0ms
# image 364/552 /content/split_custom_data/images/val/B2.3_51.jpg: 320x320 (no detections), 16.0ms
# image 365/552 /content/split_custom_data/images/val/B2.3_52.jpg: 320x320 (no detections), 15.7ms
# image 366/552 /content/split_custom_data/images/val/B2.3_53.jpg: 320x320 (no detections), 15.7ms
# image 367/552 /content/split_custom_data/images/val/B2.3_54.jpg: 320x320 (no detections), 15.2ms
# image 368/552 /content/split_custom_data/images/val/B2.3_55.jpg: 320x320 (no detections), 14.8ms
# image 369/552 /content/split_custom_data/images/val/B2.3_56.jpg: 320x320 (no detections), 14.4ms
# image 370/552 /content/split_custom_data/images/val/B2.3_57.jpg: 320x320 (no detections), 14.5ms
# image 371/552 /content/split_custom_data/images/val/B2.3_58.jpg: 320x320 (no detections), 14.7ms
# image 372/552 /content/split_custom_data/images/val/B2.3_59.jpg: 320x320 (no detections), 14.3ms
# image 373/552 /content/split_custom_data/images/val/B2.3_6.jpg: 320x320 (no detections), 14.8ms
# image 374/552 /content/split_custom_data/images/val/B2.3_7.jpg: 320x320 (no detections), 14.9ms
# image 375/552 /content/split_custom_data/images/val/B2.3_8.jpg: 320x320 2 olives, 15.4ms
# image 376/552 /content/split_custom_data/images/val/B2.3_9.jpg: 320x320 1 olive, 14.8ms
# image 377/552 /content/split_custom_data/images/val/B2.7_0.jpg: 320x320 1 olive, 5 potential_olives, 14.8ms
# image 378/552 /content/split_custom_data/images/val/B2.7_1.jpg: 320x320 (no detections), 14.6ms
# image 379/552 /content/split_custom_data/images/val/B2.7_10.jpg: 320x320 2 olives, 14.3ms
# image 380/552 /content/split_custom_data/images/val/B2.7_11.jpg: 320x320 2 olives, 14.6ms
# image 381/552 /content/split_custom_data/images/val/B2.7_12.jpg: 320x320 (no detections), 25.0ms
# image 382/552 /content/split_custom_data/images/val/B2.7_13.jpg: 320x320 (no detections), 18.4ms
# image 383/552 /content/split_custom_data/images/val/B2.7_14.jpg: 320x320 1 olive, 13.6ms
# image 476/552 /content/split_custom_data/images/val/Probne 2_1_19.jpg: 320x320 (no detections), 15.4ms
# image 477/552 /content/split_custom_data/images/val/Probne 2_1_2.jpg: 320x320 (no detections), 15.4ms
# image 478/552 /content/split_custom_data/images/val/Probne 2_1_20.jpg: 320x320 (no detections), 15.6ms
# image 479/552 /content/split_custom_data/images/val/Probne 2_1_21.jpg: 320x320 3 olives, 16.0ms
# image 480/552 /content/split_custom_data/images/val/Probne 2_1_22.jpg: 320x320 5 olives, 16.0ms
# image 481/552 /content/split_custom_data/images/val/Probne 2_1_23.jpg: 320x320 3 olives, 15.7ms
# image 482/552 /content/split_custom_data/images/val/Probne 2_1_24.jpg: 320x320 3 olives, 15.6ms
# image 483/552 /content/split_custom_data/images/val/Probne 2_1_25.jpg: 320x320 6 olives, 15.4ms
# image 484/552 /content/split_custom_data/images/val/Probne 2_1_26.jpg: 320x320 18 olives, 14.9ms
# image 485/552 /content/split_custom_data/images/val/Probne 2_1_27.jpg: 320x320 (no detections), 14.8ms
# image 486/552 /content/split_custom_data/images/val/Probne 2_1_28.jpg: 320x320 7 olives, 14.8ms
# image 487/552 /content/split_custom_data/images/val/Probne 2_1_29.jpg: 320x320 11 olives, 14.5ms
# image 488/552 /content/split_custom_data/images/val/Probne 2_1_3.jpg: 320x320 (no detections), 14.1ms
# image 489/552 /content/split_custom_data/images/val/Probne 2_1_30.jpg: 320x320 17 olives, 14.0ms
# image 490/552 /content/split_custom_data/images/val/Probne 2_1_31.jpg: 320x320 22 olives, 14.0ms
# image 491/552 /content/split_custom_data/images/val/Probne 2_1_32.jpg: 320x320 (no detections), 13.7ms
# image 492/552 /content/split_custom_data/images/val/Probne 2_1_33.jpg: 320x320 3 olives, 13.9ms
# image 493/552 /content/split_custom_data/images/val/Probne 2_1_34.jpg: 320x320 7 olives, 1 potential_olive, 14.9ms
# image 494/552 /content/split_custom_data/images/val/Probne 2_1_35.jpg: 320x320 11 olives, 15.3ms
# image 495/552 /content/split_custom_data/images/val/Probne 2_1_36.jpg: 320x320 3 olives, 15.3ms
# image 496/552 /content/split_custom_data/images/val/Probne 2_1_37.jpg: 320x320 11 olives, 15.1ms
# image 497/552 /content/split_custom_data/images/val/Probne 2_1_38.jpg: 320x320 12 olives, 14.9ms
# image 498/552 /content/split_custom_data/images/val/Probne 2_1_39.jpg: 320x320 15 olives, 14.8ms
# image 499/552 /content/split_custom_data/images/val/Probne 2_1_4.jpg: 320x320 1 olive, 14.6ms
# image 500/552 /content/split_custom_data/images/val/Probne 2_1_40.jpg: 320x320 (no detections), 14.5ms
# image 501/552 /content/split_custom_data/images/val/Probne 2_1_41.jpg: 320x320 2 olives, 14.8ms
# image 502/552 /content/split_custom_data/images/val/Probne 2_1_42.jpg: 320x320 8 olives, 15.4ms
# image 503/552 /content/split_custom_data/images/val/Probne 2_1_43.jpg: 320x320 12 olives, 16.4ms
# image 504/552 /content/split_custom_data/images/val/Probne 2_1_44.jpg: 320x320 10 olives, 14.6ms
# image 505/552 /content/split_custom_data/images/val/Probne 2_1_45.jpg: 320x320 18 olives, 14.3ms
# image 506/552 /content/split_custom_data/images/val/Probne 2_1_46.jpg: 320x320 4 olives, 14.2ms
# image 507/552 /content/split_custom_data/images/val/Probne 2_1_47.jpg: 320x320 6 olives, 14.1ms
# image 508/552 /content/split_custom_data/images/val/Probne 2_1_48.jpg: 320x320 (no detections), 14.2ms
# image 509/552 /content/split_custom_data/images/val/Probne 2_1_49.jpg: 320x320 3 olives, 14.5ms
# image 510/552 /content/split_custom_data/images/val/Probne 2_1_5.jpg: 320x320 (no detections), 15.1ms
# image 511/552 /content/split_custom_data/images/val/Probne 2_1_50.jpg: 320x320 6 olives, 15.2ms
# image 512/552 /content/split_custom_data/images/val/Probne 2_1_51.jpg: 320x320 7 olives, 15.4ms
# image 513/552 /content/split_custom_data/images/val/Probne 2_1_52.jpg: 320x320 12 olives, 1 potential_olive, 15.6ms
# image 514/552 /content/split_custom_data/images/val/Probne 2_1_53.jpg: 320x320 10 olives, 1 potential_olive, 15.6ms
# image 515/552 /content/split_custom_data/images/val/Probne 2_1_54.jpg: 320x320 3 olives, 15.1ms
# image 516/552 /content/split_custom_data/images/val/Probne 2_1_55.jpg: 320x320 9 olives, 14.9ms
# image 517/552 /content/split_custom_data/images/val/Probne 2_1_56.jpg: 320x320 (no detections), 14.8ms
# image 518/552 /content/split_custom_data/images/val/Probne 2_1_57.jpg: 320x320 2 olives, 14.6ms
# image 519/552 /content/split_custom_data/images/val/Probne 2_1_58.jpg: 320x320 9 olives, 1 potential_olive, 15.2ms
# image 520/552 /content/split_custom_data/images/val/Probne 2_1_59.jpg: 320x320 12 olives, 1 potential_olive, 15.6ms
# image 521/552 /content/split_custom_data/images/val/Probne 2_1_6.jpg: 320x320 (no detections), 15.3ms
# image 522/552 /content/split_custom_data/images/val/Probne 2_1_60.jpg: 320x320 11 olives, 14.9ms
# image 523/552 /content/split_custom_data/images/val/Probne 2_1_61.jpg: 320x320 4 olives, 14.7ms
# image 524/552 /content/split_custom_data/images/val/Probne 2_1_62.jpg: 320x320 6 olives, 14.4ms
# image 525/552 /content/split_custom_data/images/val/Probne 2_1_63.jpg: 320x320 5 olives, 14.8ms
# image 526/552 /content/split_custom_data/images/val/Probne 2_1_64.jpg: 320x320 1 olive, 14.8ms
# image 527/552 /content/split_custom_data/images/val/Probne 2_1_65.jpg: 320x320 6 olives, 15.2ms
# image 528/552 /content/split_custom_data/images/val/Probne 2_1_66.jpg: 320x320 8 olives, 1 potential_olive, 15.6ms
# image 529/552 /content/split_custom_data/images/val/Probne 2_1_67.jpg: 320x320 24 olives, 15.2ms
# image 530/552 /content/split_custom_data/images/val/Probne 2_1_68.jpg: 320x320 8 olives, 15.1ms
# image 531/552 /content/split_custom_data/images/val/Probne 2_1_69.jpg: 320x320 2 olives, 14.9ms
# image 532/552 /content/split_custom_data/images/val/Probne 2_1_7.jpg: 320x320 (no detections), 15.1ms
# image 533/552 /content/split_custom_data/images/val/Probne 2_1_70.jpg: 320x320 3 olives, 15.1ms
# image 534/552 /content/split_custom_data/images/val/Probne 2_1_71.jpg: 320x320 5 olives, 15.6ms
# image 535/552 /content/split_custom_data/images/val/Probne 2_1_72.jpg: 320x320 (no detections), 16.0ms
# image 536/552 /content/split_custom_data/images/val/Probne 2_1_73.jpg: 320x320 2 olives, 5 potential_olives, 15.7ms
# image 537/552 /content/split_custom_data/images/val/Probne 2_1_74.jpg: 320x320 8 olives, 2 potential_olives, 15.7ms
# image 538/552 /content/split_custom_data/images/val/Probne 2_1_75.jpg: 320x320 13 olives, 1 potential_olive, 15.6ms
# image 539/552 /content/split_custom_data/images/val/Probne 2_1_76.jpg: 320x320 14 olives, 3 potential_olives, 15.3ms
# image 540/552 /content/split_custom_data/images/val/Probne 2_1_77.jpg: 320x320 10 olives, 1 potential_olive, 15.0ms
# image 541/552 /content/split_custom_data/images/val/Probne 2_1_78.jpg: 320x320 3 olives, 14.8ms
# image 542/552 /content/split_custom_data/images/val/Probne 2_1_79.jpg: 320x320 5 olives, 14.6ms
# image 543/552 /content/split_custom_data/images/val/Probne 2_1_8.jpg: 320x320 (no detections), 14.4ms
# image 544/552 /content/split_custom_data/images/val/Probne 2_1_80.jpg: 320x320 1 olive, 14.6ms
# image 545/552 /content/split_custom_data/images/val/Probne 2_1_81.jpg: 320x320 6 olives, 2 potential_olives, 15.4ms
# image 546/552 /content/split_custom_data/images/val/Probne 2_1_82.jpg: 320x320 5 olives, 1 potential_olive, 15.7ms
# image 547/552 /content/split_custom_data/images/val/Probne 2_1_83.jpg: 320x320 9 olives, 15.6ms
# image 548/552 /content/split_custom_data/images/val/Probne 2_1_84.jpg: 320x320 5 olives, 15.6ms
# image 549/552 /content/split_custom_data/images/val/Probne 2_1_85.jpg: 320x320 10 olives, 2 potential_olives, 15.6ms
# image 550/552 /content/split_custom_data/images/val/Probne 2_1_86.jpg: 320x320 4 olives, 15.6ms
# image 551/552 /content/split_custom_data/images/val/Probne 2_1_87.jpg: 320x320 7 olives, 15.1ms
# image 552/552 /content/split_custom_data/images/val/Probne 2_1_9.jpg: 320x320 1 olive, 1 potential_olive, 15.2ms
# Speed: 0.6ms preprocess, 15.3ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 320)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # VIsualisation

# %%
from IPython.display import Image, display
import glob

predictions = glob.glob('/content/runs/detect/predict/*.jpg')
for image_path in predictions[:10]:
    display(Image(filename=image_path, width=600))

# %% [markdown]
# # Télécharger le modèle

# %%
# Create "my_model" folder to store model weights and train results
# !mkdir /content/my_model
# !cp /content/runs/detect/train/weights/best.pt /content/my_model/my_model.pt
# !cp -r /content/runs/detect/train /content/my_model

# Zip into "my_model.zip"
# %cd my_model
# !zip /content/my_model.zip my_model.pt
# !zip -r /content/my_model.zip train
# %cd /content
# Out:
# /content/my_model
#   adding: my_model.pt (deflated 41%)
#   adding: train/ (stored 0%)
#   adding: train/train_batch0.jpg (deflated 6%)
#   adding: train/train_batch1.jpg (deflated 3%)
#   adding: train/labels_correlogram.jpg (deflated 40%)
#   adding: train/weights/ (stored 0%)
#   adding: train/weights/best.pt (deflated 41%)
#   adding: train/weights/last.pt (deflated 42%)
#   adding: train/args.yaml (deflated 52%)
#   adding: train/results.csv (deflated 50%)
#   adding: train/events.out.tfevents.1744724389.b2d92bbad243.4288.0 (deflated 94%)
#   adding: train/train_batch2.jpg (deflated 2%)
#   adding: train/labels.jpg (deflated 24%)
# /content
