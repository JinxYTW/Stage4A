# %% [markdown]
# # Installation

# %%
# !pip install ultralytics --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 34.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 37.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 31.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 105.1 MB/s eta 0:00:00

# %% [markdown]
# # Vérification avant de commencer

# %%
import ultralytics
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
ultralytics.checks()
# Out:
# Ultralytics 8.3.129 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.4/112.6 GB disk)

# %% [markdown]
# Visualisation des ressources et utilisation GPU

# %%
# !nvidia-smi
# Out:
# Fri May  9 10:25:22 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   32C    P8              9W /   70W |       2MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# Vérification disponibilité GPU

# %%
import torch
print("GPU disponible :", torch.cuda.is_available())
# Out:
# GPU disponible : True

# %% [markdown]
# # Préparation du dataset

# %%
# !unzip -q /content/data.zip -d /content/custom_data_raw

# %% [markdown]
# ## Organisation à avoir

# %% [markdown]
# ```
# custom_data/
# ├── images/
# │   ├── train/
# │   └── val/
# ├── labels/
# │   ├── train/
# │   └── val/

# %% [markdown]
# ## Réorganisation du dataset

# %%
import os
import shutil
from sklearn.model_selection import train_test_split

# Répertoire d'origine pour les images et annotations
raw_data_path_images = "/content/custom_data_raw/images"  # Images sont dans ce dossier
raw_data_path_labels = "/content/custom_data_raw/obj_train_data"  # Annotations dans ce dossier

# Obtenir toutes les images (jpg/png) présentes dans le dossier "images"
images = [f for f in os.listdir(raw_data_path_images) if f.endswith(('.jpg', '.png'))]

# Split train/val (80% train, 20% val)
train_imgs, val_imgs = train_test_split(images, test_size=0.2, random_state=42)

# Création des dossiers cible pour images et labels
base_path = "/content/custom_data"


os.makedirs(base_path + "/images/train", exist_ok=True)
os.makedirs(base_path + "/images/val", exist_ok=True)
os.makedirs(base_path + "/labels/train", exist_ok=True)
os.makedirs(base_path + "/labels/val", exist_ok=True)

def move_data(image_list, split):
    for img_name in image_list:
        # Déplacer l'image vers le bon dossier
        src_img = os.path.join(raw_data_path_images, img_name)
        dst_img = os.path.join(base_path, f"images/{split}", img_name)
        shutil.copy(src_img, dst_img)

        # Vérifier et déplacer l'annotation .txt correspondante
        txt_name = img_name.rsplit('.', 1)[0] + '.txt'
        txt_src = os.path.join(raw_data_path_labels, txt_name)
        txt_dst = os.path.join(base_path, f"labels/{split}", txt_name)

        if os.path.exists(txt_src):
            shutil.copy(txt_src, txt_dst)
        else:
            print(f"Pas d'annotation pour {img_name}")

# Appliquer le déplacement aux deux splits : train et val
move_data(train_imgs, "train")
move_data(val_imgs, "val")

# %% [markdown]
# # Augmentation

# %%
import albumentations as A
from albumentations.pytorch import ToTensorV2
from tqdm import tqdm
import cv2
import os

# === PARAMÈTRES ===
augmentations = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.2),
    A.RandomBrightnessContrast(p=0.3),
    A.Rotate(limit=20, p=0.3),
    A.RandomGamma(p=0.3),
    A.HueSaturationValue(hue_shift_limit=10, sat_shift_limit=20, val_shift_limit=10, p=0.4)
])

# Tu appliques l'augmentation uniquement sur le dossier d'entraînement
augmented_path = "/content/custom_data_augmented/images/train"
augmented_label_path = "/content/custom_data_augmented/labels/train"
os.makedirs(augmented_path, exist_ok=True)
os.makedirs(augmented_label_path, exist_ok=True)

original_train_images_path = "/content/custom_data/images/train"
original_train_labels_path = "/content/custom_data/labels/train"

# Copie les fichiers originaux
for img_file in tqdm(os.listdir(original_train_images_path), desc="Copie des images originales"):
    if not img_file.endswith(('.jpg', '.png')):
        continue
    img_path = os.path.join(original_train_images_path, img_file)
    label_path = os.path.join(original_train_labels_path, img_file.replace('.jpg', '.txt').replace('.png', '.txt'))

    img = cv2.imread(img_path)
    h, w = img.shape[:2]

    # Sauvegarde originale
    cv2.imwrite(os.path.join(augmented_path, img_file), img)
    shutil.copy(label_path, os.path.join(augmented_label_path, os.path.basename(label_path)))

    # Augmente 2 fois chaque image
    for i in range(2):
        augmented = augmentations(image=img)["image"]
        aug_img_name = img_file.replace('.', f'_aug{i}.')
        aug_lbl_name = img_file.replace('.jpg', f'_aug{i}.txt').replace('.png', f'_aug{i}.txt')

        cv2.imwrite(os.path.join(augmented_path, aug_img_name), augmented)
        shutil.copy(label_path, os.path.join(augmented_label_path, aug_lbl_name))

print("✅ Dataset augmenté.")
# Out:
# Copie des images originales: 100%|██████████| 8/8 [00:04<00:00,  1.70it/s]
# ✅ Dataset augmenté.

# %%
# Copie val original sans modification
original_val_images_path = "/content/custom_data/images/val"
original_val_labels_path = "/content/custom_data/labels/val"

val_img_out_dir = "/content/custom_data_augmented/images/val"
val_lbl_out_dir = "/content/custom_data_augmented/labels/val"

os.makedirs(val_img_out_dir, exist_ok=True)
os.makedirs(val_lbl_out_dir, exist_ok=True)

for img_file in os.listdir(original_val_images_path):
    if not img_file.endswith(('.jpg', '.png')):
        continue

    img_src = os.path.join(original_val_images_path, img_file)
    lbl_src = os.path.join(original_val_labels_path, img_file.replace('.jpg', '.txt').replace('.png', '.txt'))

    img_dst = os.path.join(val_img_out_dir, img_file)
    lbl_dst = os.path.join(val_lbl_out_dir, os.path.basename(lbl_src))

    shutil.copy(img_src, img_dst)
    shutil.copy(lbl_src, lbl_dst)

print("✅ Validation copiée sans modification.")
# Out:
# ✅ Validation copiée sans modification.

# %% [markdown]
# # Split des images du dataset

# %%
import os
import cv2
import shutil

# === PARAMÈTRES ===
# input_root = "/content/custom_data"
input_root = "/content/custom_data_augmented"

output_root = "/content/split_custom_data"

base_split_path = "/content/split_custom_data"

tile_size = 320
overlap = 0

splits = ["train", "val"]

def yolo_to_bbox(x_center, y_center, w, h, img_w, img_h):
    x1 = int((x_center - w / 2) * img_w)
    y1 = int((y_center - h / 2) * img_h)
    x2 = int((x_center + w / 2) * img_w)
    y2 = int((y_center + h / 2) * img_h)
    return x1, y1, x2, y2

def bbox_to_yolo(x1, y1, x2, y2, tile_w, tile_h):
    x_center = (x1 + x2) / 2 / tile_w
    y_center = (y1 + y2) / 2 / tile_h
    w = (x2 - x1) / tile_w
    h = (y2 - y1) / tile_h
    return x_center, y_center, w, h

# Boucle sur train et val
for split in splits:
    input_img_dir = os.path.join(input_root, f"images/{split}")
    input_lbl_dir = os.path.join(input_root, f"labels/{split}")
    output_img_dir = os.path.join(output_root, f"images/{split}")
    output_lbl_dir = os.path.join(output_root, f"labels/{split}")

    os.makedirs(output_img_dir, exist_ok=True)
    os.makedirs(output_lbl_dir, exist_ok=True)

    for filename in os.listdir(input_img_dir):
        if not filename.lower().endswith(('.jpg', '.png')):
            continue

        basename = os.path.splitext(filename)[0]
        img_path = os.path.join(input_img_dir, filename)
        label_path = os.path.join(input_lbl_dir, f"{basename}.txt")

        img = cv2.imread(img_path)
        img_h, img_w = img.shape[:2]

        annotations = []
        if os.path.exists(label_path):
            with open(label_path, "r") as f:
                for line in f.readlines():
                    parts = line.strip().split()
                    if len(parts) == 5:
                        cls, xc, yc, w, h = map(float, parts)
                        annotations.append((cls, *yolo_to_bbox(xc, yc, w, h, img_w, img_h)))

        step = tile_size - overlap
        tile_id = 0

        for y in range(0, img_h, step):
            for x in range(0, img_w, step):
                tile = img[y:y + tile_size, x:x + tile_size]
                tile_h, tile_w = tile.shape[:2]

                if tile_h < tile_size or tile_w < tile_size:
                    continue

                tile_filename = f"{basename}_{tile_id}.jpg"
                label_filename = f"{basename}_{tile_id}.txt"
                tile_id += 1

                cv2.imwrite(os.path.join(output_img_dir, tile_filename), tile)

                new_annots = []
                for cls, x1, y1, x2, y2 in annotations:
                    if x1 >= x + tile_size or x2 <= x or y1 >= y + tile_size or y2 <= y:
                        continue

                    bx1 = max(0, x1 - x)
                    by1 = max(0, y1 - y)
                    bx2 = min(tile_size, x2 - x)
                    by2 = min(tile_size, y2 - y)

                    if bx2 - bx1 < 5 or by2 - by1 < 5:
                        continue

                    x_c, y_c, w, h = bbox_to_yolo(bx1, by1, bx2, by2, tile_size, tile_size)
                    new_annots.append(f"{int(cls)} {x_c:.6f} {y_c:.6f} {w:.6f} {h:.6f}")

                with open(os.path.join(output_lbl_dir, label_filename), "w") as f:
                    f.write("\n".join(new_annots))

    print(f"✅ Split terminé pour '{split}' — {len(os.listdir(output_img_dir))} tuiles générées")
# Out:
# ✅ Split terminé pour 'train' — 2112 tuiles générées
# ✅ Split terminé pour 'val' — 284 tuiles générées

# %% [markdown]
# # Génération des YAML

# %% [markdown]
# Dynamique :

# %%
# Chemin vers le fichier obj.names exporté par CVAT (modifie si besoin)
obj_names_path = "/content/custom_data_raw/obj.names"

# Lire les noms de classes depuis obj.names
with open(obj_names_path, 'r') as f:
    class_names = [line.strip() for line in f if line.strip()]

# Générer le contenu du fichier YAML avec les augmentations de couleur
yaml_content = f"""
path: {base_split_path}
train: images/train
val: images/val
nc: {len(class_names)}
names: {class_names}
augment: True  # Activer l'augmentation des données
auto_augment: albumentations



# weights: [0.9, 0.1]  # Exemple de pondération si olive est trop présente
"""


# Écriture du fichier data.yaml
with open(f"{base_path}/data.yaml", "w") as f:
    f.write(yaml_content.strip())

with open(f"{base_split_path}/data.yaml", "w") as f:
    f.write(yaml_content.strip())

print(" Fichier data.yaml généré automatiquement :")
print(yaml_content)
# Out:
#  Fichier data.yaml généré automatiquement :
#
# path: /content/split_custom_data
# train: images/train
# val: images/val
# nc: 2
# names: ['olive', 'potential_olive']
# augment: True  # Activer l'augmentation des données
# auto_augment: albumentations
#
#
#
# # weights: [0.9, 0.1]  # Exemple de pondération si olive est trop présente

# %%
custom_train_cfg = """
# train_custom.yaml — Configuration d'entraînement pour YOLOv8

# Chemins
data: /content/split_custom_data/data.yaml
model: yolov8m.pt
# model: yolo11x.pt

# Entraînement
epochs: 50
batch: 16
imgsz: 320
# device: 0

# Hyperparamètres généraux
optimizer: SGD
lr0: 0.01
lrf: 0.01




# Augmentations géométriques
degrees: 00.0
translate: 0.0
scale: 0.5
shear: 0.0
perspective: 0.0
flipud: 0.0
fliplr: 0.5

# Augmentations de couleur (adapté olives/feuillage)
hsv_h: 0.02
hsv_s: 0.6
hsv_v: 0.5

# Avancées
mosaic: 0.3
mixup: 0.1
copy_paste: 0.6

# auto_augment: randaugment
auto_augment: albumentations

"""

# Écriture du fichier YAML
with open("/content/custom_data/train_custom.yaml", "w") as f:
    f.write(custom_train_cfg.strip())

print("✅ Fichier train_custom.yaml généré.")

with open(f"/content/split_custom_data/train_custom.yaml", "w") as f:
    f.write(custom_train_cfg.strip())

print("✅ Fichier train_custom.yaml généré.")
# Out:
# ✅ Fichier train_custom.yaml généré.
# ✅ Fichier train_custom.yaml généré.

# %% [markdown]
# ## Vérification des labels et autres

# %%
import os
from collections import Counter

# Dictionnaire des classes : adapte-le si jamais tu changes l'ordre ou les noms
class_names = {
    '0': 'olive',
    '1': 'potential_olive'
}

def analyze_labels(labels_dir):
    label_counts = Counter()

    for split in ['train', 'val']:
        dir_path = os.path.join(labels_dir, split)
        for file in os.listdir(dir_path):
            if file.endswith('.txt'):
                with open(os.path.join(dir_path, file), 'r') as f:
                    for line in f:
                        if line.strip():
                            class_id = line.strip().split()[0]
                            label_counts[class_id] += 1

    print(" Résumé des classes dans les annotations :\n")
    for class_id, count in label_counts.items():
        class_name = class_names.get(class_id, " Inconnu")
        print(f"Classe {class_id} ({class_name}) → {count} objets")

    # Alerte pour les classes non attendues
    for cid in label_counts:
        if cid not in class_names:
            print(f"\n ID inattendu détecté : {cid}")

# Appel de la fonction
analyze_labels(f"{base_split_path}/labels")
# Out:
#  Résumé des classes dans les annotations :
#
# Classe 0 (olive) → 2006 objets
# Classe 1 (potential_olive) → 11 objets

# %% [markdown]
# # Train

# %% [markdown]
# - Changer le nombre d'epochs : Avec seulement 6 images et un grand déséquilibre, 10 epochs peuvent ne pas être suffisants. Essaie d'augmenter le nombre d'epochs (par exemple, à 50 ou 100) pour donner au modèle plus de temps pour apprendre.
#
# - Réduire le imgsz : La taille des images peut avoir un impact sur l'entraînement. Si les images sont petites (moins de détails), une taille de 320x320 ou 416x416 pourrait mieux fonctionner qu'une taille de 640x640, qui peut être plus difficile à traiter.

# %%
# !yolo task=detect mode=train cfg={base_split_path}/train_custom.yaml
# Out:
# Overriding /usr/local/lib/python3.11/dist-packages/ultralytics/cfg/default.yaml with /content/split_custom_data/train_custom.yaml
# WARNING ⚠️ 'mode' argument is missing. Valid modes are frozenset({'train', 'export', 'benchmark', 'predict', 'track', 'val'}). Using default 'mode=train'.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8m.pt to 'yolov8m.pt'...
# 100% 49.7M/49.7M [00:00<00:00, 340MB/s]
# Ultralytics 8.3.129 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=albumentations, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.6, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/split_custom_data/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.02, hsv_s=0.6, hsv_v=0.5, imgsz=320, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.1, mode=train, model=yolov8m.pt, momentum=0.937, mosaic=0.3, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=SGD, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.0, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 40.8MB/s]
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
#   8                  -1  2   3985920  ultralytics.nn.modules.block.C2f             [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  2   1993728  ultralytics.nn.modules.block.C2f             [960, 384, 2]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  2    517632  ultralytics.nn.modules.block.C2f             [576, 192, 2]
#  16                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  2   1846272  ultralytics.nn.modules.block.C2f             [576, 384, 2]
#  19                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  2   4207104  ultralytics.nn.modules.block.C2f             [960, 576, 2]
#  22        [15, 18, 21]  1   3776854  ultralytics.nn.modules.head.Detect           [2, [192, 384, 576]]
# Model summary: 169 layers, 25,857,478 parameters, 25,857,462 gradients, 79.1 GFLOPs
#
# Transferred 469/475 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100% 5.35M/5.35M [00:00<00:00, 168MB/s]
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1309.7±951.1 MB/s, size: 49.2 KB)
# train: Scanning /content/split_custom_data/labels/train... 2112 images, 1578 backgrounds, 0 corrupt: 100% 2112/2112 [00:00<00:00, 3780.84it/s]
# train: New cache created: /content/split_custom_data/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1079.6±466.8 MB/s, size: 59.7 KB)
# val: Scanning /content/split_custom_data/labels/val... 284 images, 142 backgrounds, 0 corrupt: 100% 284/284 [00:00<00:00, 1524.84it/s]
# val: New cache created: /content/split_custom_data/labels/val.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: SGD(lr=0.01, momentum=0.937) with parameter groups 77 weight(decay=0.0), 84 weight(decay=0.0005), 83 bias(decay=0.0)
# Image sizes 320 train, 320 val
# Using 2 dataloader workers
# Logging results to runs/detect/train
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1
/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:01<00:00,  5.05it/s]
#                    all        284        508      0.736       0.39      0.484       0.28
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      6.75G      1.269      2.049      1.093          8        320: 100% 132/132 [00:21<00:00,  6.11it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:02<00:00,  4.21it/s]
#                    all        284        508      0.696      0.423      0.499      0.289
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50       6.8G      1.269       2.16      1.085          8        320: 100% 132/132 [00:21<00:00,  6.20it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:01<00:00,  5.89it/s]
#                    all        284        508      0.791      0.356      0.469      0.266
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      6.98G       1.23      1.979      1.091         27        320: 100% 132/132 [00:21<00:00,  6.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:01<00:00,  5.96it/s]
#                    all        284        508      0.719      0.403      0.474      0.269
#
# 50 epochs completed in 0.337 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 52.0MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 52.0MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics 8.3.129 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 92 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:03<00:00,  2.97it/s]
#                    all        284        508      0.636       0.49      0.532      0.295
#                  olive        142        508      0.636       0.49      0.532      0.295
# Speed: 0.2ms preprocess, 2.7ms inference, 0.0ms loss, 3.1ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
#yolo task=detect mode=train model=yolo11n.pt data={base_path}/data.yaml hyp={base_path}/hyp.yaml epochs=100 imgsz=640 device=0

# %%
import glob
from IPython.display import Image, display

# %%
Image(filename='runs/detect/train/confusion_matrix.png', width=600)

# %%
Image(filename='runs/detect/train/results.png', width=600)

# %% [markdown]
# # Validation

# %%
from ultralytics import YOLO

# Charger le modèle entraîné
model = YOLO("runs/detect/train/weights/best.pt")

# Évaluer sur le dataset de validation
metrics = model.val(data="/content/split_custom_data/data.yaml", split="val", verbose=False)

# Accès aux métriques par classe
names = model.names  # dict {class_id: name}
precision_per_class = metrics.box.p  # Précision par classe
recall_per_class = metrics.box.r  # Rappel par classe
map50_per_class = metrics.box.ap50  # mAP à IoU de 0.5 par classe
map_per_class = metrics.box.ap  # mAP à IoU de 0.5-0.95 par classe

# Exemple : récupérer les métriques de la classe "olive"
class_name = "olive"
class_id = list(names.values()).index(class_name)

print(f"Métriques pour la classe '{class_name}':")
print(f" - Précision : {precision_per_class[class_id]:.3f}")
print(f" - Rappel    : {recall_per_class[class_id]:.3f}")
print(f" - mAP@50    : {map50_per_class[class_id]:.3f}")
print(f" - mAP@50-95 : {map_per_class[class_id]:.3f}")
# Out:
# Ultralytics 8.3.129 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 92 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 999.1±586.1 MB/s, size: 49.7 KB)
# val: Scanning /content/split_custom_data/labels/val.cache... 284 images, 142 backgrounds, 0 corrupt: 100%|██████████| 284/284 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 18/18 [00:05<00:00,  3.18it/s]
#                    all        284        508      0.637       0.49      0.533      0.295
# Speed: 0.8ms preprocess, 6.4ms inference, 0.0ms loss, 4.3ms postprocess per image
# Results saved to runs/detect/val
# Métriques pour la classe 'olive':
#  - Précision : 0.637
#  - Rappel    : 0.490
#  - mAP@50    : 0.533
#  - mAP@50-95 : 0.295

# %% [markdown]
# En modifiant conf

# %%
from ultralytics import YOLO
from pathlib import Path
import cv2
import os
from ultralytics.utils.metrics import bbox_iou

# 🔧 Paramètres
model_path = "runs/detect/train/weights/best.pt"
data_path = "/content/split_custom_data/data.yaml"
val_images_dir = "/content/split_custom_data/images/val"
conf_threshold = 0.2  # 🔁 MODIFIE ici le seuil de confiance
target_class = "olive"
iou_threshold = 0.5  # pour comptage TP/FN

# 📦 Charger modèle + noms des classes
model = YOLO(model_path)
names = model.names
target_id = list(names.values()).index(target_class)

# 📂 Liste des fichiers image de validation
image_paths = list(Path(val_images_dir).rglob("*.jpg")) + list(Path(val_images_dir).rglob("*.png"))

# 🔢 Compteurs
TP, FP, FN = 0, 0, 0

# 🔍 Parcourir les images
import torch

# 🔍 Parcourir les images
for img_path in image_paths:
    results = model.predict(source=str(img_path), conf=conf_threshold, iou=iou_threshold, verbose=False)[0]

    # Prédictions pour la classe cible
    preds = [b for b in results.boxes.data.cpu().numpy() if int(b[5]) == target_id]
    pred_boxes = [b[:4] for b in preds]  # x1, y1, x2, y2

    # Ground truth : via les annotations val
    label_path = str(img_path).replace("/images/", "/labels/").rsplit(".", 1)[0] + ".txt"
    gt_boxes = []
    if os.path.exists(label_path):
        with open(label_path, "r") as f:
            for line in f:
                cls, x, y, w, h = map(float, line.strip().split())
                if int(cls) == target_id:
                    # YOLO format -> (x1, y1, x2, y2)
                    img = cv2.imread(str(img_path))
                    H, W = img.shape[:2]
                    cx, cy, bw, bh = x * W, y * H, w * W, h * H
                    x1 = cx - bw / 2
                    y1 = cy - bh / 2
                    x2 = cx + bw / 2
                    y2 = cy + bh / 2
                    gt_boxes.append([x1, y1, x2, y2])

    # 🧠 Matching GT ↔ prédictions
    matched_gt = set()
    for pred_box in pred_boxes:
        matched = False
        for i, gt_box in enumerate(gt_boxes):
            # Convertir en tensor avant de calculer l'IoU
            pred_box_tensor = torch.tensor(pred_box).unsqueeze(0)  # Convertir en tensor
            gt_box_tensor = torch.tensor(gt_box).unsqueeze(0)  # Convertir en tensor
            iou = bbox_iou(pred_box_tensor, gt_box_tensor)[0]  # Calcul de l'IoU
            if iou > iou_threshold and i not in matched_gt:
                TP += 1
                matched_gt.add(i)
                matched = True
                break
        if not matched:
            FP += 1
    FN += len(gt_boxes) - len(matched_gt)

# 📊 Calcul des métriques
precision = TP / (TP + FP) if (TP + FP) > 0 else 0
recall = TP / (TP + FN) if (TP + FN) > 0 else 0

print(f"\n🔎 Résultats pour la classe '{target_class}' (seuil conf = {conf_threshold}):")
print(f" - Vrais positifs (TP) : {TP}")
print(f" - Faux positifs (FP)  : {FP}")
print(f" - Faux négatifs (FN)  : {FN}")
print(f" - Précision           : {precision:.3f}")
print(f" - Rappel              : {recall:.3f}")
# Out:
# 🔎 Résultats pour la classe 'olive' (seuil conf = 0.2):
#  - Vrais positifs (TP) : 270
#  - Faux positifs (FP)  : 145
#  - Faux négatifs (FN)  : 238
#  - Précision           : 0.651
#  - Rappel              : 0.531

# %% [markdown]
# # Predict

# %% [markdown]
# - Vérifie les prédictions avec conf=0.5 ou plus bas : Parfois, si le modèle est trop conservateur, il ne détecte rien parce qu'il exige une très forte confiance. Essaie de réduire le seuil de confiance lors de la prédiction.

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt source={base_split_path}/images/val conf=0.5 save=True device=0
# Out:
# Ultralytics 8.3.129 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 92 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/284 /content/split_custom_data/images/val/20221116_151156_0.jpg: 320x320 (no detections), 15.8ms
# image 2/284 /content/split_custom_data/images/val/20221116_151156_1.jpg: 320x320 (no detections), 15.8ms
# image 3/284 /content/split_custom_data/images/val/20221116_151156_10.jpg: 320x320 1 olive, 15.7ms
# image 4/284 /content/split_custom_data/images/val/20221116_151156_100.jpg: 320x320 (no detections), 15.9ms
# image 5/284 /content/split_custom_data/images/val/20221116_151156_101.jpg: 320x320 (no detections), 15.7ms
# image 6/284 /content/split_custom_data/images/val/20221116_151156_102.jpg: 320x320 (no detections), 15.7ms
# image 7/284 /content/split_custom_data/images/val/20221116_151156_103.jpg: 320x320 (no detections), 15.8ms
# image 8/284 /content/split_custom_data/images/val/20221116_151156_104.jpg: 320x320 (no detections), 15.7ms
# image 9/284 /content/split_custom_data/images/val/20221116_151156_105.jpg: 320x320 2 olives, 15.7ms
# image 10/284 /content/split_custom_data/images/val/20221116_151156_106.jpg: 320x320 (no detections), 15.7ms
# image 11/284 /content/split_custom_data/images/val/20221116_151156_107.jpg: 320x320 (no detections), 15.8ms
# image 12/284 /content/split_custom_data/images/val/20221116_151156_11.jpg: 320x320 (no detections), 13.7ms
# image 13/284 /content/split_custom_data/images/val/20221116_151156_12.jpg: 320x320 (no detections), 12.4ms
# image 14/284 /content/split_custom_data/images/val/20221116_151156_13.jpg: 320x320 (no detections), 10.7ms
# image 15/284 /content/split_custom_data/images/val/20221116_151156_14.jpg: 320x320 (no detections), 10.7ms
# image 16/284 /content/split_custom_data/images/val/20221116_151156_15.jpg: 320x320 (no detections), 10.7ms
# image 17/284 /content/split_custom_data/images/val/20221116_151156_16.jpg: 320x320 (no detections), 10.7ms
# image 18/284 /content/split_custom_data/images/val/20221116_151156_17.jpg: 320x320 1 olive, 10.7ms
# image 19/284 /content/split_custom_data/images/val/20221116_151156_18.jpg: 320x320 (no detections), 10.5ms
# image 20/284 /content/split_custom_data/images/val/20221116_151156_19.jpg: 320x320 3 olives, 10.5ms
# image 21/284 /content/split_custom_data/images/val/20221116_151156_2.jpg: 320x320 (no detections), 11.5ms
# image 111/284 /content/split_custom_data/images/val/IMG_20231027_131101_10.jpg: 320x320 (no detections), 7.3ms
# image 112/284 /content/split_custom_data/images/val/IMG_20231027_131101_11.jpg: 320x320 (no detections), 7.1ms
# image 113/284 /content/split_custom_data/images/val/IMG_20231027_131101_12.jpg: 320x320 (no detections), 7.4ms
# image 114/284 /content/split_custom_data/images/val/IMG_20231027_131101_13.jpg: 320x320 2 olives, 7.4ms
# image 115/284 /content/split_custom_data/images/val/IMG_20231027_131101_14.jpg: 320x320 (no detections), 7.2ms
# image 116/284 /content/split_custom_data/images/val/IMG_20231027_131101_15.jpg: 320x320 (no detections), 7.4ms
# image 117/284 /content/split_custom_data/images/val/IMG_20231027_131101_16.jpg: 320x320 (no detections), 8.6ms
# image 118/284 /content/split_custom_data/images/val/IMG_20231027_131101_17.jpg: 320x320 (no detections), 14.1ms
# image 119/284 /content/split_custom_data/images/val/IMG_20231027_131101_18.jpg: 320x320 (no detections), 7.8ms
# image 120/284 /content/split_custom_data/images/val/IMG_20231027_131101_19.jpg: 320x320 (no detections), 7.1ms
# image 121/284 /content/split_custom_data/images/val/IMG_20231027_131101_2.jpg: 320x320 (no detections), 7.7ms
# image 122/284 /content/split_custom_data/images/val/IMG_20231027_131101_20.jpg: 320x320 (no detections), 8.5ms
# image 123/284 /content/split_custom_data/images/val/IMG_20231027_131101_21.jpg: 320x320 1 olive, 7.0ms
# image 124/284 /content/split_custom_data/images/val/IMG_20231027_131101_22.jpg: 320x320 (no detections), 7.3ms
# image 125/284 /content/split_custom_data/images/val/IMG_20231027_131101_23.jpg: 320x320 (no detections), 7.4ms
# image 126/284 /content/split_custom_data/images/val/IMG_20231027_131101_24.jpg: 320x320 (no detections), 7.2ms
# image 127/284 /content/split_custom_data/images/val/IMG_20231027_131101_25.jpg: 320x320 (no detections), 7.3ms
# image 128/284 /content/split_custom_data/images/val/IMG_20231027_131101_26.jpg: 320x320 (no detections), 7.9ms
# image 129/284 /content/split_custom_data/images/val/IMG_20231027_131101_27.jpg: 320x320 (no detections), 7.4ms
# image 130/284 /content/split_custom_data/images/val/IMG_20231027_131101_28.jpg: 320x320 (no detections), 7.2ms
# image 131/284 /content/split_custom_data/images/val/IMG_20231027_131101_29.jpg: 320x320 (no detections), 7.4ms
# image 132/284 /content/split_custom_data/images/val/IMG_20231027_131101_3.jpg: 320x320 (no detections), 7.2ms
# image 133/284 /content/split_custom_data/images/val/IMG_20231027_131101_30.jpg: 320x320 1 olive, 7.3ms
# image 134/284 /content/split_custom_data/images/val/IMG_20231027_131101_31.jpg: 320x320 (no detections), 7.3ms
# image 135/284 /content/split_custom_data/images/val/IMG_20231027_131101_32.jpg: 320x320 (no detections), 7.1ms
# image 136/284 /content/split_custom_data/images/val/IMG_20231027_131101_33.jpg: 320x320 (no detections), 10.4ms
# image 137/284 /content/split_custom_data/images/val/IMG_20231027_131101_34.jpg: 320x320 (no detections), 7.5ms
# image 138/284 /content/split_custom_data/images/val/IMG_20231027_131101_35.jpg: 320x320 (no detections), 7.6ms
# image 139/284 /content/split_custom_data/images/val/IMG_20231027_131101_36.jpg: 320x320 (no detections), 7.2ms
# image 140/284 /content/split_custom_data/images/val/IMG_20231027_131101_37.jpg: 320x320 (no detections), 7.1ms
# image 141/284 /content/split_custom_data/images/val/IMG_20231027_131101_38.jpg: 320x320 (no detections), 7.0ms
# image 142/284 /content/split_custom_data/images/val/IMG_20231027_131101_39.jpg: 320x320 1 olive, 7.2ms
# image 143/284 /content/split_custom_data/images/val/IMG_20231027_131101_4.jpg: 320x320 (no detections), 7.1ms
# image 144/284 /content/split_custom_data/images/val/IMG_20231027_131101_40.jpg: 320x320 (no detections), 7.2ms
# image 145/284 /content/split_custom_data/images/val/IMG_20231027_131101_41.jpg: 320x320 (no detections), 7.3ms
# image 146/284 /content/split_custom_data/images/val/IMG_20231027_131101_42.jpg: 320x320 1 olive, 7.3ms
# image 147/284 /content/split_custom_data/images/val/IMG_20231027_131101_43.jpg: 320x320 (no detections), 7.3ms
# image 148/284 /content/split_custom_data/images/val/IMG_20231027_131101_44.jpg: 320x320 (no detections), 7.3ms
# image 149/284 /content/split_custom_data/images/val/IMG_20231027_131101_45.jpg: 320x320 (no detections), 7.2ms
# image 150/284 /content/split_custom_data/images/val/IMG_20231027_131101_46.jpg: 320x320 1 olive, 7.2ms
# image 151/284 /content/split_custom_data/images/val/IMG_20231027_131101_47.jpg: 320x320 (no detections), 7.2ms
# image 152/284 /content/split_custom_data/images/val/IMG_20231027_131101_48.jpg: 320x320 (no detections), 7.2ms
# image 153/284 /content/split_custom_data/images/val/IMG_20231027_131101_49.jpg: 320x320 (no detections), 7.2ms
# image 154/284 /content/split_custom_data/images/val/IMG_20231027_131101_5.jpg: 320x320 (no detections), 7.1ms
# image 155/284 /content/split_custom_data/images/val/IMG_20231027_131101_50.jpg: 320x320 (no detections), 9.5ms
# image 156/284 /content/split_custom_data/images/val/IMG_20231027_131101_51.jpg: 320x320 1 olive, 7.0ms
# image 157/284 /content/split_custom_data/images/val/IMG_20231027_131101_52.jpg: 320x320 (no detections), 7.1ms
# image 158/284 /content/split_custom_data/images/val/IMG_20231027_131101_53.jpg: 320x320 (no detections), 7.1ms
# image 159/284 /content/split_custom_data/images/val/IMG_20231027_131101_54.jpg: 320x320 (no detections), 8.6ms
# image 160/284 /content/split_custom_data/images/val/IMG_20231027_131101_55.jpg: 320x320 (no detections), 7.4ms
# image 161/284 /content/split_custom_data/images/val/IMG_20231027_131101_56.jpg: 320x320 1 olive, 12.4ms
# image 162/284 /content/split_custom_data/images/val/IMG_20231027_131101_57.jpg: 320x320 (no detections), 7.0ms
# image 163/284 /content/split_custom_data/images/val/IMG_20231027_131101_58.jpg: 320x320 (no detections), 8.7ms
# image 164/284 /content/split_custom_data/images/val/IMG_20231027_131101_59.jpg: 320x320 (no detections), 8.6ms
# image 165/284 /content/split_custom_data/images/val/IMG_20231027_131101_6.jpg: 320x320 1 olive, 7.1ms
# image 166/284 /content/split_custom_data/images/val/IMG_20231027_131101_60.jpg: 320x320 (no detections), 7.3ms
# image 167/284 /content/split_custom_data/images/val/IMG_20231027_131101_61.jpg: 320x320 (no detections), 7.7ms
# image 168/284 /content/split_custom_data/images/val/IMG_20231027_131101_62.jpg: 320x320 (no detections), 8.4ms
# image 169/284 /content/split_custom_data/images/val/IMG_20231027_131101_63.jpg: 320x320 (no detections), 7.3ms
# image 170/284 /content/split_custom_data/images/val/IMG_20231027_131101_64.jpg: 320x320 (no detections), 7.3ms
# image 171/284 /content/split_custom_data/images/val/IMG_20231027_131101_65.jpg: 320x320 (no detections), 7.2ms
# image 172/284 /content/split_custom_data/images/val/IMG_20231027_131101_66.jpg: 320x320 (no detections), 7.2ms
# image 173/284 /content/split_custom_data/images/val/IMG_20231027_131101_67.jpg: 320x320 (no detections), 11.4ms
# image 174/284 /content/split_custom_data/images/val/IMG_20231027_131101_68.jpg: 320x320 (no detections), 8.5ms
# image 175/284 /content/split_custom_data/images/val/IMG_20231027_131101_69.jpg: 320x320 (no detections), 7.8ms
# image 176/284 /content/split_custom_data/images/val/IMG_20231027_131101_7.jpg: 320x320 (no detections), 7.0ms
# image 177/284 /content/split_custom_data/images/val/IMG_20231027_131101_70.jpg: 320x320 (no detections), 8.2ms
# image 178/284 /content/split_custom_data/images/val/IMG_20231027_131101_71.jpg: 320x320 (no detections), 8.1ms
# image 179/284 /content/split_custom_data/images/val/IMG_20231027_131101_72.jpg: 320x320 (no detections), 7.7ms
# image 180/284 /content/split_custom_data/images/val/IMG_20231027_131101_73.jpg: 320x320 (no detections), 7.2ms
# image 181/284 /content/split_custom_data/images/val/IMG_20231027_131101_74.jpg: 320x320 (no detections), 7.1ms
# image 182/284 /content/split_custom_data/images/val/IMG_20231027_131101_75.jpg: 320x320 (no detections), 7.4ms
# image 183/284 /content/split_custom_data/images/val/IMG_20231027_131101_76.jpg: 320x320 (no detections), 12.1ms
# image 184/284 /content/split_custom_data/images/val/IMG_20231027_131101_77.jpg: 320x320 (no detections), 14.9ms
# image 185/284 /content/split_custom_data/images/val/IMG_20231027_131101_78.jpg: 320x320 1 olive, 13.0ms
# image 186/284 /content/split_custom_data/images/val/IMG_20231027_131101_79.jpg: 320x320 (no detections), 13.2ms
# image 187/284 /content/split_custom_data/images/val/IMG_20231027_131101_8.jpg: 320x320 (no detections), 11.3ms
# image 188/284 /content/split_custom_data/images/val/IMG_20231027_131101_80.jpg: 320x320 (no detections), 11.6ms
# image 189/284 /content/split_custom_data/images/val/IMG_20231027_131101_81.jpg: 320x320 (no detections), 9.5ms
# image 190/284 /content/split_custom_data/images/val/IMG_20231027_131101_82.jpg: 320x320 (no detections), 7.3ms
# image 191/284 /content/split_custom_data/images/val/IMG_20231027_131101_83.jpg: 320x320 (no detections), 8.5ms
# image 192/284 /content/split_custom_data/images/val/IMG_20231027_131101_84.jpg: 320x320 (no detections), 7.1ms
# image 193/284 /content/split_custom_data/images/val/IMG_20231027_131101_85.jpg: 320x320 (no detections), 6.9ms
# image 194/284 /content/split_custom_data/images/val/IMG_20231027_131101_86.jpg: 320x320 (no detections), 7.2ms
# image 195/284 /content/split_custom_data/images/val/IMG_20231027_131101_87.jpg: 320x320 2 olives, 6.9ms
# image 196/284 /content/split_custom_data/images/val/IMG_20231027_131101_9.jpg: 320x320 (no detections), 7.0ms
# image 197/284 /content/split_custom_data/images/val/IMG_20231108_122539_0.jpg: 320x320 (no detections), 7.8ms
# image 198/284 /content/split_custom_data/images/val/IMG_20231108_122539_1.jpg: 320x320 (no detections), 8.0ms
# image 199/284 /content/split_custom_data/images/val/IMG_20231108_122539_10.jpg: 320x320 1 olive, 8.1ms
# image 200/284 /content/split_custom_data/images/val/IMG_20231108_122539_11.jpg: 320x320 1 olive, 7.2ms
# image 201/284 /content/split_custom_data/images/val/IMG_20231108_122539_12.jpg: 320x320 (no detections), 7.2ms
# image 202/284 /content/split_custom_data/images/val/IMG_20231108_122539_13.jpg: 320x320 1 olive, 7.8ms
# image 203/284 /content/split_custom_data/images/val/IMG_20231108_122539_14.jpg: 320x320 1 olive, 7.5ms
# image 204/284 /content/split_custom_data/images/val/IMG_20231108_122539_15.jpg: 320x320 2 olives, 7.0ms
# image 205/284 /content/split_custom_data/images/val/IMG_20231108_122539_16.jpg: 320x320 (no detections), 7.3ms
# image 206/284 /content/split_custom_data/images/val/IMG_20231108_122539_17.jpg: 320x320 (no detections), 8.0ms
# image 207/284 /content/split_custom_data/images/val/IMG_20231108_122539_18.jpg: 320x320 2 olives, 7.0ms
# image 208/284 /content/split_custom_data/images/val/IMG_20231108_122539_19.jpg: 320x320 8 olives, 7.2ms
# image 209/284 /content/split_custom_data/images/val/IMG_20231108_122539_2.jpg: 320x320 (no detections), 7.1ms
# image 210/284 /content/split_custom_data/images/val/IMG_20231108_122539_20.jpg: 320x320 5 olives, 7.3ms
# image 211/284 /content/split_custom_data/images/val/IMG_20231108_122539_21.jpg: 320x320 (no detections), 7.1ms
# image 212/284 /content/split_custom_data/images/val/IMG_20231108_122539_22.jpg: 320x320 1 olive, 7.1ms
# image 213/284 /content/split_custom_data/images/val/IMG_20231108_122539_23.jpg: 320x320 (no detections), 6.9ms
# image 214/284 /content/split_custom_data/images/val/IMG_20231108_122539_24.jpg: 320x320 (no detections), 6.9ms
# image 215/284 /content/split_custom_data/images/val/IMG_20231108_122539_25.jpg: 320x320 5 olives, 7.0ms
# image 216/284 /content/split_custom_data/images/val/IMG_20231108_122539_26.jpg: 320x320 3 olives, 9.0ms
# image 217/284 /content/split_custom_data/images/val/IMG_20231108_122539_27.jpg: 320x320 (no detections), 8.3ms
# image 218/284 /content/split_custom_data/images/val/IMG_20231108_122539_28.jpg: 320x320 7 olives, 7.2ms
# image 219/284 /content/split_custom_data/images/val/IMG_20231108_122539_29.jpg: 320x320 1 olive, 7.0ms
# image 220/284 /content/split_custom_data/images/val/IMG_20231108_122539_3.jpg: 320x320 (no detections), 7.0ms
# image 221/284 /content/split_custom_data/images/val/IMG_20231108_122539_30.jpg: 320x320 3 olives, 6.9ms
# image 222/284 /content/split_custom_data/images/val/IMG_20231108_122539_31.jpg: 320x320 (no detections), 7.1ms
# image 223/284 /content/split_custom_data/images/val/IMG_20231108_122539_32.jpg: 320x320 1 olive, 8.3ms
# image 224/284 /content/split_custom_data/images/val/IMG_20231108_122539_33.jpg: 320x320 5 olives, 12.6ms
# image 225/284 /content/split_custom_data/images/val/IMG_20231108_122539_34.jpg: 320x320 4 olives, 8.8ms
# image 226/284 /content/split_custom_data/images/val/IMG_20231108_122539_35.jpg: 320x320 1 olive, 7.5ms
# image 227/284 /content/split_custom_data/images/val/IMG_20231108_122539_36.jpg: 320x320 3 olives, 8.6ms
# image 228/284 /content/split_custom_data/images/val/IMG_20231108_122539_37.jpg: 320x320 2 olives, 7.1ms
# image 229/284 /content/split_custom_data/images/val/IMG_20231108_122539_38.jpg: 320x320 2 olives, 7.8ms
# image 230/284 /content/split_custom_data/images/val/IMG_20231108_122539_39.jpg: 320x320 4 olives, 10.2ms
# image 231/284 /content/split_custom_data/images/val/IMG_20231108_122539_4.jpg: 320x320 (no detections), 6.8ms
# image 232/284 /content/split_custom_data/images/val/IMG_20231108_122539_40.jpg: 320x320 1 olive, 7.0ms
# image 233/284 /content/split_custom_data/images/val/IMG_20231108_122539_41.jpg: 320x320 5 olives, 7.1ms
# image 234/284 /content/split_custom_data/images/val/IMG_20231108_122539_42.jpg: 320x320 3 olives, 6.9ms
# image 235/284 /content/split_custom_data/images/val/IMG_20231108_122539_43.jpg: 320x320 1 olive, 6.8ms
# image 236/284 /content/split_custom_data/images/val/IMG_20231108_122539_44.jpg: 320x320 (no detections), 6.9ms
# image 237/284 /content/split_custom_data/images/val/IMG_20231108_122539_45.jpg: 320x320 1 olive, 7.1ms
# image 238/284 /content/split_custom_data/images/val/IMG_20231108_122539_46.jpg: 320x320 1 olive, 7.4ms
# image 239/284 /content/split_custom_data/images/val/IMG_20231108_122539_47.jpg: 320x320 1 olive, 7.1ms
# image 240/284 /content/split_custom_data/images/val/IMG_20231108_122539_48.jpg: 320x320 1 olive, 7.3ms
# image 241/284 /content/split_custom_data/images/val/IMG_20231108_122539_49.jpg: 320x320 3 olives, 7.1ms
# image 242/284 /content/split_custom_data/images/val/IMG_20231108_122539_5.jpg: 320x320 1 olive, 7.7ms
# image 243/284 /content/split_custom_data/images/val/IMG_20231108_122539_50.jpg: 320x320 3 olives, 7.0ms
# image 244/284 /content/split_custom_data/images/val/IMG_20231108_122539_51.jpg: 320x320 (no detections), 6.9ms
# image 245/284 /content/split_custom_data/images/val/IMG_20231108_122539_52.jpg: 320x320 1 olive, 7.1ms
# image 246/284 /content/split_custom_data/images/val/IMG_20231108_122539_53.jpg: 320x320 (no detections), 7.1ms
# image 247/284 /content/split_custom_data/images/val/IMG_20231108_122539_54.jpg: 320x320 4 olives, 7.1ms
# image 248/284 /content/split_custom_data/images/val/IMG_20231108_122539_55.jpg: 320x320 1 olive, 9.1ms
# image 249/284 /content/split_custom_data/images/val/IMG_20231108_122539_56.jpg: 320x320 3 olives, 7.0ms
# image 250/284 /content/split_custom_data/images/val/IMG_20231108_122539_57.jpg: 320x320 (no detections), 7.3ms
# image 251/284 /content/split_custom_data/images/val/IMG_20231108_122539_58.jpg: 320x320 (no detections), 7.1ms
# image 252/284 /content/split_custom_data/images/val/IMG_20231108_122539_59.jpg: 320x320 (no detections), 7.2ms
# image 253/284 /content/split_custom_data/images/val/IMG_20231108_122539_6.jpg: 320x320 1 olive, 8.6ms
# image 254/284 /content/split_custom_data/images/val/IMG_20231108_122539_60.jpg: 320x320 (no detections), 7.5ms
# image 255/284 /content/split_custom_data/images/val/IMG_20231108_122539_61.jpg: 320x320 (no detections), 7.1ms
# image 256/284 /content/split_custom_data/images/val/IMG_20231108_122539_62.jpg: 320x320 (no detections), 7.5ms
# image 257/284 /content/split_custom_data/images/val/IMG_20231108_122539_63.jpg: 320x320 1 olive, 7.2ms
# image 258/284 /content/split_custom_data/images/val/IMG_20231108_122539_64.jpg: 320x320 2 olives, 7.0ms
# image 259/284 /content/split_custom_data/images/val/IMG_20231108_122539_65.jpg: 320x320 (no detections), 7.1ms
# image 260/284 /content/split_custom_data/images/val/IMG_20231108_122539_66.jpg: 320x320 (no detections), 7.0ms
# image 261/284 /content/split_custom_data/images/val/IMG_20231108_122539_67.jpg: 320x320 1 olive, 7.2ms
# image 262/284 /content/split_custom_data/images/val/IMG_20231108_122539_68.jpg: 320x320 (no detections), 7.8ms
# image 263/284 /content/split_custom_data/images/val/IMG_20231108_122539_69.jpg: 320x320 (no detections), 7.2ms
# image 264/284 /content/split_custom_data/images/val/IMG_20231108_122539_7.jpg: 320x320 1 olive, 6.9ms
# image 265/284 /content/split_custom_data/images/val/IMG_20231108_122539_70.jpg: 320x320 (no detections), 12.9ms
# image 266/284 /content/split_custom_data/images/val/IMG_20231108_122539_71.jpg: 320x320 2 olives, 8.1ms
# image 267/284 /content/split_custom_data/images/val/IMG_20231108_122539_72.jpg: 320x320 (no detections), 10.6ms
# image 268/284 /content/split_custom_data/images/val/IMG_20231108_122539_73.jpg: 320x320 (no detections), 11.2ms
# image 269/284 /content/split_custom_data/images/val/IMG_20231108_122539_74.jpg: 320x320 1 olive, 13.6ms
# image 270/284 /content/split_custom_data/images/val/IMG_20231108_122539_75.jpg: 320x320 2 olives, 7.2ms
# image 271/284 /content/split_custom_data/images/val/IMG_20231108_122539_76.jpg: 320x320 (no detections), 7.0ms
# image 272/284 /content/split_custom_data/images/val/IMG_20231108_122539_77.jpg: 320x320 (no detections), 6.9ms
# image 273/284 /content/split_custom_data/images/val/IMG_20231108_122539_78.jpg: 320x320 (no detections), 7.5ms
# image 274/284 /content/split_custom_data/images/val/IMG_20231108_122539_79.jpg: 320x320 (no detections), 7.1ms
# image 275/284 /content/split_custom_data/images/val/IMG_20231108_122539_8.jpg: 320x320 (no detections), 7.2ms
# image 276/284 /content/split_custom_data/images/val/IMG_20231108_122539_80.jpg: 320x320 (no detections), 8.9ms
# image 277/284 /content/split_custom_data/images/val/IMG_20231108_122539_81.jpg: 320x320 (no detections), 9.1ms
# image 278/284 /content/split_custom_data/images/val/IMG_20231108_122539_82.jpg: 320x320 (no detections), 7.6ms
# image 279/284 /content/split_custom_data/images/val/IMG_20231108_122539_83.jpg: 320x320 (no detections), 8.6ms
# image 280/284 /content/split_custom_data/images/val/IMG_20231108_122539_84.jpg: 320x320 (no detections), 7.5ms
# image 281/284 /content/split_custom_data/images/val/IMG_20231108_122539_85.jpg: 320x320 (no detections), 7.1ms
# image 282/284 /content/split_custom_data/images/val/IMG_20231108_122539_86.jpg: 320x320 (no detections), 8.0ms
# image 283/284 /content/split_custom_data/images/val/IMG_20231108_122539_87.jpg: 320x320 (no detections), 7.3ms
# image 284/284 /content/split_custom_data/images/val/IMG_20231108_122539_9.jpg: 320x320 (no detections), 7.1ms
# Speed: 0.6ms preprocess, 8.5ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 320)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # VIsualisation

# %%
from IPython.display import Image, display
import glob

predictions = glob.glob('/content/runs/detect/predict/*.jpg')
for image_path in predictions[:10]:
    display(Image(filename=image_path, width=600))

# %% [markdown]
# # Télécharger le modèle

# %%
# Create "my_model" folder to store model weights and train results
# !mkdir /content/my_model
# !cp /content/runs/detect/train/weights/best.pt /content/my_model/my_model.pt
# !cp -r /content/runs/detect/train /content/my_model

# Zip into "my_model.zip"
# %cd my_model
# !zip /content/my_model.zip my_model.pt
# !zip -r /content/my_model.zip train
# %cd /content
# Out:
# /content/my_model
#   adding: my_model.pt (deflated 8%)
#   adding: train/ (stored 0%)
#   adding: train/val_batch0_pred.jpg (deflated 7%)
#   adding: train/train_batch5281.jpg (deflated 3%)
#   adding: train/val_batch0_labels.jpg (deflated 7%)
#   adding: train/R_curve.png (deflated 16%)
#   adding: train/F1_curve.png (deflated 17%)
#   adding: train/args.yaml (deflated 52%)
#   adding: train/train_batch1.jpg (deflated 4%)
#   adding: train/val_batch1_labels.jpg (deflated 9%)
#   adding: train/train_batch5280.jpg (deflated 4%)
#   adding: train/results.csv (deflated 58%)
#   adding: train/train_batch5282.jpg (deflated 4%)
#   adding: train/labels_correlogram.jpg (deflated 37%)
#   adding: train/confusion_matrix.png (deflated 35%)
#   adding: train/train_batch0.jpg (deflated 3%)
#   adding: train/train_batch2.jpg (deflated 5%)
#   adding: train/val_batch2_labels.jpg (deflated 9%)
#   adding: train/confusion_matrix_normalized.png (deflated 35%)
#   adding: train/val_batch1_pred.jpg (deflated 9%)
#   adding: train/labels.jpg (deflated 24%)
#   adding: train/results.png (deflated 6%)
#   adding: train/val_batch2_pred.jpg (deflated 9%)
#   adding: train/P_curve.png (deflated 14%)
#   adding: train/weights/ (stored 0%)
#   adding: train/weights/last.pt (deflated 8%)
#   adding: train/weights/best.pt (deflated 8%)
#   adding: train/PR_curve.png (deflated 18%)
# /content
