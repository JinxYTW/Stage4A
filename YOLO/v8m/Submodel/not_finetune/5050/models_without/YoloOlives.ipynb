# %% [markdown]
# # Installation

# %%
# !pip install ultralytics --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 55.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 68.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 37.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 63.8 MB/s eta 0:00:00

# %% [markdown]
# # Vérification avant de commencer

# %%
import ultralytics
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
ultralytics.checks()
# Out:
# Ultralytics 8.3.129 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.5/112.6 GB disk)

# %% [markdown]
# Visualisation des ressources et utilisation GPU

# %%
# !nvidia-smi
# Out:
# Fri May  9 10:55:49 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8             10W /   70W |       2MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# Vérification disponibilité GPU

# %%
import torch
print("GPU disponible :", torch.cuda.is_available())
# Out:
# GPU disponible : True

# %% [markdown]
# # Préparation du dataset

# %%
# !unzip -q /content/data.zip -d /content/custom_data_raw

# %% [markdown]
# ## Organisation à avoir

# %% [markdown]
# ```
# custom_data/
# ├── images/
# │   ├── train/
# │   └── val/
# ├── labels/
# │   ├── train/
# │   └── val/

# %% [markdown]
# ## Réorganisation du dataset

# %%
import os
import shutil
from sklearn.model_selection import train_test_split

# Répertoire d'origine pour les images et annotations
raw_data_path_images = "/content/custom_data_raw/images"  # Images sont dans ce dossier
raw_data_path_labels = "/content/custom_data_raw/obj_train_data"  # Annotations dans ce dossier

# Obtenir toutes les images (jpg/png) présentes dans le dossier "images"
images = [f for f in os.listdir(raw_data_path_images) if f.endswith(('.jpg', '.png'))]

# Split train/val (80% train, 20% val)
train_imgs, val_imgs = train_test_split(images, test_size=0.2, random_state=42)

# Création des dossiers cible pour images et labels
base_path = "/content/custom_data"


os.makedirs(base_path + "/images/train", exist_ok=True)
os.makedirs(base_path + "/images/val", exist_ok=True)
os.makedirs(base_path + "/labels/train", exist_ok=True)
os.makedirs(base_path + "/labels/val", exist_ok=True)

def move_data(image_list, split):
    for img_name in image_list:
        # Déplacer l'image vers le bon dossier
        src_img = os.path.join(raw_data_path_images, img_name)
        dst_img = os.path.join(base_path, f"images/{split}", img_name)
        shutil.copy(src_img, dst_img)

        # Vérifier et déplacer l'annotation .txt correspondante
        txt_name = img_name.rsplit('.', 1)[0] + '.txt'
        txt_src = os.path.join(raw_data_path_labels, txt_name)
        txt_dst = os.path.join(base_path, f"labels/{split}", txt_name)

        if os.path.exists(txt_src):
            shutil.copy(txt_src, txt_dst)
        else:
            print(f"Pas d'annotation pour {img_name}")

# Appliquer le déplacement aux deux splits : train et val
move_data(train_imgs, "train")
move_data(val_imgs, "val")

# %% [markdown]
# # Augmentation

# %%
import albumentations as A
from albumentations.pytorch import ToTensorV2
from tqdm import tqdm
import cv2
import os

# === PARAMÈTRES ===
augmentations = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.2),
    A.RandomBrightnessContrast(p=0.3),
    A.Rotate(limit=20, p=0.3),
    A.RandomGamma(p=0.3),
    A.HueSaturationValue(hue_shift_limit=10, sat_shift_limit=20, val_shift_limit=10, p=0.4)
])

# Tu appliques l'augmentation uniquement sur le dossier d'entraînement
augmented_path = "/content/custom_data_augmented/images/train"
augmented_label_path = "/content/custom_data_augmented/labels/train"
os.makedirs(augmented_path, exist_ok=True)
os.makedirs(augmented_label_path, exist_ok=True)

original_train_images_path = "/content/custom_data/images/train"
original_train_labels_path = "/content/custom_data/labels/train"

# Copie les fichiers originaux
for img_file in tqdm(os.listdir(original_train_images_path), desc="Copie des images originales"):
    if not img_file.endswith(('.jpg', '.png')):
        continue
    img_path = os.path.join(original_train_images_path, img_file)
    label_path = os.path.join(original_train_labels_path, img_file.replace('.jpg', '.txt').replace('.png', '.txt'))

    img = cv2.imread(img_path)
    h, w = img.shape[:2]

    # Sauvegarde originale
    cv2.imwrite(os.path.join(augmented_path, img_file), img)
    shutil.copy(label_path, os.path.join(augmented_label_path, os.path.basename(label_path)))

    # Augmente 2 fois chaque image
    for i in range(2):
        augmented = augmentations(image=img)["image"]
        aug_img_name = img_file.replace('.', f'_aug{i}.')
        aug_lbl_name = img_file.replace('.jpg', f'_aug{i}.txt').replace('.png', f'_aug{i}.txt')

        cv2.imwrite(os.path.join(augmented_path, aug_img_name), augmented)
        shutil.copy(label_path, os.path.join(augmented_label_path, aug_lbl_name))

print("✅ Dataset augmenté.")
# Out:
# Copie des images originales: 100%|██████████| 19/19 [00:09<00:00,  1.98it/s]
# ✅ Dataset augmenté.

# %%
# Copie val original sans modification
original_val_images_path = "/content/custom_data/images/val"
original_val_labels_path = "/content/custom_data/labels/val"

val_img_out_dir = "/content/custom_data_augmented/images/val"
val_lbl_out_dir = "/content/custom_data_augmented/labels/val"

os.makedirs(val_img_out_dir, exist_ok=True)
os.makedirs(val_lbl_out_dir, exist_ok=True)

for img_file in os.listdir(original_val_images_path):
    if not img_file.endswith(('.jpg', '.png')):
        continue

    img_src = os.path.join(original_val_images_path, img_file)
    lbl_src = os.path.join(original_val_labels_path, img_file.replace('.jpg', '.txt').replace('.png', '.txt'))

    img_dst = os.path.join(val_img_out_dir, img_file)
    lbl_dst = os.path.join(val_lbl_out_dir, os.path.basename(lbl_src))

    shutil.copy(img_src, img_dst)
    shutil.copy(lbl_src, lbl_dst)

print("✅ Validation copiée sans modification.")
# Out:
# ✅ Validation copiée sans modification.

# %% [markdown]
# # Split des images du dataset

# %%
import os
import cv2
import shutil

# === PARAMÈTRES ===
# input_root = "/content/custom_data"
input_root = "/content/custom_data_augmented"

output_root = "/content/split_custom_data"

base_split_path = "/content/split_custom_data"

tile_size = 320
overlap = 0

splits = ["train", "val"]

def yolo_to_bbox(x_center, y_center, w, h, img_w, img_h):
    x1 = int((x_center - w / 2) * img_w)
    y1 = int((y_center - h / 2) * img_h)
    x2 = int((x_center + w / 2) * img_w)
    y2 = int((y_center + h / 2) * img_h)
    return x1, y1, x2, y2

def bbox_to_yolo(x1, y1, x2, y2, tile_w, tile_h):
    x_center = (x1 + x2) / 2 / tile_w
    y_center = (y1 + y2) / 2 / tile_h
    w = (x2 - x1) / tile_w
    h = (y2 - y1) / tile_h
    return x_center, y_center, w, h

# Boucle sur train et val
for split in splits:
    input_img_dir = os.path.join(input_root, f"images/{split}")
    input_lbl_dir = os.path.join(input_root, f"labels/{split}")
    output_img_dir = os.path.join(output_root, f"images/{split}")
    output_lbl_dir = os.path.join(output_root, f"labels/{split}")

    os.makedirs(output_img_dir, exist_ok=True)
    os.makedirs(output_lbl_dir, exist_ok=True)

    for filename in os.listdir(input_img_dir):
        if not filename.lower().endswith(('.jpg', '.png')):
            continue

        basename = os.path.splitext(filename)[0]
        img_path = os.path.join(input_img_dir, filename)
        label_path = os.path.join(input_lbl_dir, f"{basename}.txt")

        img = cv2.imread(img_path)
        img_h, img_w = img.shape[:2]

        annotations = []
        if os.path.exists(label_path):
            with open(label_path, "r") as f:
                for line in f.readlines():
                    parts = line.strip().split()
                    if len(parts) == 5:
                        cls, xc, yc, w, h = map(float, parts)
                        annotations.append((cls, *yolo_to_bbox(xc, yc, w, h, img_w, img_h)))

        step = tile_size - overlap
        tile_id = 0

        for y in range(0, img_h, step):
            for x in range(0, img_w, step):
                tile = img[y:y + tile_size, x:x + tile_size]
                tile_h, tile_w = tile.shape[:2]

                if tile_h < tile_size or tile_w < tile_size:
                    continue

                tile_filename = f"{basename}_{tile_id}.jpg"
                label_filename = f"{basename}_{tile_id}.txt"
                tile_id += 1

                cv2.imwrite(os.path.join(output_img_dir, tile_filename), tile)

                new_annots = []
                for cls, x1, y1, x2, y2 in annotations:
                    if x1 >= x + tile_size or x2 <= x or y1 >= y + tile_size or y2 <= y:
                        continue

                    bx1 = max(0, x1 - x)
                    by1 = max(0, y1 - y)
                    bx2 = min(tile_size, x2 - x)
                    by2 = min(tile_size, y2 - y)

                    if bx2 - bx1 < 5 or by2 - by1 < 5:
                        continue

                    x_c, y_c, w, h = bbox_to_yolo(bx1, by1, bx2, by2, tile_size, tile_size)
                    new_annots.append(f"{int(cls)} {x_c:.6f} {y_c:.6f} {w:.6f} {h:.6f}")

                with open(os.path.join(output_lbl_dir, label_filename), "w") as f:
                    f.write("\n".join(new_annots))

    print(f"✅ Split terminé pour '{split}' — {len(os.listdir(output_img_dir))} tuiles générées")
# Out:
# ✅ Split terminé pour 'train' — 4524 tuiles générées
# ✅ Split terminé pour 'val' — 412 tuiles générées

# %% [markdown]
# # Génération des YAML

# %% [markdown]
# Dynamique :

# %%
# Chemin vers le fichier obj.names exporté par CVAT (modifie si besoin)
obj_names_path = "/content/custom_data_raw/obj.names"

# Lire les noms de classes depuis obj.names
with open(obj_names_path, 'r') as f:
    class_names = [line.strip() for line in f if line.strip()]

# Générer le contenu du fichier YAML avec les augmentations de couleur
yaml_content = f"""
path: {base_split_path}
train: images/train
val: images/val
nc: {len(class_names)}
names: {class_names}
augment: True  # Activer l'augmentation des données
auto_augment: albumentations



# weights: [0.9, 0.1]  # Exemple de pondération si olive est trop présente
"""


# Écriture du fichier data.yaml
with open(f"{base_path}/data.yaml", "w") as f:
    f.write(yaml_content.strip())

with open(f"{base_split_path}/data.yaml", "w") as f:
    f.write(yaml_content.strip())

print(" Fichier data.yaml généré automatiquement :")
print(yaml_content)
# Out:
#  Fichier data.yaml généré automatiquement :
#
# path: /content/split_custom_data
# train: images/train
# val: images/val
# nc: 2
# names: ['olive', 'potential_olive']
# augment: True  # Activer l'augmentation des données
# auto_augment: albumentations
#
#
#
# # weights: [0.9, 0.1]  # Exemple de pondération si olive est trop présente

# %%
custom_train_cfg = """
# train_custom.yaml — Configuration d'entraînement pour YOLOv8

# Chemins
data: /content/split_custom_data/data.yaml
model: yolov8m.pt
# model: yolo11x.pt

# Entraînement
epochs: 50
batch: 16
imgsz: 320
# device: 0

# Hyperparamètres généraux
optimizer: SGD
lr0: 0.01
lrf: 0.01




# Augmentations géométriques
degrees: 00.0
translate: 0.0
scale: 0.5
shear: 0.0
perspective: 0.0
flipud: 0.0
fliplr: 0.5

# Augmentations de couleur (adapté olives/feuillage)
hsv_h: 0.02
hsv_s: 0.6
hsv_v: 0.5

# Avancées
mosaic: 0.3
mixup: 0.1
copy_paste: 0.6

# auto_augment: randaugment
auto_augment: albumentations

"""

# Écriture du fichier YAML
with open("/content/custom_data/train_custom.yaml", "w") as f:
    f.write(custom_train_cfg.strip())

print("✅ Fichier train_custom.yaml généré.")

with open(f"/content/split_custom_data/train_custom.yaml", "w") as f:
    f.write(custom_train_cfg.strip())

print("✅ Fichier train_custom.yaml généré.")
# Out:
# ✅ Fichier train_custom.yaml généré.
# ✅ Fichier train_custom.yaml généré.

# %% [markdown]
# ## Vérification des labels et autres

# %%
import os
from collections import Counter

# Dictionnaire des classes : adapte-le si jamais tu changes l'ordre ou les noms
class_names = {
    '0': 'olive',
    '1': 'potential_olive'
}

def analyze_labels(labels_dir):
    label_counts = Counter()

    for split in ['train', 'val']:
        dir_path = os.path.join(labels_dir, split)
        for file in os.listdir(dir_path):
            if file.endswith('.txt'):
                with open(os.path.join(dir_path, file), 'r') as f:
                    for line in f:
                        if line.strip():
                            class_id = line.strip().split()[0]
                            label_counts[class_id] += 1

    print(" Résumé des classes dans les annotations :\n")
    for class_id, count in label_counts.items():
        class_name = class_names.get(class_id, " Inconnu")
        print(f"Classe {class_id} ({class_name}) → {count} objets")

    # Alerte pour les classes non attendues
    for cid in label_counts:
        if cid not in class_names:
            print(f"\n ID inattendu détecté : {cid}")

# Appel de la fonction
analyze_labels(f"{base_split_path}/labels")
# Out:
#  Résumé des classes dans les annotations :
#
# Classe 0 (olive) → 6219 objets
# Classe 1 (potential_olive) → 112 objets

# %% [markdown]
# # Train

# %% [markdown]
# - Changer le nombre d'epochs : Avec seulement 6 images et un grand déséquilibre, 10 epochs peuvent ne pas être suffisants. Essaie d'augmenter le nombre d'epochs (par exemple, à 50 ou 100) pour donner au modèle plus de temps pour apprendre.
#
# - Réduire le imgsz : La taille des images peut avoir un impact sur l'entraînement. Si les images sont petites (moins de détails), une taille de 320x320 ou 416x416 pourrait mieux fonctionner qu'une taille de 640x640, qui peut être plus difficile à traiter.

# %%
# !yolo task=detect mode=train cfg={base_split_path}/train_custom.yaml
# Out:
# Overriding /usr/local/lib/python3.11/dist-packages/ultralytics/cfg/default.yaml with /content/split_custom_data/train_custom.yaml
# WARNING ⚠️ 'mode' argument is missing. Valid modes are frozenset({'export', 'track', 'train', 'benchmark', 'val', 'predict'}). Using default 'mode=train'.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8m.pt to 'yolov8m.pt'...
# 100% 49.7M/49.7M [00:00<00:00, 308MB/s]
# Ultralytics 8.3.129 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=albumentations, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.6, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/split_custom_data/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.02, hsv_s=0.6, hsv_v=0.5, imgsz=320, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.1, mode=train, model=yolov8m.pt, momentum=0.937, mosaic=0.3, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=SGD, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.0, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 88.4MB/s]
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
#   8                  -1  2   3985920  ultralytics.nn.modules.block.C2f             [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  2   1993728  ultralytics.nn.modules.block.C2f             [960, 384, 2]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  2    517632  ultralytics.nn.modules.block.C2f             [576, 192, 2]
#  16                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  2   1846272  ultralytics.nn.modules.block.C2f             [576, 384, 2]
#  19                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  2   4207104  ultralytics.nn.modules.block.C2f             [960, 576, 2]
#  22        [15, 18, 21]  1   3776854  ultralytics.nn.modules.head.Detect           [2, [192, 384, 576]]
# Model summary: 169 layers, 25,857,478 parameters, 25,857,462 gradients, 79.1 GFLOPs
#
# Transferred 469/475 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100% 5.35M/5.35M [00:00<00:00, 305MB/s]
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1594.5±733.3 MB/s, size: 46.0 KB)
# train: Scanning /content/split_custom_data/labels/train... 4524 images, 2969 backgrounds, 0 corrupt: 100% 4524/4524 [00:01<00:00, 3438.33it/s]
# train: New cache created: /content/split_custom_data/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 772.3±440.8 MB/s, size: 32.9 KB)
# val: Scanning /content/split_custom_data/labels/val... 412 images, 220 backgrounds, 0 corrupt: 100% 412/412 [00:00<00:00, 1391.92it/s]
# val: New cache created: /content/split_custom_data/labels/val.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: SGD(lr=0.01, momentum=0.937) with parameter groups 77 weight(decay=0.0), 84 weight(decay=0.0005), 83 bias(decay=0.0)
# Image sizes 320 train, 320 val
# Using 2 dataloader workers
# Logging results to runs/detect/train
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      1.88G      2.202      3.409       1.62         17        320: 100% 283/283 [00:50<00:00,  5.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:03<00:00,  3.99it/s]
#                    all        412        701      0.835      0.248      0.282      0.182
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      2.23G      2.073      2.858      1.507          5        320: 100% 283/283 [00:49<00:00,  5.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  6.41it/s]
#                    all        412        701     0.0886      0.202      0.135     0.0783
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      2.28G      2.401      3.094       1.62         43        320: 100% 283/283 [00:48<00:00,  5.87it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  5.94it/s]
#                    all        412        701      0.668     0.0853     0.0802     0.0408
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      2.33G      2.589      3.382      1.689         15        320: 100% 283/283 [00:47<00:00,  5.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  5.97it/s]
#                    all        412        701     0.0274     0.0555     0.0122    0.00478
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50       2.5G      2.545      3.214      1.649          9        320: 100% 283/283 [00:48<00:00,  5.89it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  5.86it/s]
#                    all        412        701      0.283      0.135      0.169     0.0981
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      2.55G      2.482      3.162      1.616         32        320: 100% 283/283 [00:48<00:00,  5.89it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  4.65it/s]
#                    all        412        701      0.159      0.118      0.116     0.0713
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      2.59G      2.445      3.051      1.615         17        320: 100% 283/283 [00:48<00:00,  5.89it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  6.04it/s]
#                    all        412        701      0.294      0.186      0.225      0.122
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      2.64G      2.365      3.044      1.568         14        320: 100% 283/283 [00:48<00:00,  5.89it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  5.78it/s]
#                    all        412        701      0.284      0.181      0.214      0.125
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      2.82G      2.369      2.956      1.567         10        320: 100% 283/283 [00:49<00:00,  5.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  5.79it/s]
#                    all        412        701      0.274      0.175      0.193      0.113
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      2.86G      2.271      2.905      1.514          7        320: 100% 283/283 [00:48<00:00,  5.86it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  6.09it/s]
#                    all        412        701      0.336      0.193      0.238      0.141
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      2.91G      2.269      2.902       1.53         21        320: 100% 283/283 [00:49<00:00,  5.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  5.87it/s]
#                    all        412        701      0.367      0.164      0.233      0.134
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      3.09G      2.212      2.756      1.515         11        320: 100% 283/283 [00:48<00:00,  5.88it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  5.98it/s]
#                    all        412        701      0.328      0.209      0.245      0.143
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      3.13G      2.242       2.81      1.476         13        320: 100% 283/283 [00:47<00:00,  5.93it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  5.91it/s]
#                    all        412        701      0.316      0.223      0.258      0.154
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      3.18G      2.223      2.743      1.482          8        320: 100% 283/283 [00:48<00:00,  5.89it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  5.80it/s]
#                    all        412        701      0.355       0.21       0.27      0.157
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      3.27G      2.193      2.765      1.488         27        320: 100% 283/283 [00:48<00:00,  5.86it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  5.92it/s]
#                    all        412        701      0.379      0.221      0.283      0.173
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      3.45G      2.223      2.824       1.48         30        320: 100% 283/283 [00:48<00:00,  5.78it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  6.06it/s]
#                    all        412        701      0.424      0.166      0.253      0.147
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      3.72G      2.106      2.661      1.439         10        320: 100% 283/283 [00:48<00:00,  5.88it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  5.84it/s]
#                    all        412        701      0.321      0.262      0.301      0.181
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      3.77G       2.12      2.749      1.446         22        320: 100% 283/283 [00:47<00:00,  5.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  5.86it/s]
#                    all        412        701      0.835      0.287       0.32      0.194
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      3.81G      2.094       2.59      1.436          7        320: 100% 283/283 [00:47<00:00,  5.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  5.80it/s]
#                    all        412        701      0.856      0.258      0.307      0.191
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      3.86G      2.044      2.531      1.401         14        320: 100% 283/283 [00:48<00:00,  5.82it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  6.15it/s]
#                    all        412        701      0.898       0.24      0.302      0.191
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      4.13G      2.042      2.532      1.419          3        320: 100% 283/283 [00:48<00:00,  5.89it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  5.97it/s]
#                    all        412        701      0.845      0.263      0.309      0.187
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      4.17G      2.037      2.578       1.41          7        320: 100% 283/283 [00:47<00:00,  5.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  5.97it/s]
#                    all        412        701      0.871      0.298      0.337      0.208
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      4.21G      1.985       2.55      1.394         17        320: 100% 283/283 [00:48<00:00,  5.89it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  5.95it/s]
#                    all        412        701       0.86       0.26      0.313      0.196
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      4.26G      1.983      2.538      1.391          6        320: 100% 283/283 [00:48<00:00,  5.89it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  6.02it/s]
#                    all        412        701      0.872      0.281      0.337      0.211
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      4.53G      1.927      2.515      1.362         21        320: 100% 283/283 [00:48<00:00,  5.82it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  6.00it/s]
#                    all        412        701      0.864       0.27      0.324      0.198
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      4.57G       1.98      2.461      1.388         21        320: 100% 283/283 [00:47<00:00,  5.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  5.88it/s]
#                    all        412        701      0.865      0.271      0.325        0.2
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      4.62G      1.899      2.358      1.362         15        320: 100% 283/283 [00:47<00:00,  5.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  5.87it/s]
#                    all        412        701      0.854      0.283      0.328      0.212
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      4.66G      1.903       2.41      1.335         11        320: 100% 283/283 [00:47<00:00,  5.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  5.91it/s]
#                    all        412        701      0.865      0.294       0.34      0.221
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      4.84G      1.867       2.36      1.341          4        320: 100% 283/283 [00:48<00:00,  5.88it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  5.90it/s]
#                    all        412        701      0.889      0.274      0.335      0.208
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      4.88G      1.853      2.361      1.332          5        320: 100% 283/283 [00:48<00:00,  5.82it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  5.95it/s]
#                    all        412        701      0.883      0.297      0.349      0.223
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      4.93G      1.931      2.504      1.368         23        320: 100% 283/283 [00:47<00:00,  5.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  5.90it/s]
#                    all        412        701       0.87      0.284      0.338      0.217
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50       5.2G      1.879      2.425      1.321         13        320: 100% 283/283 [00:48<00:00,  5.89it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  5.79it/s]
#                    all        412        701      0.862      0.279       0.34      0.211
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      5.24G      1.926      2.454      1.344         18        320: 100% 283/283 [00:48<00:00,  5.78it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  5.68it/s]
#                    all        412        701      0.857      0.308      0.342      0.217
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      5.29G      1.837      2.274      1.319         26        320: 100% 283/283 [00:49<00:00,  5.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  5.93it/s]
#                    all        412        701      0.895      0.305      0.356      0.223
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      5.33G      1.786      2.239      1.313         26        320: 100% 283/283 [00:48<00:00,  5.88it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  5.94it/s]
#                    all        412        701      0.865      0.314      0.348      0.223
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50       5.6G      1.819      2.349      1.303         33        320: 100% 283/283 [00:48<00:00,  5.84it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  5.88it/s]
#                    all        412        701      0.863      0.311      0.348       0.22
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      5.65G       1.79      2.362      1.301          9        320: 100% 283/283 [00:47<00:00,  5.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  5.80it/s]
#                    all        412        701      0.861      0.286      0.328      0.206
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      5.69G      1.771      2.243      1.297         10        320: 100% 283/283 [00:48<00:00,  5.86it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  5.53it/s]
#                    all        412        701      0.877      0.303      0.348       0.22
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      5.74G      1.759      2.267      1.291          7        320: 100% 283/283 [00:48<00:00,  5.78it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  5.85it/s]
#                    all        412        701       0.88      0.315      0.361      0.227
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      6.01G      1.753      2.226      1.295         19        320: 100% 283/283 [00:48<00:00,  5.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  5.93it/s]
#                    all        412        701      0.876      0.308      0.353      0.222
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      6.05G      1.696       2.26      1.271          7        320: 100% 283/283 [00:48<00:00,  5.87it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  5.94it/s]
#                    all        412        701      0.896      0.309      0.358       0.23
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50       6.1G      1.694      2.313      1.278          8        320: 100% 283/283 [00:47<00:00,  5.94it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  5.75it/s]
#                    all        412        701      0.886      0.308      0.353      0.231
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      6.14G      1.675      2.274      1.268         20        320: 100% 283/283 [00:47<00:00,  5.99it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  5.30it/s]
#                    all        412        701      0.903        0.3      0.353      0.225
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      6.41G      1.649        2.2      1.261          4        320: 100% 283/283 [00:47<00:00,  5.95it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  4.95it/s]
#                    all        412        701      0.882      0.313      0.355      0.221
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      6.45G      1.642      2.297      1.262         11        320: 100% 283/283 [00:47<00:00,  6.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  4.79it/s]
#                    all        412        701      0.883      0.316       0.36       0.23
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50       6.5G      1.605      2.204      1.246         19        320: 100% 283/283 [00:46<00:00,  6.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  4.43it/s]
#                    all        412        701      0.881      0.324       0.36      0.228
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      6.54G      1.634      2.208       1.26         20        320: 100% 283/283 [00:47<00:00,  6.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  4.78it/s]
#                    all        412        701      0.379      0.319      0.367      0.236
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      6.81G      1.624      2.167      1.255         18        320: 100% 283/283 [00:48<00:00,  5.83it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  5.50it/s]
#                    all        412        701      0.882      0.304      0.357      0.225
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      6.86G      1.567      2.186      1.233          6        320: 100% 283/283 [00:47<00:00,  5.94it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  5.84it/s]
#                    all        412        701      0.883      0.317      0.365      0.231
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50       6.9G      1.567      2.097      1.227          4        320: 100% 283/283 [00:47<00:00,  5.93it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:02<00:00,  5.98it/s]
#                    all        412        701      0.878      0.322      0.361       0.23
#
# 50 epochs completed in 0.709 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 52.0MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 52.0MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics 8.3.129 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 92 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 13/13 [00:03<00:00,  4.08it/s]
#                    all        412        701      0.379       0.32      0.367      0.236
#                  olive        189        694      0.758       0.64       0.73       0.47
#        potential_olive          5          7          0          0    0.00275    0.00199
# Speed: 0.1ms preprocess, 2.7ms inference, 0.0ms loss, 1.9ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
#yolo task=detect mode=train model=yolo11n.pt data={base_path}/data.yaml hyp={base_path}/hyp.yaml epochs=100 imgsz=640 device=0

# %%
import glob
from IPython.display import Image, display

# %%
Image(filename='runs/detect/train/confusion_matrix.png', width=600)

# %%
Image(filename='runs/detect/train/results.png', width=600)

# %% [markdown]
# # Validation

# %%
from ultralytics import YOLO

# Charger le modèle entraîné
model = YOLO("runs/detect/train/weights/best.pt")

# Évaluer sur le dataset de validation
metrics = model.val(data="/content/split_custom_data/data.yaml", split="val", verbose=False)

# Accès aux métriques par classe
names = model.names  # dict {class_id: name}
precision_per_class = metrics.box.p  # Précision par classe
recall_per_class = metrics.box.r  # Rappel par classe
map50_per_class = metrics.box.ap50  # mAP à IoU de 0.5 par classe
map_per_class = metrics.box.ap  # mAP à IoU de 0.5-0.95 par classe

# Exemple : récupérer les métriques de la classe "olive"
class_name = "olive"
class_id = list(names.values()).index(class_name)

print(f"Métriques pour la classe '{class_name}':")
print(f" - Précision : {precision_per_class[class_id]:.3f}")
print(f" - Rappel    : {recall_per_class[class_id]:.3f}")
print(f" - mAP@50    : {map50_per_class[class_id]:.3f}")
print(f" - mAP@50-95 : {map_per_class[class_id]:.3f}")
# Out:
# Ultralytics 8.3.129 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 92 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1980.9±765.5 MB/s, size: 53.6 KB)
# val: Scanning /content/split_custom_data/labels/val.cache... 412 images, 220 backgrounds, 0 corrupt: 100%|██████████| 412/412 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:04<00:00,  6.42it/s]
#                    all        412        701      0.379       0.32      0.366      0.236
# Speed: 0.5ms preprocess, 5.8ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to runs/detect/val
# Métriques pour la classe 'olive':
#  - Précision : 0.758
#  - Rappel    : 0.640
#  - mAP@50    : 0.730
#  - mAP@50-95 : 0.470

# %% [markdown]
# En modifiant conf

# %%
from ultralytics import YOLO
from pathlib import Path
import cv2
import os
from ultralytics.utils.metrics import bbox_iou

# 🔧 Paramètres
model_path = "runs/detect/train/weights/best.pt"
data_path = "/content/split_custom_data/data.yaml"
val_images_dir = "/content/split_custom_data/images/val"
conf_threshold = 0.1  # 🔁 MODIFIE ici le seuil de confiance
target_class = "olive"
iou_threshold = 0.5  # pour comptage TP/FN

# 📦 Charger modèle + noms des classes
model = YOLO(model_path)
names = model.names
target_id = list(names.values()).index(target_class)

# 📂 Liste des fichiers image de validation
image_paths = list(Path(val_images_dir).rglob("*.jpg")) + list(Path(val_images_dir).rglob("*.png"))

# 🔢 Compteurs
TP, FP, FN = 0, 0, 0

# 🔍 Parcourir les images
import torch

# 🔍 Parcourir les images
for img_path in image_paths:
    results = model.predict(source=str(img_path), conf=conf_threshold, iou=iou_threshold, verbose=False)[0]

    # Prédictions pour la classe cible
    preds = [b for b in results.boxes.data.cpu().numpy() if int(b[5]) == target_id]
    pred_boxes = [b[:4] for b in preds]  # x1, y1, x2, y2

    # Ground truth : via les annotations val
    label_path = str(img_path).replace("/images/", "/labels/").rsplit(".", 1)[0] + ".txt"
    gt_boxes = []
    if os.path.exists(label_path):
        with open(label_path, "r") as f:
            for line in f:
                cls, x, y, w, h = map(float, line.strip().split())
                if int(cls) == target_id:
                    # YOLO format -> (x1, y1, x2, y2)
                    img = cv2.imread(str(img_path))
                    H, W = img.shape[:2]
                    cx, cy, bw, bh = x * W, y * H, w * W, h * H
                    x1 = cx - bw / 2
                    y1 = cy - bh / 2
                    x2 = cx + bw / 2
                    y2 = cy + bh / 2
                    gt_boxes.append([x1, y1, x2, y2])

    # 🧠 Matching GT ↔ prédictions
    matched_gt = set()
    for pred_box in pred_boxes:
        matched = False
        for i, gt_box in enumerate(gt_boxes):
            # Convertir en tensor avant de calculer l'IoU
            pred_box_tensor = torch.tensor(pred_box).unsqueeze(0)  # Convertir en tensor
            gt_box_tensor = torch.tensor(gt_box).unsqueeze(0)  # Convertir en tensor
            iou = bbox_iou(pred_box_tensor, gt_box_tensor)[0]  # Calcul de l'IoU
            if iou > iou_threshold and i not in matched_gt:
                TP += 1
                matched_gt.add(i)
                matched = True
                break
        if not matched:
            FP += 1
    FN += len(gt_boxes) - len(matched_gt)

# 📊 Calcul des métriques
precision = TP / (TP + FP) if (TP + FP) > 0 else 0
recall = TP / (TP + FN) if (TP + FN) > 0 else 0

print(f"\n🔎 Résultats pour la classe '{target_class}' (seuil conf = {conf_threshold}):")
print(f" - Vrais positifs (TP) : {TP}")
print(f" - Faux positifs (FP)  : {FP}")
print(f" - Faux négatifs (FN)  : {FN}")
print(f" - Précision           : {precision:.3f}")
print(f" - Rappel              : {recall:.3f}")
# Out:
# 🔎 Résultats pour la classe 'olive' (seuil conf = 0.1):
#  - Vrais positifs (TP) : 490
#  - Faux positifs (FP)  : 144
#  - Faux négatifs (FN)  : 204
#  - Précision           : 0.773
#  - Rappel              : 0.706

# %% [markdown]
# # Predict

# %% [markdown]
# - Vérifie les prédictions avec conf=0.5 ou plus bas : Parfois, si le modèle est trop conservateur, il ne détecte rien parce qu'il exige une très forte confiance. Essaie de réduire le seuil de confiance lors de la prédiction.

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt source={base_split_path}/images/val conf=0.5 save=True device=0
# Out:
# Ultralytics 8.3.129 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 92 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/412 /content/split_custom_data/images/val/B112_0.jpg: 320x320 (no detections), 15.8ms
# image 2/412 /content/split_custom_data/images/val/B112_1.jpg: 320x320 (no detections), 15.8ms
# image 3/412 /content/split_custom_data/images/val/B112_10.jpg: 320x320 (no detections), 15.8ms
# image 4/412 /content/split_custom_data/images/val/B112_11.jpg: 320x320 (no detections), 15.7ms
# image 5/412 /content/split_custom_data/images/val/B112_12.jpg: 320x320 (no detections), 15.7ms
# image 6/412 /content/split_custom_data/images/val/B112_13.jpg: 320x320 (no detections), 15.8ms
# image 7/412 /content/split_custom_data/images/val/B112_14.jpg: 320x320 (no detections), 15.8ms
# image 8/412 /content/split_custom_data/images/val/B112_15.jpg: 320x320 (no detections), 15.7ms
# image 9/412 /content/split_custom_data/images/val/B112_16.jpg: 320x320 (no detections), 15.8ms
# image 10/412 /content/split_custom_data/images/val/B112_17.jpg: 320x320 5 olives, 15.7ms
# image 11/412 /content/split_custom_data/images/val/B112_18.jpg: 320x320 (no detections), 11.1ms
# image 12/412 /content/split_custom_data/images/val/B112_19.jpg: 320x320 (no detections), 10.9ms
# image 13/412 /content/split_custom_data/images/val/B112_2.jpg: 320x320 (no detections), 10.9ms
# image 14/412 /content/split_custom_data/images/val/B112_20.jpg: 320x320 (no detections), 10.9ms
# image 15/412 /content/split_custom_data/images/val/B112_21.jpg: 320x320 (no detections), 10.9ms
# image 16/412 /content/split_custom_data/images/val/B112_22.jpg: 320x320 (no detections), 10.9ms
# image 17/412 /content/split_custom_data/images/val/B112_23.jpg: 320x320 (no detections), 10.9ms
# image 18/412 /content/split_custom_data/images/val/B112_24.jpg: 320x320 (no detections), 10.9ms
# image 19/412 /content/split_custom_data/images/val/B112_25.jpg: 320x320 (no detections), 10.9ms
# image 20/412 /content/split_custom_data/images/val/B112_26.jpg: 320x320 (no detections), 10.9ms
# image 21/412 /content/split_custom_data/images/val/B112_27.jpg: 320x320 (no detections), 10.9ms
# image 22/412 /content/split_custom_data/images/val/B112_28.jpg: 320x320 (no detections), 10.9ms
# image 23/412 /content/split_custom_data/images/val/B112_29.jpg: 320x320 1 olive, 10.9ms
# image 24/412 /content/split_custom_data/images/val/B112_3.jpg: 320x320 1 olive, 11.0ms
# image 25/412 /content/split_custom_data/images/val/B112_30.jpg: 320x320 (no detections), 11.0ms
# image 26/412 /content/split_custom_data/images/val/B112_31.jpg: 320x320 (no detections), 10.9ms
# image 27/412 /content/split_custom_data/images/val/B112_32.jpg: 320x320 (no detections), 10.9ms
# image 28/412 /content/split_custom_data/images/val/B112_33.jpg: 320x320 (no detections), 11.0ms
# image 29/412 /content/split_custom_data/images/val/B112_34.jpg: 320x320 (no detections), 10.9ms
# image 30/412 /content/split_custom_data/images/val/B112_35.jpg: 320x320 (no detections), 10.9ms
# image 31/412 /content/split_custom_data/images/val/B112_36.jpg: 320x320 (no detections), 7.7ms
# image 32/412 /content/split_custom_data/images/val/B112_37.jpg: 320x320 (no detections), 7.6ms
# image 33/412 /content/split_custom_data/images/val/B112_38.jpg: 320x320 (no detections), 7.6ms
# image 34/412 /content/split_custom_data/images/val/B112_39.jpg: 320x320 (no detections), 7.6ms
# image 35/412 /content/split_custom_data/images/val/B112_4.jpg: 320x320 (no detections), 7.6ms
# image 36/412 /content/split_custom_data/images/val/B112_40.jpg: 320x320 (no detections), 7.6ms
# image 37/412 /content/split_custom_data/images/val/B112_41.jpg: 320x320 (no detections), 7.6ms
# image 38/412 /content/split_custom_data/images/val/B112_42.jpg: 320x320 (no detections), 7.7ms
# image 39/412 /content/split_custom_data/images/val/B112_43.jpg: 320x320 (no detections), 7.5ms
# image 40/412 /content/split_custom_data/images/val/B112_44.jpg: 320x320 (no detections), 7.5ms
# image 41/412 /content/split_custom_data/images/val/B112_45.jpg: 320x320 (no detections), 7.5ms
# image 42/412 /content/split_custom_data/images/val/B112_46.jpg: 320x320 (no detections), 7.4ms
# image 43/412 /content/split_custom_data/images/val/B112_47.jpg: 320x320 (no detections), 7.4ms
# image 44/412 /content/split_custom_data/images/val/B112_48.jpg: 320x320 (no detections), 7.4ms
# image 45/412 /content/split_custom_data/images/val/B112_49.jpg: 320x320 (no detections), 7.3ms
# image 46/412 /content/split_custom_data/images/val/B112_5.jpg: 320x320 (no detections), 7.4ms
# image 47/412 /content/split_custom_data/images/val/B112_50.jpg: 320x320 (no detections), 8.3ms
# image 48/412 /content/split_custom_data/images/val/B112_51.jpg: 320x320 (no detections), 7.3ms
# image 49/412 /content/split_custom_data/images/val/B112_52.jpg: 320x320 (no detections), 7.3ms
# image 50/412 /content/split_custom_data/images/val/B112_53.jpg: 320x320 (no detections), 7.4ms
# image 51/412 /content/split_custom_data/images/val/B112_54.jpg: 320x320 (no detections), 7.4ms
# image 52/412 /content/split_custom_data/images/val/B112_55.jpg: 320x320 (no detections), 7.5ms
# image 53/412 /content/split_custom_data/images/val/B112_56.jpg: 320x320 (no detections), 7.5ms
# image 54/412 /content/split_custom_data/images/val/B112_57.jpg: 320x320 (no detections), 7.5ms
# image 55/412 /content/split_custom_data/images/val/B112_58.jpg: 320x320 (no detections), 10.6ms
# image 56/412 /content/split_custom_data/images/val/B112_59.jpg: 320x320 (no detections), 9.2ms
# image 57/412 /content/split_custom_data/images/val/B112_6.jpg: 320x320 (no detections), 7.4ms
# image 58/412 /content/split_custom_data/images/val/B112_7.jpg: 320x320 (no detections), 7.4ms
# image 59/412 /content/split_custom_data/images/val/B112_8.jpg: 320x320 (no detections), 7.3ms
# image 60/412 /content/split_custom_data/images/val/B112_9.jpg: 320x320 (no detections), 7.2ms
# image 61/412 /content/split_custom_data/images/val/IMG_20221123_154036_0.jpg: 320x320 (no detections), 7.2ms
# image 62/412 /content/split_custom_data/images/val/IMG_20221123_154036_1.jpg: 320x320 (no detections), 7.2ms
# image 63/412 /content/split_custom_data/images/val/IMG_20221123_154036_10.jpg: 320x320 (no detections), 8.2ms
# image 64/412 /content/split_custom_data/images/val/IMG_20221123_154036_11.jpg: 320x320 (no detections), 9.7ms
# image 65/412 /content/split_custom_data/images/val/IMG_20221123_154036_12.jpg: 320x320 (no detections), 7.4ms
# image 66/412 /content/split_custom_data/images/val/IMG_20221123_154036_13.jpg: 320x320 (no detections), 7.7ms
# image 67/412 /content/split_custom_data/images/val/IMG_20221123_154036_14.jpg: 320x320 (no detections), 7.5ms
# image 68/412 /content/split_custom_data/images/val/IMG_20221123_154036_15.jpg: 320x320 (no detections), 9.0ms
# image 69/412 /content/split_custom_data/images/val/IMG_20221123_154036_16.jpg: 320x320 (no detections), 13.0ms
# image 70/412 /content/split_custom_data/images/val/IMG_20221123_154036_17.jpg: 320x320 (no detections), 13.0ms
# image 71/412 /content/split_custom_data/images/val/IMG_20221123_154036_18.jpg: 320x320 2 olives, 7.0ms
# image 72/412 /content/split_custom_data/images/val/IMG_20221123_154036_19.jpg: 320x320 (no detections), 8.5ms
# image 73/412 /content/split_custom_data/images/val/IMG_20221123_154036_2.jpg: 320x320 (no detections), 7.2ms
# image 74/412 /content/split_custom_data/images/val/IMG_20221123_154036_20.jpg: 320x320 (no detections), 7.2ms
# image 75/412 /content/split_custom_data/images/val/IMG_20221123_154036_21.jpg: 320x320 (no detections), 7.2ms
# image 76/412 /content/split_custom_data/images/val/IMG_20221123_154036_22.jpg: 320x320 (no detections), 7.2ms
# image 77/412 /content/split_custom_data/images/val/IMG_20221123_154036_23.jpg: 320x320 (no detections), 7.2ms
# image 78/412 /content/split_custom_data/images/val/IMG_20221123_154036_24.jpg: 320x320 1 olive, 7.2ms
# image 79/412 /content/split_custom_data/images/val/IMG_20221123_154036_25.jpg: 320x320 1 olive, 7.2ms
# image 80/412 /content/split_custom_data/images/val/IMG_20221123_154036_26.jpg: 320x320 2 olives, 7.2ms
# image 81/412 /content/split_custom_data/images/val/IMG_20221123_154036_27.jpg: 320x320 (no detections), 7.5ms
# image 82/412 /content/split_custom_data/images/val/IMG_20221123_154036_28.jpg: 320x320 1 olive, 9.0ms
# image 83/412 /content/split_custom_data/images/val/IMG_20221123_154036_29.jpg: 320x320 1 olive, 7.4ms
# image 84/412 /content/split_custom_data/images/val/IMG_20221123_154036_3.jpg: 320x320 (no detections), 7.4ms
# image 85/412 /content/split_custom_data/images/val/IMG_20221123_154036_30.jpg: 320x320 (no detections), 7.3ms
# image 86/412 /content/split_custom_data/images/val/IMG_20221123_154036_31.jpg: 320x320 (no detections), 7.3ms
# image 87/412 /content/split_custom_data/images/val/IMG_20221123_154036_32.jpg: 320x320 (no detections), 7.2ms
# image 88/412 /content/split_custom_data/images/val/IMG_20221123_154036_33.jpg: 320x320 (no detections), 8.2ms
# image 89/412 /content/split_custom_data/images/val/IMG_20221123_154036_34.jpg: 320x320 (no detections), 7.3ms
# image 90/412 /content/split_custom_data/images/val/IMG_20221123_154036_35.jpg: 320x320 1 olive, 7.2ms
# image 91/412 /content/split_custom_data/images/val/IMG_20221123_154036_36.jpg: 320x320 3 olives, 8.3ms
# image 92/412 /content/split_custom_data/images/val/IMG_20221123_154036_37.jpg: 320x320 (no detections), 7.4ms
# image 93/412 /content/split_custom_data/images/val/IMG_20221123_154036_38.jpg: 320x320 2 olives, 7.4ms
# image 94/412 /content/split_custom_data/images/val/IMG_20221123_154036_39.jpg: 320x320 (no detections), 7.4ms
# image 95/412 /content/split_custom_data/images/val/IMG_20221123_154036_4.jpg: 320x320 (no detections), 7.4ms
# image 96/412 /content/split_custom_data/images/val/IMG_20221123_154036_40.jpg: 320x320 2 olives, 7.3ms
# image 97/412 /content/split_custom_data/images/val/IMG_20221123_154036_41.jpg: 320x320 1 olive, 7.2ms
# image 98/412 /content/split_custom_data/images/val/IMG_20221123_154036_42.jpg: 320x320 (no detections), 7.8ms
# image 99/412 /content/split_custom_data/images/val/IMG_20221123_154036_43.jpg: 320x320 1 olive, 7.4ms
# image 100/412 /content/split_custom_data/images/val/IMG_20221123_154036_44.jpg: 320x320 (no detections), 7.5ms
# image 101/412 /content/split_custom_data/images/val/IMG_20221123_154036_45.jpg: 320x320 1 olive, 7.5ms
# image 102/412 /content/split_custom_data/images/val/IMG_20221123_154036_46.jpg: 320x320 (no detections), 7.4ms
# image 103/412 /content/split_custom_data/images/val/IMG_20221123_154036_47.jpg: 320x320 1 olive, 7.3ms
# image 104/412 /content/split_custom_data/images/val/IMG_20221123_154036_48.jpg: 320x320 (no detections), 7.3ms
# image 105/412 /content/split_custom_data/images/val/IMG_20221123_154036_49.jpg: 320x320 1 olive, 7.2ms
# image 106/412 /content/split_custom_data/images/val/IMG_20221123_154036_5.jpg: 320x320 (no detections), 7.3ms
# image 107/412 /content/split_custom_data/images/val/IMG_20221123_154036_50.jpg: 320x320 (no detections), 7.3ms
# image 108/412 /content/split_custom_data/images/val/IMG_20221123_154036_51.jpg: 320x320 (no detections), 7.5ms
# image 109/412 /content/split_custom_data/images/val/IMG_20221123_154036_52.jpg: 320x320 2 olives, 7.6ms
# image 110/412 /content/split_custom_data/images/val/IMG_20221123_154036_53.jpg: 320x320 2 olives, 7.8ms
# image 111/412 /content/split_custom_data/images/val/IMG_20221123_154036_54.jpg: 320x320 (no detections), 8.6ms
# image 112/412 /content/split_custom_data/images/val/IMG_20221123_154036_55.jpg: 320x320 2 olives, 7.6ms
# image 113/412 /content/split_custom_data/images/val/IMG_20221123_154036_56.jpg: 320x320 2 olives, 7.5ms
# image 114/412 /content/split_custom_data/images/val/IMG_20221123_154036_57.jpg: 320x320 (no detections), 7.3ms
# image 115/412 /content/split_custom_data/images/val/IMG_20221123_154036_58.jpg: 320x320 (no detections), 7.4ms
# image 116/412 /content/split_custom_data/images/val/IMG_20221123_154036_59.jpg: 320x320 (no detections), 7.4ms
# image 117/412 /content/split_custom_data/images/val/IMG_20221123_154036_6.jpg: 320x320 (no detections), 7.7ms
# image 118/412 /content/split_custom_data/images/val/IMG_20221123_154036_60.jpg: 320x320 3 olives, 7.7ms
# image 119/412 /content/split_custom_data/images/val/IMG_20221123_154036_61.jpg: 320x320 1 olive, 7.8ms
# image 120/412 /content/split_custom_data/images/val/IMG_20221123_154036_62.jpg: 320x320 1 olive, 7.7ms
# image 121/412 /content/split_custom_data/images/val/IMG_20221123_154036_63.jpg: 320x320 1 olive, 7.6ms
# image 122/412 /content/split_custom_data/images/val/IMG_20221123_154036_64.jpg: 320x320 2 olives, 7.4ms
# image 123/412 /content/split_custom_data/images/val/IMG_20221123_154036_65.jpg: 320x320 (no detections), 7.6ms
# image 124/412 /content/split_custom_data/images/val/IMG_20221123_154036_66.jpg: 320x320 (no detections), 7.4ms
# image 125/412 /content/split_custom_data/images/val/IMG_20221123_154036_67.jpg: 320x320 1 olive, 10.9ms
# image 126/412 /content/split_custom_data/images/val/IMG_20221123_154036_68.jpg: 320x320 (no detections), 9.5ms
# image 127/412 /content/split_custom_data/images/val/IMG_20221123_154036_69.jpg: 320x320 (no detections), 7.3ms
# image 128/412 /content/split_custom_data/images/val/IMG_20221123_154036_7.jpg: 320x320 (no detections), 7.3ms
# image 129/412 /content/split_custom_data/images/val/IMG_20221123_154036_70.jpg: 320x320 (no detections), 7.6ms
# image 130/412 /content/split_custom_data/images/val/IMG_20221123_154036_71.jpg: 320x320 (no detections), 7.6ms
# image 131/412 /content/split_custom_data/images/val/IMG_20221123_154036_72.jpg: 320x320 1 olive, 7.6ms
# image 132/412 /content/split_custom_data/images/val/IMG_20221123_154036_73.jpg: 320x320 1 olive, 7.6ms
# image 133/412 /content/split_custom_data/images/val/IMG_20221123_154036_74.jpg: 320x320 (no detections), 7.5ms
# image 134/412 /content/split_custom_data/images/val/IMG_20221123_154036_75.jpg: 320x320 (no detections), 7.4ms
# image 135/412 /content/split_custom_data/images/val/IMG_20221123_154036_76.jpg: 320x320 (no detections), 8.3ms
# image 136/412 /content/split_custom_data/images/val/IMG_20221123_154036_77.jpg: 320x320 (no detections), 7.2ms
# image 137/412 /content/split_custom_data/images/val/IMG_20221123_154036_78.jpg: 320x320 (no detections), 7.3ms
# image 138/412 /content/split_custom_data/images/val/IMG_20221123_154036_79.jpg: 320x320 (no detections), 7.3ms
# image 139/412 /content/split_custom_data/images/val/IMG_20221123_154036_8.jpg: 320x320 (no detections), 7.4ms
# image 140/412 /content/split_custom_data/images/val/IMG_20221123_154036_80.jpg: 320x320 1 olive, 7.5ms
# image 141/412 /content/split_custom_data/images/val/IMG_20221123_154036_81.jpg: 320x320 (no detections), 7.6ms
# image 142/412 /content/split_custom_data/images/val/IMG_20221123_154036_82.jpg: 320x320 (no detections), 7.6ms
# image 143/412 /content/split_custom_data/images/val/IMG_20221123_154036_83.jpg: 320x320 (no detections), 7.8ms
# image 144/412 /content/split_custom_data/images/val/IMG_20221123_154036_84.jpg: 320x320 (no detections), 7.5ms
# image 145/412 /content/split_custom_data/images/val/IMG_20221123_154036_85.jpg: 320x320 (no detections), 7.5ms
# image 146/412 /content/split_custom_data/images/val/IMG_20221123_154036_86.jpg: 320x320 (no detections), 7.5ms
# image 147/412 /content/split_custom_data/images/val/IMG_20221123_154036_87.jpg: 320x320 (no detections), 7.9ms
# image 148/412 /content/split_custom_data/images/val/IMG_20221123_154036_9.jpg: 320x320 (no detections), 7.5ms
# image 149/412 /content/split_custom_data/images/val/IMG_20221123_155340_0.jpg: 320x320 (no detections), 7.5ms
# image 150/412 /content/split_custom_data/images/val/IMG_20221123_155340_1.jpg: 320x320 (no detections), 7.4ms
# image 151/412 /content/split_custom_data/images/val/IMG_20221123_155340_10.jpg: 320x320 1 olive, 7.8ms
# image 152/412 /content/split_custom_data/images/val/IMG_20221123_155340_11.jpg: 320x320 (no detections), 10.6ms
# image 153/412 /content/split_custom_data/images/val/IMG_20221123_155340_12.jpg: 320x320 (no detections), 7.5ms
# image 154/412 /content/split_custom_data/images/val/IMG_20221123_155340_13.jpg: 320x320 1 olive, 7.4ms
# image 155/412 /content/split_custom_data/images/val/IMG_20221123_155340_14.jpg: 320x320 (no detections), 7.5ms
# image 156/412 /content/split_custom_data/images/val/IMG_20221123_155340_15.jpg: 320x320 (no detections), 7.5ms
# image 157/412 /content/split_custom_data/images/val/IMG_20221123_155340_16.jpg: 320x320 1 olive, 7.6ms
# image 158/412 /content/split_custom_data/images/val/IMG_20221123_155340_17.jpg: 320x320 1 olive, 8.2ms
# image 159/412 /content/split_custom_data/images/val/IMG_20221123_155340_18.jpg: 320x320 1 olive, 11.4ms
# image 160/412 /content/split_custom_data/images/val/IMG_20221123_155340_19.jpg: 320x320 1 olive, 15.6ms
# image 161/412 /content/split_custom_data/images/val/IMG_20221123_155340_2.jpg: 320x320 1 olive, 7.2ms
# image 162/412 /content/split_custom_data/images/val/IMG_20221123_155340_20.jpg: 320x320 2 olives, 7.5ms
# image 163/412 /content/split_custom_data/images/val/IMG_20221123_155340_21.jpg: 320x320 (no detections), 7.1ms
# image 164/412 /content/split_custom_data/images/val/IMG_20221123_155340_22.jpg: 320x320 (no detections), 7.3ms
# image 165/412 /content/split_custom_data/images/val/IMG_20221123_155340_23.jpg: 320x320 (no detections), 7.4ms
# image 166/412 /content/split_custom_data/images/val/IMG_20221123_155340_24.jpg: 320x320 (no detections), 7.5ms
# image 167/412 /content/split_custom_data/images/val/IMG_20221123_155340_25.jpg: 320x320 (no detections), 7.5ms
# image 168/412 /content/split_custom_data/images/val/IMG_20221123_155340_26.jpg: 320x320 (no detections), 7.9ms
# image 169/412 /content/split_custom_data/images/val/IMG_20221123_155340_27.jpg: 320x320 1 olive, 7.6ms
# image 170/412 /content/split_custom_data/images/val/IMG_20221123_155340_28.jpg: 320x320 1 olive, 7.5ms
# image 171/412 /content/split_custom_data/images/val/IMG_20221123_155340_29.jpg: 320x320 (no detections), 7.4ms
# image 172/412 /content/split_custom_data/images/val/IMG_20221123_155340_3.jpg: 320x320 (no detections), 7.3ms
# image 173/412 /content/split_custom_data/images/val/IMG_20221123_155340_30.jpg: 320x320 (no detections), 7.3ms
# image 174/412 /content/split_custom_data/images/val/IMG_20221123_155340_31.jpg: 320x320 (no detections), 7.3ms
# image 175/412 /content/split_custom_data/images/val/IMG_20221123_155340_32.jpg: 320x320 1 olive, 7.4ms
# image 176/412 /content/split_custom_data/images/val/IMG_20221123_155340_33.jpg: 320x320 5 olives, 9.3ms
# image 177/412 /content/split_custom_data/images/val/IMG_20221123_155340_34.jpg: 320x320 1 olive, 9.5ms
# image 178/412 /content/split_custom_data/images/val/IMG_20221123_155340_35.jpg: 320x320 (no detections), 7.3ms
# image 179/412 /content/split_custom_data/images/val/IMG_20221123_155340_36.jpg: 320x320 (no detections), 7.2ms
# image 180/412 /content/split_custom_data/images/val/IMG_20221123_155340_37.jpg: 320x320 (no detections), 7.4ms
# image 181/412 /content/split_custom_data/images/val/IMG_20221123_155340_38.jpg: 320x320 (no detections), 7.5ms
# image 182/412 /content/split_custom_data/images/val/IMG_20221123_155340_39.jpg: 320x320 (no detections), 7.6ms
# image 183/412 /content/split_custom_data/images/val/IMG_20221123_155340_4.jpg: 320x320 (no detections), 7.6ms
# image 184/412 /content/split_custom_data/images/val/IMG_20221123_155340_40.jpg: 320x320 4 olives, 9.2ms
# image 185/412 /content/split_custom_data/images/val/IMG_20221123_155340_41.jpg: 320x320 1 olive, 7.5ms
# image 186/412 /content/split_custom_data/images/val/IMG_20221123_155340_42.jpg: 320x320 (no detections), 7.3ms
# image 187/412 /content/split_custom_data/images/val/IMG_20221123_155340_43.jpg: 320x320 (no detections), 7.3ms
# image 188/412 /content/split_custom_data/images/val/IMG_20221123_155340_44.jpg: 320x320 1 olive, 7.2ms
# image 189/412 /content/split_custom_data/images/val/IMG_20221123_155340_45.jpg: 320x320 2 olives, 7.3ms
# image 190/412 /content/split_custom_data/images/val/IMG_20221123_155340_46.jpg: 320x320 3 olives, 7.5ms
# image 191/412 /content/split_custom_data/images/val/IMG_20221123_155340_47.jpg: 320x320 3 olives, 7.3ms
# image 192/412 /content/split_custom_data/images/val/IMG_20221123_155340_48.jpg: 320x320 1 olive, 7.4ms
# image 193/412 /content/split_custom_data/images/val/IMG_20221123_155340_49.jpg: 320x320 (no detections), 7.5ms
# image 194/412 /content/split_custom_data/images/val/IMG_20221123_155340_5.jpg: 320x320 (no detections), 7.4ms
# image 195/412 /content/split_custom_data/images/val/IMG_20221123_155340_50.jpg: 320x320 1 olive, 8.4ms
# image 196/412 /content/split_custom_data/images/val/IMG_20221123_155340_51.jpg: 320x320 1 olive, 8.4ms
# image 197/412 /content/split_custom_data/images/val/IMG_20221123_155340_52.jpg: 320x320 (no detections), 7.3ms
# image 198/412 /content/split_custom_data/images/val/IMG_20221123_155340_53.jpg: 320x320 (no detections), 8.5ms
# image 199/412 /content/split_custom_data/images/val/IMG_20221123_155340_54.jpg: 320x320 1 olive, 7.4ms
# image 200/412 /content/split_custom_data/images/val/IMG_20221123_155340_55.jpg: 320x320 (no detections), 7.4ms
# image 201/412 /content/split_custom_data/images/val/IMG_20221123_155340_56.jpg: 320x320 (no detections), 7.4ms
# image 202/412 /content/split_custom_data/images/val/IMG_20221123_155340_57.jpg: 320x320 (no detections), 7.4ms
# image 203/412 /content/split_custom_data/images/val/IMG_20221123_155340_58.jpg: 320x320 (no detections), 7.3ms
# image 204/412 /content/split_custom_data/images/val/IMG_20221123_155340_59.jpg: 320x320 1 olive, 7.3ms
# image 205/412 /content/split_custom_data/images/val/IMG_20221123_155340_6.jpg: 320x320 2 olives, 7.3ms
# image 206/412 /content/split_custom_data/images/val/IMG_20221123_155340_60.jpg: 320x320 1 olive, 7.3ms
# image 207/412 /content/split_custom_data/images/val/IMG_20221123_155340_61.jpg: 320x320 1 olive, 7.7ms
# image 208/412 /content/split_custom_data/images/val/IMG_20221123_155340_62.jpg: 320x320 (no detections), 7.7ms
# image 209/412 /content/split_custom_data/images/val/IMG_20221123_155340_63.jpg: 320x320 (no detections), 7.6ms
# image 210/412 /content/split_custom_data/images/val/IMG_20221123_155340_64.jpg: 320x320 (no detections), 7.6ms
# image 211/412 /content/split_custom_data/images/val/IMG_20221123_155340_65.jpg: 320x320 (no detections), 7.5ms
# image 212/412 /content/split_custom_data/images/val/IMG_20221123_155340_66.jpg: 320x320 1 olive, 7.5ms
# image 213/412 /content/split_custom_data/images/val/IMG_20221123_155340_67.jpg: 320x320 (no detections), 7.5ms
# image 214/412 /content/split_custom_data/images/val/IMG_20221123_155340_68.jpg: 320x320 (no detections), 9.2ms
# image 215/412 /content/split_custom_data/images/val/IMG_20221123_155340_69.jpg: 320x320 (no detections), 8.7ms
# image 216/412 /content/split_custom_data/images/val/IMG_20221123_155340_7.jpg: 320x320 (no detections), 7.4ms
# image 217/412 /content/split_custom_data/images/val/IMG_20221123_155340_70.jpg: 320x320 1 olive, 7.5ms
# image 218/412 /content/split_custom_data/images/val/IMG_20221123_155340_71.jpg: 320x320 (no detections), 7.4ms
# image 219/412 /content/split_custom_data/images/val/IMG_20221123_155340_72.jpg: 320x320 (no detections), 7.6ms
# image 220/412 /content/split_custom_data/images/val/IMG_20221123_155340_73.jpg: 320x320 (no detections), 9.1ms
# image 221/412 /content/split_custom_data/images/val/IMG_20221123_155340_74.jpg: 320x320 (no detections), 9.8ms
# image 222/412 /content/split_custom_data/images/val/IMG_20221123_155340_75.jpg: 320x320 1 olive, 7.3ms
# image 223/412 /content/split_custom_data/images/val/IMG_20221123_155340_76.jpg: 320x320 (no detections), 9.3ms
# image 224/412 /content/split_custom_data/images/val/IMG_20221123_155340_77.jpg: 320x320 (no detections), 7.5ms
# image 225/412 /content/split_custom_data/images/val/IMG_20221123_155340_78.jpg: 320x320 2 olives, 8.5ms
# image 226/412 /content/split_custom_data/images/val/IMG_20221123_155340_79.jpg: 320x320 (no detections), 7.5ms
# image 227/412 /content/split_custom_data/images/val/IMG_20221123_155340_8.jpg: 320x320 (no detections), 7.3ms
# image 228/412 /content/split_custom_data/images/val/IMG_20221123_155340_80.jpg: 320x320 (no detections), 7.3ms
# image 229/412 /content/split_custom_data/images/val/IMG_20221123_155340_81.jpg: 320x320 (no detections), 7.3ms
# image 230/412 /content/split_custom_data/images/val/IMG_20221123_155340_82.jpg: 320x320 (no detections), 7.5ms
# image 231/412 /content/split_custom_data/images/val/IMG_20221123_155340_83.jpg: 320x320 (no detections), 7.4ms
# image 232/412 /content/split_custom_data/images/val/IMG_20221123_155340_84.jpg: 320x320 (no detections), 7.4ms
# image 233/412 /content/split_custom_data/images/val/IMG_20221123_155340_85.jpg: 320x320 (no detections), 7.8ms
# image 234/412 /content/split_custom_data/images/val/IMG_20221123_155340_86.jpg: 320x320 (no detections), 7.5ms
# image 235/412 /content/split_custom_data/images/val/IMG_20221123_155340_87.jpg: 320x320 (no detections), 7.5ms
# image 236/412 /content/split_custom_data/images/val/IMG_20221123_155340_9.jpg: 320x320 1 olive, 7.7ms
# image 237/412 /content/split_custom_data/images/val/IMG_20231007_163938_0.jpg: 320x320 (no detections), 7.8ms
# image 238/412 /content/split_custom_data/images/val/IMG_20231007_163938_1.jpg: 320x320 (no detections), 8.4ms
# image 239/412 /content/split_custom_data/images/val/IMG_20231007_163938_10.jpg: 320x320 (no detections), 7.8ms
# image 240/412 /content/split_custom_data/images/val/IMG_20231007_163938_11.jpg: 320x320 (no detections), 9.3ms
# image 241/412 /content/split_custom_data/images/val/IMG_20231007_163938_12.jpg: 320x320 (no detections), 7.9ms
# image 242/412 /content/split_custom_data/images/val/IMG_20231007_163938_13.jpg: 320x320 (no detections), 7.7ms
# image 243/412 /content/split_custom_data/images/val/IMG_20231007_163938_14.jpg: 320x320 (no detections), 7.7ms
# image 244/412 /content/split_custom_data/images/val/IMG_20231007_163938_15.jpg: 320x320 (no detections), 7.6ms
# image 245/412 /content/split_custom_data/images/val/IMG_20231007_163938_16.jpg: 320x320 (no detections), 7.6ms
# image 246/412 /content/split_custom_data/images/val/IMG_20231007_163938_17.jpg: 320x320 (no detections), 7.6ms
# image 247/412 /content/split_custom_data/images/val/IMG_20231007_163938_18.jpg: 320x320 (no detections), 7.5ms
# image 248/412 /content/split_custom_data/images/val/IMG_20231007_163938_19.jpg: 320x320 (no detections), 7.4ms
# image 249/412 /content/split_custom_data/images/val/IMG_20231007_163938_2.jpg: 320x320 (no detections), 11.3ms
# image 250/412 /content/split_custom_data/images/val/IMG_20231007_163938_20.jpg: 320x320 (no detections), 12.1ms
# image 251/412 /content/split_custom_data/images/val/IMG_20231007_163938_21.jpg: 320x320 (no detections), 14.7ms
# image 252/412 /content/split_custom_data/images/val/IMG_20231007_163938_22.jpg: 320x320 (no detections), 7.7ms
# image 253/412 /content/split_custom_data/images/val/IMG_20231007_163938_23.jpg: 320x320 (no detections), 7.5ms
# image 254/412 /content/split_custom_data/images/val/IMG_20231007_163938_24.jpg: 320x320 (no detections), 7.3ms
# image 255/412 /content/split_custom_data/images/val/IMG_20231007_163938_25.jpg: 320x320 (no detections), 7.5ms
# image 256/412 /content/split_custom_data/images/val/IMG_20231007_163938_26.jpg: 320x320 (no detections), 7.2ms
# image 257/412 /content/split_custom_data/images/val/IMG_20231007_163938_27.jpg: 320x320 1 olive, 7.7ms
# image 258/412 /content/split_custom_data/images/val/IMG_20231007_163938_28.jpg: 320x320 (no detections), 7.3ms
# image 259/412 /content/split_custom_data/images/val/IMG_20231007_163938_29.jpg: 320x320 (no detections), 7.7ms
# image 260/412 /content/split_custom_data/images/val/IMG_20231007_163938_3.jpg: 320x320 (no detections), 7.6ms
# image 261/412 /content/split_custom_data/images/val/IMG_20231007_163938_30.jpg: 320x320 (no detections), 7.7ms
# image 262/412 /content/split_custom_data/images/val/IMG_20231007_163938_31.jpg: 320x320 (no detections), 7.7ms
# image 263/412 /content/split_custom_data/images/val/IMG_20231007_163938_32.jpg: 320x320 (no detections), 7.7ms
# image 264/412 /content/split_custom_data/images/val/IMG_20231007_163938_33.jpg: 320x320 (no detections), 8.2ms
# image 265/412 /content/split_custom_data/images/val/IMG_20231007_163938_34.jpg: 320x320 (no detections), 7.7ms
# image 266/412 /content/split_custom_data/images/val/IMG_20231007_163938_35.jpg: 320x320 (no detections), 7.6ms
# image 267/412 /content/split_custom_data/images/val/IMG_20231007_163938_36.jpg: 320x320 (no detections), 7.6ms
# image 268/412 /content/split_custom_data/images/val/IMG_20231007_163938_37.jpg: 320x320 (no detections), 7.5ms
# image 269/412 /content/split_custom_data/images/val/IMG_20231007_163938_38.jpg: 320x320 (no detections), 7.4ms
# image 270/412 /content/split_custom_data/images/val/IMG_20231007_163938_39.jpg: 320x320 (no detections), 7.4ms
# image 271/412 /content/split_custom_data/images/val/IMG_20231007_163938_4.jpg: 320x320 (no detections), 7.4ms
# image 272/412 /content/split_custom_data/images/val/IMG_20231007_163938_40.jpg: 320x320 (no detections), 7.3ms
# image 273/412 /content/split_custom_data/images/val/IMG_20231007_163938_41.jpg: 320x320 (no detections), 7.4ms
# image 274/412 /content/split_custom_data/images/val/IMG_20231007_163938_42.jpg: 320x320 (no detections), 7.4ms
# image 275/412 /content/split_custom_data/images/val/IMG_20231007_163938_43.jpg: 320x320 (no detections), 7.4ms
# image 276/412 /content/split_custom_data/images/val/IMG_20231007_163938_44.jpg: 320x320 (no detections), 8.7ms
# image 277/412 /content/split_custom_data/images/val/IMG_20231007_163938_45.jpg: 320x320 (no detections), 7.5ms
# image 278/412 /content/split_custom_data/images/val/IMG_20231007_163938_46.jpg: 320x320 (no detections), 7.5ms
# image 279/412 /content/split_custom_data/images/val/IMG_20231007_163938_47.jpg: 320x320 (no detections), 7.5ms
# image 280/412 /content/split_custom_data/images/val/IMG_20231007_163938_48.jpg: 320x320 (no detections), 7.5ms
# image 281/412 /content/split_custom_data/images/val/IMG_20231007_163938_49.jpg: 320x320 (no detections), 7.5ms
# image 282/412 /content/split_custom_data/images/val/IMG_20231007_163938_5.jpg: 320x320 (no detections), 7.5ms
# image 283/412 /content/split_custom_data/images/val/IMG_20231007_163938_50.jpg: 320x320 (no detections), 7.5ms
# image 284/412 /content/split_custom_data/images/val/IMG_20231007_163938_51.jpg: 320x320 (no detections), 7.4ms
# image 285/412 /content/split_custom_data/images/val/IMG_20231007_163938_52.jpg: 320x320 (no detections), 7.4ms
# image 286/412 /content/split_custom_data/images/val/IMG_20231007_163938_53.jpg: 320x320 (no detections), 7.4ms
# image 287/412 /content/split_custom_data/images/val/IMG_20231007_163938_54.jpg: 320x320 (no detections), 7.4ms
# image 288/412 /content/split_custom_data/images/val/IMG_20231007_163938_55.jpg: 320x320 (no detections), 7.4ms
# image 289/412 /content/split_custom_data/images/val/IMG_20231007_163938_56.jpg: 320x320 (no detections), 7.3ms
# image 290/412 /content/split_custom_data/images/val/IMG_20231007_163938_57.jpg: 320x320 (no detections), 7.3ms
# image 291/412 /content/split_custom_data/images/val/IMG_20231007_163938_58.jpg: 320x320 (no detections), 7.3ms
# image 292/412 /content/split_custom_data/images/val/IMG_20231007_163938_59.jpg: 320x320 (no detections), 7.3ms
# image 293/412 /content/split_custom_data/images/val/IMG_20231007_163938_6.jpg: 320x320 (no detections), 7.4ms
# image 294/412 /content/split_custom_data/images/val/IMG_20231007_163938_60.jpg: 320x320 (no detections), 8.2ms
# image 295/412 /content/split_custom_data/images/val/IMG_20231007_163938_61.jpg: 320x320 (no detections), 8.1ms
# image 296/412 /content/split_custom_data/images/val/IMG_20231007_163938_62.jpg: 320x320 (no detections), 8.0ms
# image 297/412 /content/split_custom_data/images/val/IMG_20231007_163938_63.jpg: 320x320 (no detections), 8.0ms
# image 298/412 /content/split_custom_data/images/val/IMG_20231007_163938_64.jpg: 320x320 (no detections), 7.9ms
# image 299/412 /content/split_custom_data/images/val/IMG_20231007_163938_65.jpg: 320x320 (no detections), 8.1ms
# image 300/412 /content/split_custom_data/images/val/IMG_20231007_163938_66.jpg: 320x320 (no detections), 8.6ms
# image 301/412 /content/split_custom_data/images/val/IMG_20231007_163938_67.jpg: 320x320 (no detections), 7.4ms
# image 302/412 /content/split_custom_data/images/val/IMG_20231007_163938_68.jpg: 320x320 (no detections), 7.4ms
# image 303/412 /content/split_custom_data/images/val/IMG_20231007_163938_69.jpg: 320x320 (no detections), 9.3ms
# image 304/412 /content/split_custom_data/images/val/IMG_20231007_163938_7.jpg: 320x320 (no detections), 10.1ms
# image 305/412 /content/split_custom_data/images/val/IMG_20231007_163938_70.jpg: 320x320 (no detections), 9.5ms
# image 306/412 /content/split_custom_data/images/val/IMG_20231007_163938_71.jpg: 320x320 (no detections), 7.3ms
# image 307/412 /content/split_custom_data/images/val/IMG_20231007_163938_72.jpg: 320x320 (no detections), 7.3ms
# image 308/412 /content/split_custom_data/images/val/IMG_20231007_163938_73.jpg: 320x320 (no detections), 7.3ms
# image 309/412 /content/split_custom_data/images/val/IMG_20231007_163938_74.jpg: 320x320 (no detections), 7.3ms
# image 310/412 /content/split_custom_data/images/val/IMG_20231007_163938_75.jpg: 320x320 (no detections), 7.4ms
# image 311/412 /content/split_custom_data/images/val/IMG_20231007_163938_76.jpg: 320x320 (no detections), 7.7ms
# image 312/412 /content/split_custom_data/images/val/IMG_20231007_163938_77.jpg: 320x320 (no detections), 7.5ms
# image 313/412 /content/split_custom_data/images/val/IMG_20231007_163938_78.jpg: 320x320 (no detections), 7.6ms
# image 314/412 /content/split_custom_data/images/val/IMG_20231007_163938_79.jpg: 320x320 (no detections), 8.9ms
# image 315/412 /content/split_custom_data/images/val/IMG_20231007_163938_8.jpg: 320x320 (no detections), 7.7ms
# image 316/412 /content/split_custom_data/images/val/IMG_20231007_163938_80.jpg: 320x320 (no detections), 7.7ms
# image 317/412 /content/split_custom_data/images/val/IMG_20231007_163938_81.jpg: 320x320 (no detections), 7.7ms
# image 318/412 /content/split_custom_data/images/val/IMG_20231007_163938_82.jpg: 320x320 (no detections), 7.7ms
# image 319/412 /content/split_custom_data/images/val/IMG_20231007_163938_83.jpg: 320x320 (no detections), 7.7ms
# image 320/412 /content/split_custom_data/images/val/IMG_20231007_163938_84.jpg: 320x320 (no detections), 7.6ms
# image 321/412 /content/split_custom_data/images/val/IMG_20231007_163938_85.jpg: 320x320 (no detections), 7.6ms
# image 322/412 /content/split_custom_data/images/val/IMG_20231007_163938_86.jpg: 320x320 (no detections), 9.5ms
# image 323/412 /content/split_custom_data/images/val/IMG_20231007_163938_87.jpg: 320x320 (no detections), 7.5ms
# image 324/412 /content/split_custom_data/images/val/IMG_20231007_163938_9.jpg: 320x320 (no detections), 7.5ms
# image 325/412 /content/split_custom_data/images/val/IMG_20231007_164022_0.jpg: 320x320 (no detections), 7.5ms
# image 326/412 /content/split_custom_data/images/val/IMG_20231007_164022_1.jpg: 320x320 (no detections), 7.8ms
# image 327/412 /content/split_custom_data/images/val/IMG_20231007_164022_10.jpg: 320x320 (no detections), 10.1ms
# image 328/412 /content/split_custom_data/images/val/IMG_20231007_164022_11.jpg: 320x320 (no detections), 7.9ms
# image 329/412 /content/split_custom_data/images/val/IMG_20231007_164022_12.jpg: 320x320 (no detections), 7.7ms
# image 330/412 /content/split_custom_data/images/val/IMG_20231007_164022_13.jpg: 320x320 (no detections), 7.5ms
# image 331/412 /content/split_custom_data/images/val/IMG_20231007_164022_14.jpg: 320x320 (no detections), 9.0ms
# image 332/412 /content/split_custom_data/images/val/IMG_20231007_164022_15.jpg: 320x320 (no detections), 7.4ms
# image 333/412 /content/split_custom_data/images/val/IMG_20231007_164022_16.jpg: 320x320 (no detections), 7.5ms
# image 334/412 /content/split_custom_data/images/val/IMG_20231007_164022_17.jpg: 320x320 (no detections), 7.5ms
# image 335/412 /content/split_custom_data/images/val/IMG_20231007_164022_18.jpg: 320x320 (no detections), 7.8ms
# image 336/412 /content/split_custom_data/images/val/IMG_20231007_164022_19.jpg: 320x320 (no detections), 7.8ms
# image 337/412 /content/split_custom_data/images/val/IMG_20231007_164022_2.jpg: 320x320 (no detections), 7.9ms
# image 338/412 /content/split_custom_data/images/val/IMG_20231007_164022_20.jpg: 320x320 (no detections), 7.9ms
# image 339/412 /content/split_custom_data/images/val/IMG_20231007_164022_21.jpg: 320x320 (no detections), 7.8ms
# image 340/412 /content/split_custom_data/images/val/IMG_20231007_164022_22.jpg: 320x320 (no detections), 7.9ms
# image 341/412 /content/split_custom_data/images/val/IMG_20231007_164022_23.jpg: 320x320 (no detections), 7.6ms
# image 342/412 /content/split_custom_data/images/val/IMG_20231007_164022_24.jpg: 320x320 (no detections), 7.6ms
# image 343/412 /content/split_custom_data/images/val/IMG_20231007_164022_25.jpg: 320x320 (no detections), 8.1ms
# image 344/412 /content/split_custom_data/images/val/IMG_20231007_164022_26.jpg: 320x320 (no detections), 13.4ms
# image 345/412 /content/split_custom_data/images/val/IMG_20231007_164022_27.jpg: 320x320 (no detections), 11.1ms
# image 346/412 /content/split_custom_data/images/val/IMG_20231007_164022_28.jpg: 320x320 (no detections), 7.3ms
# image 347/412 /content/split_custom_data/images/val/IMG_20231007_164022_29.jpg: 320x320 (no detections), 7.7ms
# image 348/412 /content/split_custom_data/images/val/IMG_20231007_164022_3.jpg: 320x320 (no detections), 10.9ms
# image 349/412 /content/split_custom_data/images/val/IMG_20231007_164022_30.jpg: 320x320 (no detections), 7.5ms
# image 350/412 /content/split_custom_data/images/val/IMG_20231007_164022_31.jpg: 320x320 (no detections), 8.8ms
# image 351/412 /content/split_custom_data/images/val/IMG_20231007_164022_32.jpg: 320x320 (no detections), 7.9ms
# image 352/412 /content/split_custom_data/images/val/IMG_20231007_164022_33.jpg: 320x320 1 olive, 8.4ms
# image 353/412 /content/split_custom_data/images/val/IMG_20231007_164022_34.jpg: 320x320 (no detections), 7.8ms
# image 354/412 /content/split_custom_data/images/val/IMG_20231007_164022_35.jpg: 320x320 3 olives, 9.7ms
# image 355/412 /content/split_custom_data/images/val/IMG_20231007_164022_36.jpg: 320x320 4 olives, 8.0ms
# image 356/412 /content/split_custom_data/images/val/IMG_20231007_164022_37.jpg: 320x320 (no detections), 7.9ms
# image 357/412 /content/split_custom_data/images/val/IMG_20231007_164022_38.jpg: 320x320 (no detections), 8.1ms
# image 358/412 /content/split_custom_data/images/val/IMG_20231007_164022_39.jpg: 320x320 (no detections), 8.2ms
# image 359/412 /content/split_custom_data/images/val/IMG_20231007_164022_4.jpg: 320x320 (no detections), 7.8ms
# image 360/412 /content/split_custom_data/images/val/IMG_20231007_164022_40.jpg: 320x320 (no detections), 7.9ms
# image 361/412 /content/split_custom_data/images/val/IMG_20231007_164022_41.jpg: 320x320 (no detections), 7.5ms
# image 362/412 /content/split_custom_data/images/val/IMG_20231007_164022_42.jpg: 320x320 (no detections), 7.6ms
# image 363/412 /content/split_custom_data/images/val/IMG_20231007_164022_43.jpg: 320x320 (no detections), 7.5ms
# image 364/412 /content/split_custom_data/images/val/IMG_20231007_164022_44.jpg: 320x320 1 olive, 7.7ms
# image 365/412 /content/split_custom_data/images/val/IMG_20231007_164022_45.jpg: 320x320 (no detections), 9.0ms
# image 366/412 /content/split_custom_data/images/val/IMG_20231007_164022_46.jpg: 320x320 (no detections), 7.5ms
# image 367/412 /content/split_custom_data/images/val/IMG_20231007_164022_47.jpg: 320x320 (no detections), 7.5ms
# image 368/412 /content/split_custom_data/images/val/IMG_20231007_164022_48.jpg: 320x320 (no detections), 7.4ms
# image 369/412 /content/split_custom_data/images/val/IMG_20231007_164022_49.jpg: 320x320 (no detections), 7.4ms
# image 370/412 /content/split_custom_data/images/val/IMG_20231007_164022_5.jpg: 320x320 (no detections), 7.5ms
# image 371/412 /content/split_custom_data/images/val/IMG_20231007_164022_50.jpg: 320x320 (no detections), 7.8ms
# image 372/412 /content/split_custom_data/images/val/IMG_20231007_164022_51.jpg: 320x320 (no detections), 7.4ms
# image 373/412 /content/split_custom_data/images/val/IMG_20231007_164022_52.jpg: 320x320 (no detections), 7.6ms
# image 374/412 /content/split_custom_data/images/val/IMG_20231007_164022_53.jpg: 320x320 (no detections), 7.9ms
# image 375/412 /content/split_custom_data/images/val/IMG_20231007_164022_54.jpg: 320x320 (no detections), 8.0ms
# image 376/412 /content/split_custom_data/images/val/IMG_20231007_164022_55.jpg: 320x320 (no detections), 7.7ms
# image 377/412 /content/split_custom_data/images/val/IMG_20231007_164022_56.jpg: 320x320 (no detections), 7.8ms
# image 378/412 /content/split_custom_data/images/val/IMG_20231007_164022_57.jpg: 320x320 (no detections), 7.6ms
# image 379/412 /content/split_custom_data/images/val/IMG_20231007_164022_58.jpg: 320x320 (no detections), 7.9ms
# image 380/412 /content/split_custom_data/images/val/IMG_20231007_164022_59.jpg: 320x320 (no detections), 8.5ms
# image 381/412 /content/split_custom_data/images/val/IMG_20231007_164022_6.jpg: 320x320 (no detections), 8.0ms
# image 382/412 /content/split_custom_data/images/val/IMG_20231007_164022_60.jpg: 320x320 (no detections), 8.1ms
# image 383/412 /content/split_custom_data/images/val/IMG_20231007_164022_61.jpg: 320x320 (no detections), 7.6ms
# image 384/412 /content/split_custom_data/images/val/IMG_20231007_164022_62.jpg: 320x320 (no detections), 7.7ms
# image 385/412 /content/split_custom_data/images/val/IMG_20231007_164022_63.jpg: 320x320 (no detections), 7.5ms
# image 386/412 /content/split_custom_data/images/val/IMG_20231007_164022_64.jpg: 320x320 (no detections), 7.8ms
# image 387/412 /content/split_custom_data/images/val/IMG_20231007_164022_65.jpg: 320x320 1 olive, 7.5ms
# image 388/412 /content/split_custom_data/images/val/IMG_20231007_164022_66.jpg: 320x320 (no detections), 7.5ms
# image 389/412 /content/split_custom_data/images/val/IMG_20231007_164022_67.jpg: 320x320 (no detections), 7.5ms
# image 390/412 /content/split_custom_data/images/val/IMG_20231007_164022_68.jpg: 320x320 (no detections), 7.4ms
# image 391/412 /content/split_custom_data/images/val/IMG_20231007_164022_69.jpg: 320x320 (no detections), 7.4ms
# image 392/412 /content/split_custom_data/images/val/IMG_20231007_164022_7.jpg: 320x320 (no detections), 10.8ms
# image 393/412 /content/split_custom_data/images/val/IMG_20231007_164022_70.jpg: 320x320 (no detections), 9.3ms
# image 394/412 /content/split_custom_data/images/val/IMG_20231007_164022_71.jpg: 320x320 (no detections), 8.4ms
# image 395/412 /content/split_custom_data/images/val/IMG_20231007_164022_72.jpg: 320x320 (no detections), 7.3ms
# image 396/412 /content/split_custom_data/images/val/IMG_20231007_164022_73.jpg: 320x320 (no detections), 7.3ms
# image 397/412 /content/split_custom_data/images/val/IMG_20231007_164022_74.jpg: 320x320 (no detections), 7.4ms
# image 398/412 /content/split_custom_data/images/val/IMG_20231007_164022_75.jpg: 320x320 (no detections), 7.5ms
# image 399/412 /content/split_custom_data/images/val/IMG_20231007_164022_76.jpg: 320x320 (no detections), 7.3ms
# image 400/412 /content/split_custom_data/images/val/IMG_20231007_164022_77.jpg: 320x320 (no detections), 7.3ms
# image 401/412 /content/split_custom_data/images/val/IMG_20231007_164022_78.jpg: 320x320 (no detections), 7.3ms
# image 402/412 /content/split_custom_data/images/val/IMG_20231007_164022_79.jpg: 320x320 (no detections), 7.3ms
# image 403/412 /content/split_custom_data/images/val/IMG_20231007_164022_8.jpg: 320x320 (no detections), 7.3ms
# image 404/412 /content/split_custom_data/images/val/IMG_20231007_164022_80.jpg: 320x320 (no detections), 7.5ms
# image 405/412 /content/split_custom_data/images/val/IMG_20231007_164022_81.jpg: 320x320 (no detections), 7.6ms
# image 406/412 /content/split_custom_data/images/val/IMG_20231007_164022_82.jpg: 320x320 (no detections), 7.7ms
# image 407/412 /content/split_custom_data/images/val/IMG_20231007_164022_83.jpg: 320x320 (no detections), 7.8ms
# image 408/412 /content/split_custom_data/images/val/IMG_20231007_164022_84.jpg: 320x320 (no detections), 7.8ms
# image 409/412 /content/split_custom_data/images/val/IMG_20231007_164022_85.jpg: 320x320 (no detections), 7.8ms
# image 410/412 /content/split_custom_data/images/val/IMG_20231007_164022_86.jpg: 320x320 (no detections), 8.0ms
# image 411/412 /content/split_custom_data/images/val/IMG_20231007_164022_87.jpg: 320x320 (no detections), 9.6ms
# image 412/412 /content/split_custom_data/images/val/IMG_20231007_164022_9.jpg: 320x320 (no detections), 7.5ms
# Speed: 0.6ms preprocess, 8.2ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 320)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # VIsualisation

# %%
from IPython.display import Image, display
import glob

predictions = glob.glob('/content/runs/detect/predict/*.jpg')
for image_path in predictions[:10]:
    display(Image(filename=image_path, width=600))

# %% [markdown]
# # Télécharger le modèle

# %%
# Create "my_model" folder to store model weights and train results
# !mkdir /content/my_model
# !cp /content/runs/detect/train/weights/best.pt /content/my_model/my_model.pt
# !cp -r /content/runs/detect/train /content/my_model

# Zip into "my_model.zip"
# %cd my_model
# !zip /content/my_model.zip my_model.pt
# !zip -r /content/my_model.zip train
# %cd /content
# Out:
# /content/my_model
#   adding: my_model.pt (deflated 8%)
#   adding: train/ (stored 0%)
#   adding: train/val_batch0_pred.jpg (deflated 11%)
#   adding: train/val_batch0_labels.jpg (deflated 10%)
#   adding: train/R_curve.png (deflated 15%)
#   adding: train/F1_curve.png (deflated 15%)
#   adding: train/train_batch11320.jpg (deflated 4%)
#   adding: train/args.yaml (deflated 52%)
#   adding: train/train_batch1.jpg (deflated 4%)
#   adding: train/val_batch1_labels.jpg (deflated 9%)
#   adding: train/results.csv (deflated 59%)
#   adding: train/train_batch11322.jpg (deflated 7%)
#   adding: train/labels_correlogram.jpg (deflated 34%)
#   adding: train/confusion_matrix.png (deflated 35%)
#   adding: train/train_batch11321.jpg (deflated 5%)
#   adding: train/train_batch0.jpg (deflated 3%)
#   adding: train/train_batch2.jpg (deflated 4%)
#   adding: train/val_batch2_labels.jpg (deflated 7%)
#   adding: train/confusion_matrix_normalized.png (deflated 34%)
#   adding: train/val_batch1_pred.jpg (deflated 9%)
#   adding: train/labels.jpg (deflated 21%)
#   adding: train/results.png (deflated 6%)
#   adding: train/val_batch2_pred.jpg (deflated 8%)
#   adding: train/P_curve.png (deflated 16%)
#   adding: train/weights/ (stored 0%)
#   adding: train/weights/last.pt (deflated 8%)
#   adding: train/weights/best.pt (deflated 8%)
#   adding: train/PR_curve.png (deflated 15%)
# /content
